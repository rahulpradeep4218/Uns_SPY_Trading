# %%
import pandas as pd
import numpy as np
import yaml
from sklearn.manifold import TSNE
from sklearn.cluster import DBSCAN
from scipy.fft import fft
from scipy.stats import boxcox
from scipy.special import inv_boxcox
import matplotlib.pyplot as plt
from plotly.subplots import make_subplots
from sklearn.preprocessing import StandardScaler, OneHotEncoder, LabelEncoder, MinMaxScaler, PowerTransformer, RobustScaler
from sklearn.linear_model import LinearRegression
import openpyxl
import plotly.graph_objects as go
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, recall_score,precision_score, f1_score, mean_squared_error
import xgboost as xgb
import optuna
import talib
import json
import pickle
import torch
import os
import logging
from scipy.stats.mstats import winsorize
from plotly.subplots import make_subplots
import seaborn as sns
from imblearn.over_sampling import SMOTEN
import smogn
import warnings
from datetime import datetime, timedelta

# %%
print(torch.backends.mps.is_available())
# Out:
# True

# %%
def load_yaml(file):
    import yaml
    with open(file, 'r') as f:
        config = yaml.safe_load(f)
    return config

# %%
config = load_yaml('../config_xgRegSlope.yaml')

# %%
for handler in logging.root.handlers[:]:
    logging.root.removeHandler(handler)

log_dir = "logs"
os.makedirs(log_dir, exist_ok=True)
log_file = "logstraining_logs_xgRegSlope.txt"
log_file_path = os.path.join(log_dir, log_file)
print(log_file_path)
logging.basicConfig(
    filename=log_file_path,
    level=logging.INFO,
    format="%(asctime)s - %(levelname)s - %(message)s",
    datefmt="%Y-%m-%d %H:%M:%S"
)

logging.info("Logging started")
# Out:
# logs/logstraining_logs_xgRegSlope.txt

# %%
all_trading_data_dfs = []
sheet_names = ['5minData11-6-2014', '5minData12-17-2019']
for sheet in sheet_names:
    temp_df = pd.read_excel(config['all_data_excel_path'], sheet_name=sheet)
    all_trading_data_dfs.append(temp_df)
all_trading_data = pd.concat(all_trading_data_dfs, ignore_index=True)

# Load 5 min data
all_trading_data['Date'] = pd.to_datetime(all_trading_data['Date'])

# %%
##### Set the Date Start and End for the filtering of trading data
train_start_date = pd.to_datetime('2023-01-01')
train_end_date = pd.to_datetime('2023-12-31')
trading_data_raw = all_trading_data[(all_trading_data['Date'] >= train_start_date) & (all_trading_data['Date'] <= train_end_date)]
trading_data_raw = trading_data_raw.reset_index(drop=True)
trading_data_raw.drop(columns=['Symbol'], inplace=True)
trading_data_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19430 entries, 0 to 19429
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    19430 non-null  datetime64[ns]
#  1   Open    19430 non-null  float64
#  2   High    19430 non-null  float64
#  3   Low     19430 non-null  float64
#  4   Close   19430 non-null  float64
#  5   Volume  19430 non-null  int64
# dtypes: datetime64[ns](1), float64(4), int64(1)
# memory usage: 910.9 KB

# %%
fourier_lookback_window = config['fourier_lookback_window']
fourier_n_components = config['fourier_n_components']
m_bars = config['m_future']

# %%
def calculate_bollinger_bands(data, window_size, num_std_dev):
    rolling_mean = data['Close'].rolling(window=window_size).mean()
    rolling_std = data['Close'].rolling(window=window_size).std()
    data['BOLLBU'] = rolling_mean + (rolling_std * num_std_dev)
    data['BOLLBM'] = rolling_mean
    data['BOLLBL'] = rolling_mean - (rolling_std * num_std_dev)
    
    return data

def calculate_donchn_bands(data, window_size):
    data['DONCH_U'] = data['High'].rolling(window=window_size).max()
    data['DONCH_L'] = data['Low'].rolling(window=window_size).min()
    
    return data
    
def calculate_tchr(data):
    period = config['tchr_period']
    retracement = config['tchr_retracement']
    adj = config['tchr_adj']
    range = config['tchr_range']

    if range == 'highlow':
        data['TCHR_U'] = talib.MAX(data['High'], timeperiod=period) + adj
        data['TCHR_L'] = talib.MIN(data['Low'], timeperiod=period) - adj
    elif range == 'close':
        data['TCHR_U'] = talib.MAX(data['Close'], timeperiod=period) + adj
        data['TCHR_L'] = talib.MIN(data['Close'], timeperiod=period) - adj
    
    #calculate retracement
    if retracement == "long":
        data['TCHR'] = (data['Close'] - data['TCHR_L']) / (data['TCHR_U'] - data['TCHR_L'])
    elif retracement == "short":
        data['TCHR'] = (data['TCHR_U'] - data['Close']) / (data['TCHR_U'] - data['TCHR_L'])
    
    return data
    
def calculate_adwm(data):
    period = config['adwm_period']
    data['Previous_Close']= data['Close'].shift(1)
    data['TRH'] = data[['High', 'Previous_Close']].max(axis=1)
    data['TRL'] = data[['Low', 'Previous_Close']].min(axis=1)

    data['ADWM_AD'] = 0.0
    data.loc[data['Close'] > data['Previous_Close'], 'ADWM_AD'] = (data['Close'] - data['TRL'])
    data.loc[data['Close'] < data['Previous_Close'], 'ADWM_AD'] = (data['Close'] - data['TRH'])

    data['ADWM'] = data['ADWM_AD']

    data['ADWMMA'] = data['ADWM'].rolling(window=period).mean()

    return data

def calculate_si(row, prev_row, limit):
    if pd.isna(prev_row['Close']):
        return 0
    c = row['Close']
    c_prev = prev_row['Close']
    o = row['Open']
    o_prev = prev_row['Open']
    return (50 * ((c - c_prev) + (0.5 * (c - o)) + (0.25 * (c_prev - o_prev))) / limit)

def calculate_WASI(data):
    wasi_limit = config['wasi_limit']
    data['SI'] = data.apply(lambda row: calculate_si(row, data.shift(1).loc[row.name], wasi_limit), axis=1)
    data['WASI'] = data['SI']
    return data

def calculate_ATR(data):
    atr_period = config['atr_period']
    atr_ma = config['atr_ma']
    data['ATR'] = talib.ATR(data['High'], data['Low'], data['Close'], timeperiod=atr_period)
    data['ADJATR'] = talib.SMA(data['ATR'], timeperiod=atr_ma)
    return data


def compute_volatility_momentum(df, price_col='Close', vol_window=14, mom_window=10):
    """
    Computes rolling volatility and momentum for a given price column.

    Parameters:
        df (pd.DataFrame): DataFrame containing historical price data.
        price_col (str): Column name of the closing price.
        vol_window (int): Window size for rolling volatility calculation.
        mom_window (int): Window size for momentum calculation.

    Returns:
        pd.DataFrame: DataFrame with added 'Volatility' and 'Momentum' features.
    """

    # Ensure price column exists
    if price_col not in df.columns:
        raise ValueError(f"Column '{price_col}' not found in DataFrame")

    # 🔹 Compute Log Returns (for better volatility calculation)
    df['Log_Returns'] = np.log(df[price_col] / df[price_col].shift(1))

    # 🔹 Compute Rolling Volatility (Standard Deviation of Log Returns)
    df['Volatility'] = df['Log_Returns'].rolling(window=vol_window).std()

    # 🔹 Compute Momentum (Rate of Change in Price)
    df['Momentum'] = df[price_col].pct_change(periods=mom_window) * 100

    # 🔹 Drop NaN values from rolling computations
    #df.dropna(inplace=True)

    return df


def compute_fourier_df(value_series, n_components=10):
    fft_result = np.fft.fft(value_series)
    real = fft_result.real[:n_components]
    imag = fft_result.imag[:n_components]
    mag = np.abs(fft_result)[:n_components]

    return real, imag, mag

def get_fourier_columns():
    return [f'fourier_real_{j+2}' for j in range(fourier_n_components-1)] + [f'fourier_imag_{j+2}' for j in range(fourier_n_components-1)] + [f'fourier_mag_{j+2}' for j in range(fourier_n_components-1)]   

def transform_features(df):
    close_diff_features = config['Close_Diff_Features'].split(',')
    df[close_diff_features] = df[close_diff_features].sub(df['Close'], axis=0).div(df['Close'], axis=0)
    return df

def get_all_training_features():
    training_features = config['training_features'].split(',')
    fourier_cols = get_fourier_columns()
    return training_features + fourier_cols

def normalize_timegaps(df, time_gap_threshold=300):
    df = df.copy()
    features = ['Open', 'High', 'Low', 'Close']
    df['time_delta'] = df['Date'].diff().dt.total_seconds()
    df['time_delta'] = df['time_delta'].fillna(df['time_delta'].median())
    df['time_gap_flag'] = df['time_delta'] > time_gap_threshold
    gap_indices = df.index[df['time_gap_flag']].tolist()
    for p in gap_indices:
        if p > 0: # ensure p-1 exist
            jump_value = df.loc[p, 'Close'] - df.loc[p-1, 'Close']
            df.loc[:p-1, features] += jump_value
    return df

# %%
def add_new_features_df(data):
    fourier_lookback_window = config['fourier_lookback_window']
    fourier_n_components = config['fourier_n_components']

    #data['Date'] = pd.to_datetime(data['Date'])
    #print(f"bolband period : {config['bolband_period']}")
    bolband_period = config['bolband_period']
    bolband_width = config['bolband_width']
    upper, middle, lower = talib.BBANDS(data['Close'], timeperiod=bolband_period, nbdevup=bolband_width, nbdevdn=bolband_width, matype=0)
    data['BOLLBU'] = upper
    data['BOLLBM'] = middle
    data['BOLLBL'] = lower
    #data = calculate_bollinger_bands(data, int(config['bolband_period']), int(config['bolband_width']))

    # Calculate DONCHN Bands
    donchn_period = config['donchn_period']
    data['DONUP'] = talib.MAX(data['High'], timeperiod=donchn_period)

    data['DONLOW'] = talib.MIN(data['Low'], timeperiod=donchn_period)

    data['DONMID'] = (data['DONLOW'] + data['DONUP']) / 2

    data['MA20'] = talib.SMA(data['Close'], timeperiod=20)

    data['MA50'] = talib.SMA(data['Close'], timeperiod=50)

    data['MA100'] = talib.SMA(data['Close'], timeperiod=100)

    data['EMA20'] = talib.EMA(data['Close'], timeperiod=20)

    # Calculate the pivot points
    data['PVPT'] = (data['High'] + data['Low'] + data['Close']) / 3
    data['PVPTR1'] = (2 * data['PVPT']) - data['Low']

    data['PVPTR2'] = data['PVPT'] + data['High'] - data['Low']

    data['PVPTR3'] = data['High'] + 2 * (data['PVPT'] - data['Low'])

    data['PVPTS1'] = (2 * data['PVPT']) - data['High']

    data['PVPTS2'] = data['PVPT'] - (data['High'] - data['Low'])

    data['PVPTS3'] = data['Low'] - 2 * (data['High'] - data['PVPT'])

    data = calculate_tchr(data)

    data = calculate_adwm(data)

    data = calculate_WASI(data)

    volume_ma_period = config['volume_ma_period']

    data['VOLMA'] = talib.SMA(data['Volume'], timeperiod=volume_ma_period)

    data = calculate_ATR(data)

    data['DayofWeek'] = data['Date'].dt.dayofweek

    data['DayofWeek'] = data['DayofWeek'].astype('category')

    data = compute_volatility_momentum(data, price_col='Close', vol_window=config['volatility_period'], mom_window=config['momentum_period'])

    # Add fourier columns to the df
    for i in range(fourier_n_components):
        data[f'fourier_real_{i+1}'] = np.nan
        data[f'fourier_imag_{i+1}'] = np.nan
        data[f'fourier_mag_{i+1}'] = np.nan

    features = []
    epsilon = 1e-5
    #print(f"fourier window - 1 : {fourier_lookback_window - 1}")
    for i in range(len(data)):
        if i >= fourier_lookback_window - 1:
            #print("entered point 1")
            close_window = data['Close'].iloc[i - fourier_lookback_window + 1: i + 1].values
            real, imag, mag = compute_fourier_df(close_window, n_components=fourier_n_components)

            for j in range(fourier_n_components):
                data.iloc[i, data.columns.get_loc(f'fourier_real_{j+1}')] = real[j]
                data.iloc[i, data.columns.get_loc(f'fourier_imag_{j+1}')] = imag[j]
                data.iloc[i, data.columns.get_loc(f'fourier_mag_{j+1}')] = mag[j]
                #print(data.loc[i, 'Date'])
    


    # Add the time of day feature to the trading data

    # Define max time of day in minutes
    MAX_TIME_MINUTES = 1440
    data['Minutes_Passed'] = (data['Date'].dt.hour* 60) + data['Date'].dt.minute
    data['TimeOfDay_Group'] = (data['Minutes_Passed'] // 5).astype('int')
    data['Sine_TimeOfDay'] = np.sin(2 * np.pi * data['TimeOfDay_Group'] / MAX_TIME_MINUTES)
    data['Cosine_TimeOfDay'] = np.cos(2 * np.pi * data['TimeOfDay_Group'] / MAX_TIME_MINUTES)
    data['Take_Profit_Level'] = (data['Close'] * config['atr_multiplier'] * data['ADJATR'])
    data['time_delta'] = data['Date'].diff().dt.total_seconds()
    data['time_delta'].fillna(data['time_delta'].median(), inplace=True)
    #print("Feature df info : ")
    #print(data.info())

    #print(f"Last row after adding features : ")
    #print(data.tail())
    return data

# %%
trading_data_time_normalized = normalize_timegaps(trading_data_raw)

# %%
toplot_df = trading_data_time_normalized

fig = make_subplots(rows=2, cols=1, shared_xaxes=True, 
                    vertical_spacing=0.1,
                    subplot_titles=("CandleStick Chart Norm", "CandleStick Chart"))
fig.add_trace(
    go.Candlestick(
        x=toplot_df['Date'], 
        open=toplot_df['Open'], 
        high=toplot_df['High'], 
        low=toplot_df['Low'], 
        close=toplot_df['Close'],
        name='OHLC Norm'
        ), row=1, col=1
)

fig.add_trace(
    go.Candlestick(
        x=trading_data_raw['Date'], 
        open=trading_data_raw['Open'], 
        high=trading_data_raw['High'], 
        low=trading_data_raw['Low'], 
        close=trading_data_raw['Close'],
        name='OHLC'
        ), row=2,col=1
)

fig.update_layout(
    title='CandleStick chart of time normalized',
    xaxis=dict(type="date", 
               rangebreaks=[
                   dict(bounds=["sat", "mon"]),
                   dict(bounds=[16,9.5], pattern='hour')
               ]              
            ),
    xaxis_rangeslider_visible=False,
    height=600,
    hovermode='x unified'
)



fig.update_xaxes(matches='x')

fig.show()

# %%
def calculate_label(data):

# Define the threshold for buy and sell signals
    
    buy_powers = []
    sell_powers = []
    n=config['bars_no_to_wait']
    for i in range(len(data)):
        current_close = data.loc[i, "Close"]

        future_closes = data.loc[i+1: i+n+1, "Close"].values

        if len(future_closes) == 0:
            buy_powers.append(0)
            sell_powers.append(0)
            continue
        future_close_max = max(future_closes) 
        future_close_min = min(future_closes)
        max_high = future_close_max - current_close
        min_high = current_close - future_close_min
        max_high_idx = list(future_closes).index( future_close_max)
        min_high_idx = list(future_closes).index( future_close_min)

        if max_high_idx == (len(future_closes) - 1): #when max value is at the last of window
            buy_retr_penalty = 0
        else:
            buy_retr_penalty = future_close_max - min(future_closes[max_high_idx+1:])
        max_down_below = max(0, current_close - future_close_min)
        penalty_buy = buy_retr_penalty + max_down_below
        buy_power = max(0, max_high - penalty_buy)

        if min_high_idx == (len(future_closes) - 1): 
            sell_retr_penalty = 0
        else:
            sell_retr_penalty = max(future_closes[min_high_idx+1:]) - future_close_min
        max_up_above = max(0, future_close_max - current_close)
        penalty_sell = sell_retr_penalty + max_up_above
        sell_power = max(0, min_high - penalty_sell)

        buy_powers.append(buy_power)
        sell_powers.append(sell_power)

    data['BuyPower'] = buy_powers
    data['SellPower'] = sell_powers
        

    return data

# %%
trading_data_with_power = calculate_label(trading_data_time_normalized)
trading_data_with_power.dropna(inplace=True)

# %%
trading_data_with_power[['BuyPower']].describe()
# Out:
#            BuyPower
# count  19430.000000
# mean       0.336215
# std        0.643031
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.448075
# max        9.050000

# %%
trading_data_with_power[['SellPower']].describe()
# Out:
#           SellPower
# count  19430.000000
# mean       0.306297
# std        0.667021
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.278700
# max        9.600000

# %%
trading_data_with_power[(trading_data_with_power['BuyPower'] > 0.5) | (trading_data_with_power['SellPower'] > 0.5)].count()
#trading_data_with_slope.count()
# Out:
# Date             8481
# Open             8481
# High             8481
# Low              8481
# Close            8481
# Volume           8481
# time_delta       8481
# time_gap_flag    8481
# BuyPower         8481
# SellPower        8481
# dtype: int64

# %%
trading_data_with_features = add_new_features_df(trading_data_with_power.copy())
# Out:
# /var/folders/ns/6tgyd_dx5lq_3chvzvfdm1sr0000gp/T/ipykernel_39932/1900632745.py:96: FutureWarning:
#
# A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.

# %%
pd.set_option("display.max_columns", None)  # Show all columns
pd.set_option("display.max_rows", None)  # Show all rows
trading_data_with_features.describe().T
# Out:
#                      count                           mean  \
# Date                 19430  2023-07-02 15:44:07.936180992
# Open               19430.0                     468.036754
# High               19430.0                     468.267182
# Low                19430.0                     467.801705
# Close              19430.0                     468.039982
# Volume             19430.0                  748430.984354
# time_delta         19430.0                    1602.027792
# BuyPower           19430.0                       0.336215
# SellPower          19430.0                       0.306297
# BOLLBU             19411.0                     469.038549
# BOLLBM             19411.0                     468.057158
# BOLLBL             19411.0                     467.075768
# DONUP              19411.0                     469.093305
# DONLOW             19411.0                     466.954038
# DONMID             19411.0                     468.023672
# MA20               19411.0                     468.057158
# MA50               19381.0                     468.086562
# MA100              19331.0                     468.136237
# EMA20              19411.0                     468.057532
# PVPT               19430.0                     468.036289
# PVPTR1             19430.0                     468.270874
# PVPTR2             19430.0                     468.501766
# PVPTR3             19430.0                     468.736351
# PVPTS1             19430.0                     467.805397
# PVPTS2             19430.0                     467.570813
# PVPTS3             19430.0                     467.339921
# TCHR_U             19331.0                     475.555742
# TCHR_L             19331.0                     460.534923
# TCHR               19331.0                       0.515323
# Previous_Close     19429.0                     468.039603
# TRH                19430.0                     468.267304
# TRL                19430.0                     467.801533
# ADWM_AD            19430.0                       0.005714
# ADWM               19430.0                       0.005714
# ADWMMA             19417.0                       0.005903
# SI                 19430.0                       0.081289
# WASI               19430.0                       0.081289
# VOLMA              19421.0                  747670.370347
# ATR                19416.0                       0.465729
# ADJATR             19397.0                       0.465537
# Log_Returns        19429.0                       0.000005
# Volatility         19416.0                       0.000604
# Momentum           19420.0                       0.005909
# fourier_real_1     19331.0                    46813.62368
# fourier_imag_1     19331.0                            0.0
# fourier_mag_1      19331.0                    46813.62368
# fourier_real_2     19331.0                      -0.185167
# fourier_imag_2     19331.0                       4.326233
# fourier_mag_2      19331.0                       61.55453
# fourier_real_3     19331.0                      -0.128774
# fourier_imag_3     19331.0                       2.168186
# fourier_mag_3      19331.0                      31.372622
# fourier_real_4     19331.0                       -0.13242
# fourier_imag_4     19331.0                       1.435442
# fourier_mag_4      19331.0                      20.245386
# fourier_real_5     19331.0                      -0.135737
# fourier_imag_5     19331.0                       1.079201
# fourier_mag_5      19331.0                      14.764448
# fourier_real_6     19331.0                      -0.137131
# fourier_imag_6     19331.0                       0.859639
# fourier_mag_6      19331.0                       12.21928
# fourier_real_7     19331.0                      -0.135077
# fourier_imag_7     19331.0                        0.71357
# fourier_mag_7      19331.0                      10.181927
# fourier_real_8     19331.0                      -0.135885
# fourier_imag_8     19331.0                       0.606716
# fourier_mag_8      19331.0                       8.967302
# fourier_real_9     19331.0                      -0.134824
# fourier_imag_9     19331.0                       0.527453
# fourier_mag_9      19331.0                       7.751669
# fourier_real_10    19331.0                      -0.134856
# fourier_imag_10    19331.0                       0.467094
# fourier_mag_10     19331.0                        7.06588
# Minutes_Passed     19430.0                     762.112712
# TimeOfDay_Group    19430.0                     152.422542
# Sine_TimeOfDay     19430.0                        0.61414
# Cosine_TimeOfDay   19430.0                       0.783085
# Take_Profit_Level  19397.0                       4.335516
#
#                                    min                  25%  \
# Date               2023-01-03 09:30:00  2023-04-03 11:16:15
# Open                          420.4026            460.29615
# High                          420.6326            460.54785
# Low                           419.7826            460.06165
# Close                         420.4026           460.297225
# Volume                        102474.0            400117.75
# time_delta                       300.0                300.0
# BuyPower                           0.0                  0.0
# SellPower                          0.0                  0.0
# BOLLBU                      422.698806           461.370436
# BOLLBM                      421.815025           460.335253
# BOLLBL                       419.85179           459.230916
# DONUP                         422.9426              461.445
# DONLOW                        419.7826             459.2183
# DONMID                        421.8481             460.3533
# MA20                        421.815025           460.335253
# MA50                        422.241238             460.3517
# MA100                       423.095738           460.336445
# EMA20                       421.951642           460.338838
# PVPT                          420.2726           460.308225
# PVPTR1                        420.7626           460.548425
# PVPTR2                        421.1226           460.797542
# PVPTR3                      421.539133           461.032642
# PVPTS1                        419.6326           460.058108
# PVPTS2                        418.7326           459.822075
# PVPTS3                        417.5726           459.572692
# TCHR_U                        431.1926             468.0724
# TCHR_L                        414.7826             452.2543
# TCHR                          0.203933             0.431688
# Previous_Close                420.4026             460.2963
# TRH                           420.6326            460.54785
# TRL                           419.7826            460.06165
# ADWM_AD                         -2.834                -0.27
# ADWM                            -2.834                -0.27
# ADWMMA                       -0.765421            -0.052229
# SI                             -68.215            -3.996042
# WASI                           -68.215            -3.996042
# VOLMA                         181077.7             443069.9
# ATR                           0.164919             0.347587
# ADJATR                        0.176209             0.352608
# Log_Returns                  -0.005842            -0.000333
# Volatility                    0.000097             0.000397
# Momentum                     -1.383578             -0.10864
# fourier_real_1              42309.5738          46033.64445
# fourier_imag_1                     0.0                  0.0
# fourier_mag_1               42309.5738          46033.64445
# fourier_real_2             -128.968521           -20.973629
# fourier_imag_2              -237.59569           -33.455218
# fourier_mag_2                 0.223697            31.869742
# fourier_real_3              -86.353998           -11.023066
# fourier_imag_3             -158.768886           -16.971632
# fourier_mag_3                 0.230777            16.270338
# fourier_real_4              -56.346467            -7.098327
# fourier_imag_4             -103.033168           -11.114172
# fourier_mag_4                 0.080291            10.315018
# fourier_real_5              -41.588373            -5.010341
# fourier_imag_5              -56.586982            -8.481924
# fourier_mag_5                 0.155883             7.466479
# fourier_real_6              -43.833967            -4.421647
# fourier_imag_6              -64.038175            -6.800731
# fourier_mag_6                 0.020273             6.200472
# fourier_real_7              -39.812036            -3.750754
# fourier_imag_7              -46.528942            -5.621105
# fourier_mag_7                 0.035649             5.312237
# fourier_real_8              -31.158141            -3.501378
# fourier_imag_8              -47.414182            -4.839925
# fourier_mag_8                 0.062019              4.64683
# fourier_real_9              -23.498053            -2.964306
# fourier_imag_9              -38.436374             -4.12721
# fourier_mag_9                 0.069479             3.849461
# fourier_real_10             -20.461723            -2.925189
# fourier_imag_10             -31.987948            -3.832047
# fourier_mag_10                0.024952             3.731861
# Minutes_Passed                   570.0                665.0
# TimeOfDay_Group                  114.0                133.0
# Sine_TimeOfDay                0.477159             0.548293
# Cosine_TimeOfDay              0.672367             0.731354
# Take_Profit_Level             1.681099             3.332625
#
#                                    50%                  75%  \
# Date               2023-07-04 11:15:00  2023-10-02 11:13:45
# Open                         468.24485             476.8406
# High                          468.4607           477.037475
# Low                          467.98915             476.6397
# Close                         468.2429           476.839175
# Volume                        567533.0            835923.25
# time_delta                       300.0                300.0
# BuyPower                           0.0             0.448075
# SellPower                          0.0               0.2787
# BOLLBU                      469.188263           477.590059
# BOLLBM                      468.186145           476.822095
# BOLLBL                      467.197938           476.071495
# DONUP                         469.2936              477.628
# DONLOW                        467.1282             475.9988
# DONMID                        468.2036           476.833475
# MA20                        468.186145           476.822095
# MA50                         468.17541            476.92241
# MA100                       468.082709           476.988877
# EMA20                       468.190234           476.863058
# PVPT                        468.233033           476.837267
# PVPTR1                      468.450833           477.033567
# PVPTR2                      468.695383           477.233317
# PVPTR3                      468.901383           477.415167
# PVPTS1                       467.98915           476.630908
# PVPTS2                        467.7547           476.455992
# PVPTS3                      467.543983           476.263625
# TCHR_U                        475.3236             484.0509
# TCHR_L                        460.5526             470.0497
# TCHR                          0.523473               0.6001
# Previous_Close                468.2426             476.8397
# TRH                           468.4607           477.037475
# TRL                          467.98915             476.6397
# ADWM_AD                          0.055                 0.28
# ADWM                             0.055                 0.28
# ADWMMA                        0.010971             0.067843
# SI                            0.333333             4.330417
# WASI                          0.333333             4.330417
# VOLMA                         594229.5             880622.8
# ATR                           0.429324             0.544852
# ADJATR                        0.430428             0.541333
# Log_Returns                   0.000012             0.000356
# Volatility                    0.000528             0.000733
# Momentum                      0.013902             0.125032
# fourier_real_1              46808.2709          47698.88765
# fourier_imag_1                     0.0                  0.0
# fourier_mag_1               46808.2709          47698.88765
# fourier_real_2                -0.67293            20.815251
# fourier_imag_2                7.978626            44.000977
# fourier_mag_2                52.292525            81.680708
# fourier_real_3                0.008806            10.820115
# fourier_imag_3                 3.13656            22.041482
# fourier_mag_3                26.965166            42.072115
# fourier_real_4               -0.200583             6.939561
# fourier_imag_4                2.080982            14.003489
# fourier_mag_4                 16.79571            26.933502
# fourier_real_5               -0.190956             4.911804
# fourier_imag_5                1.622721            10.305544
# fourier_mag_5                12.627922            19.574733
# fourier_real_6                -0.27321             4.156078
# fourier_imag_6                1.237374              8.27174
# fourier_mag_6                10.220869            15.989397
# fourier_real_7               -0.177649             3.408504
# fourier_imag_7                0.981924             7.226143
# fourier_mag_7                 8.623216            13.490423
# fourier_real_8               -0.258847              3.10852
# fourier_imag_8                1.003803             6.145007
# fourier_mag_8                 7.584035            11.807937
# fourier_real_9               -0.204059             2.601414
# fourier_imag_9                0.848226             5.315185
# fourier_mag_9                 6.504487            10.294216
# fourier_real_10              -0.281823             2.570994
# fourier_imag_10               0.713582             4.735687
# fourier_mag_10                6.097115             9.411132
# Minutes_Passed                   760.0                860.0
# TimeOfDay_Group                  152.0                172.0
# Sine_TimeOfDay                0.615661             0.681998
# Cosine_TimeOfDay              0.788011             0.836286
# Take_Profit_Level             4.038999             5.008397
#
#                                    max            std
# Date               2023-12-29 15:55:00            NaN
# Open                          500.9704      15.430225
# High                          501.1004      15.389335
# Low                           500.7604      15.464606
# Close                         500.9754      15.428774
# Volume                      14680996.0  774583.394127
# time_delta                    322500.0   14296.510143
# BuyPower                          9.05       0.643031
# SellPower                          9.6       0.667021
# BOLLBU                      501.101291      15.253146
# BOLLBM                       500.56589      15.395992
# BOLLBL                      500.171015      15.561256
# DONUP                         501.1004      15.228514
# DONLOW                        499.7504      15.569751
# DONMID                        500.3454      15.389999
# MA20                         500.56589      15.395992
# MA50                        500.470186      15.338541
# MA100                       500.184697      15.237977
# EMA20                       500.546574      15.389273
# PVPT                          500.9154      15.426962
# PVPTR1                        501.0704      15.390685
# PVPTR2                      501.277067      15.354023
# PVPTR3                        501.5604      15.320095
# PVPTS1                        500.8204      15.466007
# PVPTS2                        500.6654        15.5046
# PVPTS3                        500.5704      15.545993
# TCHR_U                        506.1004      14.854207
# TCHR_L                        494.0404      15.700945
# TCHR                            0.7951       0.109501
# Previous_Close                500.9754      15.429081
# TRH                           501.1004      15.389318
# TRL                           500.7604       15.46465
# ADWM_AD                           3.88       0.414159
# ADWM                              3.88       0.414159
# ADWMMA                         0.74965       0.108271
# SI                           84.208333       7.978444
# WASI                         84.208333       7.978444
# VOLMA                        3800975.9  457651.812739
# ATR                           1.621182       0.175727
# ADJATR                        1.554505       0.168835
# Log_Returns                   0.007856       0.000679
# Volatility                    0.002781       0.000306
# Momentum                      1.579669       0.215423
# fourier_real_1              50018.4697    1523.797662
# fourier_imag_1                     0.0            0.0
# fourier_mag_1               50018.4697    1523.797662
# fourier_real_2              160.100603       35.29862
# fourier_imag_2              264.730959      64.839898
# fourier_mag_2               264.798918      40.985368
# fourier_real_3               85.579219      18.660813
# fourier_imag_3              132.216078      32.791171
# fourier_mag_3               158.862526      21.069228
# fourier_real_4               54.341794      11.716087
# fourier_imag_4               87.671447      21.423742
# fourier_mag_4                103.17662      13.726787
# fourier_real_5               39.235818        8.26417
# fourier_imag_5               74.072137      15.672988
# fourier_mag_5                74.413565        9.85505
# fourier_real_6               40.743604       7.428701
# fourier_imag_6               61.162539      12.883315
# fourier_mag_6                64.634789       8.520838
# fourier_real_7               35.373723       6.107312
# fourier_imag_7               49.379343      10.613182
# fourier_mag_7                50.200241       6.840273
# fourier_real_8               30.361453        5.55966
# fourier_imag_8               41.902741       9.242196
# fourier_mag_8                48.364642       6.024776
# fourier_real_9               26.278727        4.89502
# fourier_imag_9               39.375617       8.033084
# fourier_mag_9                40.008818       5.356919
# fourier_real_10              22.374692       4.451368
# fourier_imag_10              32.871283       7.133808
# fourier_mag_10               33.658841       4.583997
# Minutes_Passed                   955.0     112.553342
# TimeOfDay_Group                  191.0      22.510668
# Sine_TimeOfDay                0.740218       0.077095
# Cosine_TimeOfDay              0.878817       0.060553
# Take_Profit_Level            14.129873       1.503389

# %%
#trading_data['Date'] = pd.to_datetime(trading_data['Date'])
fig = go.Figure(data=[go.Candlestick(x=trading_data_with_features['Date'], open=trading_data_with_features['Open'], high=trading_data_with_features['High'], low=trading_data_with_features['Low'], close=trading_data_with_features['Close'])])
fig.update_layout(title='CandleStick Chart SPY', xaxis_title='Date', yaxis_title='Price', xaxis_rangeslider_visible=False, yaxis=dict(fixedrange=False), xaxis=dict(type='category'))
buy_signals = trading_data_with_features[trading_data_with_features['BuyPower'] > 0.5]
sell_signals = trading_data_with_features[trading_data_with_features['SellPower'] > 0.5]
fig.add_trace(go.Scatter(x=buy_signals['Date'], y=buy_signals['Low'], mode='markers', name='Buy Signal', marker=dict(color='blue', size=10), text=[f"Slope: {slope:.3f}" for slope in buy_signals['BuyPower']]))
fig.add_trace(go.Scatter(x=sell_signals['Date'], y=sell_signals['High'], mode='markers', name='Sell Signal', marker=dict(color='yellow', size=10), text=[f"Slope: {slope:.3f}" for slope in sell_signals['SellPower']]))
fig.show()

# %% [markdown]
# ####  Transform Features that have to be differenced from Close

# %%
trading_data_transformed = transform_features(trading_data_with_features.copy())

# %%
all_training_features = get_all_training_features()

# %% [markdown]
# #### Do Robust scaling on all training features

# %%
trading_data_scaled = trading_data_transformed.copy()
rscaler = RobustScaler()
trading_data_scaled[all_training_features] = rscaler.fit_transform(trading_data_scaled[all_training_features])

# %% [markdown]
# #### Use Clipping (Winsorization) to Limit Extreme Values

# %%
def winsor_features(df, features, lower=5, upper=95):
    df = df.copy()
    lower_limit = lower / 100
    upper_limit = (100 - upper) / 100
    for feature in features:
        df[feature] = winsorize(df[feature], limits=(lower_limit, upper_limit))

    return df

# %%
### Set lower limit and upper limit for winsor
lower_limit_winsor = 5
upper_limit_Winsor = 95
### Apply the winsorization for all training features
trading_data_scaled = winsor_features(trading_data_scaled, all_training_features, lower=lower_limit_winsor, upper=upper_limit_Winsor)

# %%
plt.figure(figsize=(20, 10))
sns.boxplot(data=trading_data_scaled[all_training_features])
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# #### UnderSampling and Oversampling Data

# %%
do_smote = False
if do_smote:
    epsilon = 0.05

    X = trading_data_scaled[all_training_features]
    y = trading_data_scaled['Close_Slope']

    # Balance dataset by reducing near zero slopes
    extreme_values = trading_data_scaled[np.abs(y) > epsilon]
    near_zero_values = trading_data_scaled[np.abs(y) <= epsilon].sample(frac=0.3, random_state=42)
    balanced_data = pd.concat([extreme_values, near_zero_values]).reset_index(drop=True)
    print(f"Balanced data before smogn shape: {balanced_data.shape}")
    balanced_data['Close_Slope'].describe()
    features_with_labels = all_training_features + ['Close_Slope']
    balanced_data = balanced_data[features_with_labels]

    # Apply SMOGN
    smote_balanced_data = smogn.smoter(
        data=balanced_data, 
        y='Close_Slope', 
        samp_method='balance'
    )
    print(f"Balanced data after smogn shape: {smote_balanced_data.shape}")
    #X_balanced = balanced_data[all_training_features]
    #y_balanced = balanced_data['Close_Slope']

    X = smote_balanced_data[all_training_features]
    y = smote_balanced_data['Close_Slope']

# %%
def weighted_loss(preds, dtrain):
    labels = dtrain.get_label()
    residuals = (preds - labels).astype("float")
    weights = np.where(np.abs(labels) > 0.05, 5.0, 1.0)
    grad = 2.0 * residuals * weights
    hess = 2.0 * weights
    return grad, hess

# %% [markdown]
# #### Check Weights of buy power and sell power

# %%
y = trading_data_scaled[['BuyPower', 'SellPower']]
X = trading_data_scaled[all_training_features]
buying_weight = (y['BuyPower'] > 0).sum() / (y['BuyPower'] == 0).sum()
selling_weight = (y['SellPower'] > 0).sum() / (y['SellPower'] == 0).sum()
print(f"Buying weight: {buying_weight}")
print(f"Selling weight: {selling_weight}")
# Out:
# Buying weight: 0.6222760290556901
# Selling weight: 0.4690760623015273

# %%
((y['BuyPower'] == 0) & (y['SellPower'] == 0)).sum()
# Out:
# np.int64(5773)

# %%
do_weight_balancing = False
if do_weight_balancing:
    epsilon = 0.05
    extreme_values = trading_data_scaled[np.abs(trading_data_scaled['Close_Slope']) > epsilon]
    near_zero_values = trading_data_scaled[np.abs(trading_data_scaled['Close_Slope']) <= epsilon].sample(frac=0.5, random_state=42)
    print(f"Extreme values shape: {extreme_values.shape} and near zero values shape: {near_zero_values.shape}")
    balanced_data = pd.concat([extreme_values, near_zero_values]).reset_index(drop=True)
    print(f"Balanced data shape: {balanced_data.shape} and actual data shape : {trading_data_scaled.shape}")
    X = balanced_data[all_training_features]
    y = balanced_data['Close_Slope']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=43)

# %%
print(X.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19430 entries, 0 to 19429
# Data columns (total 50 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   BOLLBU            19430 non-null  float64
#  1   BOLLBM            19430 non-null  float64
#  2   BOLLBL            19430 non-null  float64
#  3   DONUP             19430 non-null  float64
#  4   DONMID            19430 non-null  float64
#  5   DONLOW            19430 non-null  float64
#  6   MA20              19430 non-null  float64
#  7   MA50              19430 non-null  float64
#  8   MA100             19430 non-null  float64
#  9   EMA20             19430 non-null  float64
#  10  PVPTR1            19430 non-null  float64
#  11  PVPTR2            19430 non-null  float64
#  12  PVPTR3            19430 non-null  float64
#  13  PVPTS1            19430 non-null  float64
#  14  PVPTS2            19430 non-null  float64
#  15  PVPTS3            19430 non-null  float64
#  16  Sine_TimeOfDay    19430 non-null  float64
#  17  Cosine_TimeOfDay  19430 non-null  float64
#  18  ADWMMA            19430 non-null  float64
#  19  TCHR              19430 non-null  float64
#  20  ADJATR            19430 non-null  float64
#  21  Volatility        19430 non-null  float64
#  22  Momentum          19430 non-null  float64
#  23  fourier_real_2    19430 non-null  float64
#  24  fourier_real_3    19430 non-null  float64
#  25  fourier_real_4    19430 non-null  float64
#  26  fourier_real_5    19430 non-null  float64
#  27  fourier_real_6    19430 non-null  float64
#  28  fourier_real_7    19430 non-null  float64
#  29  fourier_real_8    19430 non-null  float64
#  30  fourier_real_9    19430 non-null  float64
#  31  fourier_real_10   19430 non-null  float64
#  32  fourier_imag_2    19430 non-null  float64
#  33  fourier_imag_3    19430 non-null  float64
#  34  fourier_imag_4    19430 non-null  float64
#  35  fourier_imag_5    19430 non-null  float64
#  36  fourier_imag_6    19430 non-null  float64
#  37  fourier_imag_7    19430 non-null  float64
#  38  fourier_imag_8    19430 non-null  float64
#  39  fourier_imag_9    19430 non-null  float64
#  40  fourier_imag_10   19430 non-null  float64
#  41  fourier_mag_2     19430 non-null  float64
#  42  fourier_mag_3     19430 non-null  float64
#  43  fourier_mag_4     19430 non-null  float64
#  44  fourier_mag_5     19430 non-null  float64
#  45  fourier_mag_6     19430 non-null  float64
#  46  fourier_mag_7     19430 non-null  float64
#  47  fourier_mag_8     19430 non-null  float64
#  48  fourier_mag_9     19430 non-null  float64
#  49  fourier_mag_10    19430 non-null  float64
# dtypes: float64(50)
# memory usage: 7.4 MB
# None

# %%
#convert data to d matrix to use with xgb
enab_cat = False
dtrain = xgb.DMatrix(X_train, label=y_train, enable_categorical=False )
dtest = xgb.DMatrix(X_test, label=y_test, enable_categorical=False)

# %%
num_boosting_rounds = 20000
##### Implement initial training of the model   
learning_rate = 0.01
starting_tree_method = 'approx'
#metric can be mlogloss, auc, merror etc
metric = 'rmse'

base_params = {
    'objective': 'reg:squarederror',
    'eval_metric': metric,
    'scale_pos_weight': 2.0
}

params = {
    'tree_method': starting_tree_method
}

params.update(base_params)

# %%
#model = xgb.train(params=params, dtrain=dtrain, num_boost_round=num_boosting_rounds, evals=[(dtrain, 'train')], early_stopping_rounds=50)

# %%
##### CReate the objective function for optuna to tune tree parameters

def objective(trial):
    #print("Point 0")
    params = {
        'tree_method' : trial.suggest_categorical('tree_method', ['approx', 'hist']) , 
        'gamma': trial.suggest_float('gamma', 1e-2, 10),
        'max_depth': trial.suggest_int('max_depth', 3, 12),
        'eta': trial.suggest_float('eta', 0.001, 0.3, log=True),
        'min_child_weight': trial.suggest_float('min_child_weight', 1, 250),
        'subsample': trial.suggest_float('subsample', 0.1, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.5, 1.0),
        'lambda': trial.suggest_float('lambda', 0.001, 25), 
        'alpha': trial.suggest_float('alpha', 0.001, 10)
    }
    #'scale_pos_weight': trial.suggest_float('scale_pos_weight', min(buying_weight, selling_weight), max(buying_weight, selling_weight))
    params.update(base_params)
    #thresholds = [trial.suggest_float(f'threshold_{i}', 0.1, 0.9) for i in ]
    pruning_callback = optuna.integration.XGBoostPruningCallback(trial, f'test-{metric}')
    evals_result = {}
    #print("Point 1")
    #print(dtrain)
    xgb_model = xgb.train(params=params, dtrain=dtrain, num_boost_round=num_boosting_rounds, 
                          evals=[(dtest, 'test')],
                          early_stopping_rounds=50,
                          verbose_eval=False,
                          callbacks=[pruning_callback],
                          evals_result=evals_result
                        )
    #print("Point 2")
    preds = xgb_model.predict(dtest)
    rmse_buy = mean_squared_error(y_test['BuyPower'], preds[:, 0]) ** 0.5
    rmse_sell = mean_squared_error(y_test['SellPower'], preds[:, 1]) ** 0.5
    #rmse = np.sqrt(np.mean((preds - y_test.values) ** 2))
    rmse = (rmse_buy + rmse_sell) / 2
    #print("Point 3")
    print(f"Trial {trial.number}: Best iteration = {xgb_model.best_iteration}, test rmse = {rmse}")

    return rmse

# %%
study = optuna.create_study(direction='minimize') # for metric auc its maximuze, and for mlogloss its minimie
study.optimize(objective, n_trials=100)

# Get the best parameters
print(f" Best parameters: {study.best_params}")
print(f" Best Accuracy: {study.best_value}")
# Out:
# [I 2025-03-05 09:51:31,258] A new study created in memory with name: no-name-6d05402e-4b9f-4fae-bd42-50c242772108
# [I 2025-03-05 09:51:57,656] Trial 0 finished with value: 0.5560105601178513 and parameters: {'tree_method': 'approx', 'gamma': 1.1755704072360227, 'max_depth': 11, 'eta': 0.02023643342970164, 'min_child_weight': 175.3604693056249, 'subsample': 0.5528560467681598, 'colsample_bytree': 0.8057420903844192, 'lambda': 13.603901198165477, 'alpha': 7.188799630146756}. Best is trial 0 with value: 0.5560105601178513.
# Trial 0: Best iteration = 6872, test rmse = 0.5560105601178513
# [I 2025-03-05 09:52:02,767] Trial 1 finished with value: 0.6205851945069992 and parameters: {'tree_method': 'approx', 'gamma': 3.1126350673964476, 'max_depth': 5, 'eta': 0.03691030534149097, 'min_child_weight': 68.71393991850849, 'subsample': 0.44398358970511803, 'colsample_bytree': 0.9016773930425388, 'lambda': 20.814708620194235, 'alpha': 9.03580281046199}. Best is trial 0 with value: 0.5560105601178513.
# Trial 1: Best iteration = 2045, test rmse = 0.6205851945069992
# [I 2025-03-05 09:52:06,055] Trial 2 finished with value: 0.6455724745529354 and parameters: {'tree_method': 'approx', 'gamma': 6.762862891435771, 'max_depth': 5, 'eta': 0.010585065758596083, 'min_child_weight': 114.67364750014129, 'subsample': 0.7543770501832244, 'colsample_bytree': 0.6557613118668046, 'lambda': 11.280737598488955, 'alpha': 3.826836343735941}. Best is trial 0 with value: 0.5560105601178513.
# Trial 2: Best iteration = 1232, test rmse = 0.6455724745529354
# [I 2025-03-05 09:52:13,293] Trial 3 finished with value: 0.6155483731391094 and parameters: {'tree_method': 'hist', 'gamma': 3.9149474115980407, 'max_depth': 12, 'eta': 0.0054946279971658475, 'min_child_weight': 39.57926099917489, 'subsample': 0.876427974715985, 'colsample_bytree': 0.9848747345442526, 'lambda': 15.002022050189659, 'alpha': 9.171704769846311}. Best is trial 0 with value: 0.5560105601178513.
# Trial 3: Best iteration = 2069, test rmse = 0.6155483731391094
# [I 2025-03-05 09:52:14,485] Trial 4 finished with value: 0.6603761534192263 and parameters: {'tree_method': 'hist', 'gamma': 8.965733952892906, 'max_depth': 8, 'eta': 0.025177019629017784, 'min_child_weight': 119.24415201891291, 'subsample': 0.24144210432752758, 'colsample_bytree': 0.6649635068249284, 'lambda': 9.372393153226316, 'alpha': 8.336686367010907}. Best is trial 0 with value: 0.5560105601178513.
# [I 2025-03-05 09:52:14,498] Trial 5 pruned. Trial was pruned at iteration 0.
# Trial 4: Best iteration = 677, test rmse = 0.6603761534192263
# [I 2025-03-05 09:52:17,524] Trial 6 finished with value: 0.6164733233980979 and parameters: {'tree_method': 'approx', 'gamma': 2.823855685827866, 'max_depth': 4, 'eta': 0.11285191188289251, 'min_child_weight': 212.06526499142285, 'subsample': 0.39678064944270386, 'colsample_bytree': 0.6142387532520779, 'lambda': 12.456631117751627, 'alpha': 1.6647020392798302}. Best is trial 0 with value: 0.5560105601178513.
# [I 2025-03-05 09:52:17,530] Trial 7 pruned. Trial was pruned at iteration 0.
# Trial 6: Best iteration = 993, test rmse = 0.6164733233980979
# [I 2025-03-05 09:52:17,759] Trial 8 pruned. Trial was pruned at iteration 49.
# [I 2025-03-05 09:52:28,809] Trial 9 pruned. Trial was pruned at iteration 2120.
# [I 2025-03-05 09:52:28,850] Trial 10 pruned. Trial was pruned at iteration 0.
# [I 2025-03-05 09:52:28,907] Trial 11 pruned. Trial was pruned at iteration 0.
# [I 2025-03-05 09:52:29,520] Trial 12 finished with value: 0.5675816629454999 and parameters: {'tree_method': 'hist', 'gamma': 1.623783812086618, 'max_depth': 10, 'eta': 0.2867638663231071, 'min_child_weight': 1.4732060861671101, 'subsample': 0.9700265969130075, 'colsample_bytree': 0.8794520506859325, 'lambda': 17.426797235221308, 'alpha': 6.8127243835455396}. Best is trial 0 with value: 0.5560105601178513.
# Trial 12: Best iteration = 207, test rmse = 0.5675816629454999
# [I 2025-03-05 09:52:31,389] Trial 13 finished with value: 0.5715916109106063 and parameters: {'tree_method': 'hist', 'gamma': 1.578805241533618, 'max_depth': 10, 'eta': 0.2827367695499147, 'min_child_weight': 173.5770134170779, 'subsample': 0.6887728748746849, 'colsample_bytree': 0.865164332297595, 'lambda': 18.610839468342924, 'alpha': 6.764084411563583}. Best is trial 0 with value: 0.5560105601178513.
# Trial 13: Best iteration = 720, test rmse = 0.5715916109106063
# [I 2025-03-05 09:52:31,755] Trial 14 finished with value: 0.5600892959962196 and parameters: {'tree_method': 'hist', 'gamma': 1.3793250328066256, 'max_depth': 10, 'eta': 0.28890613775874296, 'min_child_weight': 5.729825633387037, 'subsample': 0.995405074438767, 'colsample_bytree': 0.7383489321440089, 'lambda': 3.815819071666933, 'alpha': 5.2356163415772}. Best is trial 0 with value: 0.5560105601178513.
# Trial 14: Best iteration = 70, test rmse = 0.5600892959962196
# [I 2025-03-05 09:52:35,409] Trial 15 finished with value: 0.5397978190859224 and parameters: {'tree_method': 'hist', 'gamma': 0.9073880072390131, 'max_depth': 10, 'eta': 0.10481946131975066, 'min_child_weight': 148.61709799149978, 'subsample': 0.7863159777638584, 'colsample_bytree': 0.7208936547628096, 'lambda': 4.042658290629006, 'alpha': 5.328270408873328}. Best is trial 15 with value: 0.5397978190859224.
# Trial 15: Best iteration = 1260, test rmse = 0.5397978190859224
# [I 2025-03-05 09:52:35,792] Trial 16 pruned. Trial was pruned at iteration 122.
# [I 2025-03-05 09:52:45,081] Trial 17 finished with value: 0.5031884390943875 and parameters: {'tree_method': 'approx', 'gamma': 0.5004569947423265, 'max_depth': 11, 'eta': 0.1117678678427131, 'min_child_weight': 194.2225444469863, 'subsample': 0.613320621535536, 'colsample_bytree': 0.7956906263368045, 'lambda': 5.240884702680176, 'alpha': 5.167035263505248}. Best is trial 17 with value: 0.5031884390943875.
# Trial 17: Best iteration = 1664, test rmse = 0.5031884390943875
# [I 2025-03-05 09:52:56,507] Trial 18 finished with value: 0.45216360043937864 and parameters: {'tree_method': 'hist', 'gamma': 0.15950169244500334, 'max_depth': 9, 'eta': 0.11374178160406756, 'min_child_weight': 216.53667930403273, 'subsample': 0.6211250644642793, 'colsample_bytree': 0.7031891880201654, 'lambda': 0.8148478581536187, 'alpha': 0.6831345026425986}. Best is trial 18 with value: 0.45216360043937864.
# [I 2025-03-05 09:52:56,541] Trial 19 pruned. Trial was pruned at iteration 0.
# [I 2025-03-05 09:52:56,572] Trial 20 pruned. Trial was pruned at iteration 0.
# Trial 18: Best iteration = 1897, test rmse = 0.45216360043937864
# [I 2025-03-05 09:53:01,629] Trial 21 finished with value: 0.5233696136479814 and parameters: {'tree_method': 'hist', 'gamma': 0.7339850672421853, 'max_depth': 11, 'eta': 0.12285093193513298, 'min_child_weight': 206.11599422560184, 'subsample': 0.6552472200470421, 'colsample_bytree': 0.7160361095912053, 'lambda': 5.66296310393871, 'alpha': 4.980884351997231}. Best is trial 18 with value: 0.45216360043937864.
# Trial 21: Best iteration = 1460, test rmse = 0.5233696136479814
# [I 2025-03-05 09:53:09,329] Trial 22 finished with value: 0.48115586838289703 and parameters: {'tree_method': 'hist', 'gamma': 0.35420667306070497, 'max_depth': 11, 'eta': 0.16463283898737477, 'min_child_weight': 207.11010207318526, 'subsample': 0.6090335517294098, 'colsample_bytree': 0.7730336244673054, 'lambda': 7.110560616591423, 'alpha': 2.461728476677534}. Best is trial 18 with value: 0.45216360043937864.
# [I 2025-03-05 09:53:09,359] Trial 23 pruned. Trial was pruned at iteration 0.
# Trial 22: Best iteration = 1887, test rmse = 0.48115586838289703
# [I 2025-03-05 09:53:09,609] Trial 24 pruned. Trial was pruned at iteration 29.
# [I 2025-03-05 09:53:09,631] Trial 25 pruned. Trial was pruned at iteration 0.
# [I 2025-03-05 09:53:16,236] Trial 26 finished with value: 0.5020278217159646 and parameters: {'tree_method': 'approx', 'gamma': 0.6458096897244393, 'max_depth': 11, 'eta': 0.1928274672542672, 'min_child_weight': 188.38463203000742, 'subsample': 0.6254118433444421, 'colsample_bytree': 0.9357055414877833, 'lambda': 2.1350631196452703, 'alpha': 2.5234548340050766}. Best is trial 18 with value: 0.45216360043937864.
# Trial 26: Best iteration = 1647, test rmse = 0.5020278217159646
# [I 2025-03-05 09:53:16,711] Trial 27 pruned. Trial was pruned at iteration 66.
# [I 2025-03-05 09:53:16,751] Trial 28 pruned. Trial was pruned at iteration 0.
# [I 2025-03-05 09:53:20,103] Trial 29 pruned. Trial was pruned at iteration 770.
# [I 2025-03-05 09:53:20,133] Trial 30 pruned. Trial was pruned at iteration 0.
# [I 2025-03-05 09:53:25,511] Trial 31 pruned. Trial was pruned at iteration 1310.
# [I 2025-03-05 09:53:25,542] Trial 32 pruned. Trial was pruned at iteration 0.
# [I 2025-03-05 09:53:25,906] Trial 33 pruned. Trial was pruned at iteration 36.
# [I 2025-03-05 09:53:49,185] Trial 34 finished with value: 0.4129444657535727 and parameters: {'tree_method': 'approx', 'gamma': 0.044583640789922455, 'max_depth': 12, 'eta': 0.08415891673918872, 'min_child_weight': 136.36846358046986, 'subsample': 0.7594498252414573, 'colsample_bytree': 0.8412823228736555, 'lambda': 2.564278213869014, 'alpha': 3.1619080567631346}. Best is trial 34 with value: 0.4129444657535727.
# Trial 34: Best iteration = 3006, test rmse = 0.4129444657535727
# [I 2025-03-05 09:53:52,669] Trial 35 pruned. Trial was pruned at iteration 728.
# [I 2025-03-05 09:53:52,703] Trial 36 pruned. Trial was pruned at iteration 0.
# [I 2025-03-05 09:53:52,740] Trial 37 pruned. Trial was pruned at iteration 0.
# [I 2025-03-05 09:53:52,767] Trial 38 pruned. Trial was pruned at iteration 0.
# [I 2025-03-05 09:53:52,802] Trial 39 pruned. Trial was pruned at iteration 0.
# [I 2025-03-05 09:53:56,225] Trial 40 pruned. Trial was pruned at iteration 728.
# [I 2025-03-05 09:53:56,277] Trial 41 pruned. Trial was pruned at iteration 1.
# [I 2025-03-05 09:54:01,681] Trial 42 finished with value: 0.5101015600652081 and parameters: {'tree_method': 'approx', 'gamma': 0.529034059903142, 'max_depth': 12, 'eta': 0.21354055167115654, 'min_child_weight': 198.09838684844064, 'subsample': 0.6270167867459239, 'colsample_bytree': 0.8176815328982466, 'lambda': 5.113124348697044, 'alpha': 5.750989412710721}. Best is trial 34 with value: 0.4129444657535727.
# Trial 42: Best iteration = 1116, test rmse = 0.5101015600652081
# [I 2025-03-05 09:54:06,519] Trial 43 pruned. Trial was pruned at iteration 1043.
# [I 2025-03-05 09:54:06,545] Trial 44 pruned. Trial was pruned at iteration 0.
# [I 2025-03-05 09:54:06,566] Trial 45 pruned. Trial was pruned at iteration 0.
# [I 2025-03-05 09:54:31,494] Trial 46 finished with value: 0.42670122778911934 and parameters: {'tree_method': 'approx', 'gamma': 0.014891395245848704, 'max_depth': 12, 'eta': 0.215301824147844, 'min_child_weight': 205.4786117658883, 'subsample': 0.6017531381038618, 'colsample_bytree': 0.8630886102645587, 'lambda': 3.2463255679814282, 'alpha': 2.410966229835509}. Best is trial 34 with value: 0.4129444657535727.
# Trial 46: Best iteration = 2429, test rmse = 0.42670122778911934
# [I 2025-03-05 09:54:32,242] Trial 47 pruned. Trial was pruned at iteration 207.
# [I 2025-03-05 09:54:53,398] Trial 48 finished with value: 0.4253525829580549 and parameters: {'tree_method': 'approx', 'gamma': 0.01488447329715827, 'max_depth': 12, 'eta': 0.2387222725450511, 'min_child_weight': 208.17774732959015, 'subsample': 0.6666061704792746, 'colsample_bytree': 0.9603734410764079, 'lambda': 1.6015975982355297, 'alpha': 1.2026585596279338}. Best is trial 34 with value: 0.4129444657535727.
# [I 2025-03-05 09:54:53,476] Trial 49 pruned. Trial was pruned at iteration 10.
# [I 2025-03-05 09:54:53,499] Trial 50 pruned. Trial was pruned at iteration 0.
# Trial 48: Best iteration = 2229, test rmse = 0.4253525829580549
# [I 2025-03-05 09:54:55,521] Trial 51 pruned. Trial was pruned at iteration 258.
# [I 2025-03-05 09:55:19,074] Trial 52 finished with value: 0.4237536917437833 and parameters: {'tree_method': 'approx', 'gamma': 0.0263802505920656, 'max_depth': 11, 'eta': 0.13897836510249495, 'min_child_weight': 179.61946208618534, 'subsample': 0.5940669033053873, 'colsample_bytree': 0.9741690030710929, 'lambda': 3.690928843071762, 'alpha': 1.4782372390542813}. Best is trial 34 with value: 0.4129444657535727.
# Trial 52: Best iteration = 1870, test rmse = 0.4237536917437833
# [I 2025-03-05 09:55:46,252] Trial 53 finished with value: 0.4013332275648481 and parameters: {'tree_method': 'approx', 'gamma': 0.01065800546467793, 'max_depth': 10, 'eta': 0.1394889206682504, 'min_child_weight': 176.77611674394547, 'subsample': 0.7047628931542494, 'colsample_bytree': 0.9966322863195164, 'lambda': 4.032262320175688, 'alpha': 1.5223773036096937}. Best is trial 53 with value: 0.4013332275648481.
# Trial 53: Best iteration = 2474, test rmse = 0.4013332275648481
# [I 2025-03-05 09:55:47,466] Trial 54 pruned. Trial was pruned at iteration 88.
# [I 2025-03-05 09:55:47,513] Trial 55 pruned. Trial was pruned at iteration 1.
# [I 2025-03-05 09:55:48,933] Trial 56 finished with value: 0.5335796123351983 and parameters: {'tree_method': 'approx', 'gamma': 0.9888212610304131, 'max_depth': 10, 'eta': 0.2979778865103907, 'min_child_weight': 131.17280024649628, 'subsample': 0.7901660425564814, 'colsample_bytree': 0.9774495155737771, 'lambda': 3.085726272668068, 'alpha': 1.1692713375453807}. Best is trial 53 with value: 0.4013332275648481.
# Trial 56: Best iteration = 197, test rmse = 0.5335796123351983
# [I 2025-03-05 09:55:51,853] Trial 57 finished with value: 0.4968416707112381 and parameters: {'tree_method': 'approx', 'gamma': 0.3629500193322728, 'max_depth': 10, 'eta': 0.2362871736916332, 'min_child_weight': 155.3348178235696, 'subsample': 0.9333383335762689, 'colsample_bytree': 0.9603825928854073, 'lambda': 6.317515583014102, 'alpha': 1.778370839666733}. Best is trial 53 with value: 0.4013332275648481.
# [I 2025-03-05 09:55:51,880] Trial 58 pruned. Trial was pruned at iteration 0.
# [I 2025-03-05 09:55:51,915] Trial 59 pruned. Trial was pruned at iteration 0.
# Trial 57: Best iteration = 679, test rmse = 0.4968416707112381
# [I 2025-03-05 09:55:52,698] Trial 60 pruned. Trial was pruned at iteration 77.
# [I 2025-03-05 09:55:52,743] Trial 61 pruned. Trial was pruned at iteration 0.
# [I 2025-03-05 09:55:55,575] Trial 62 pruned. Trial was pruned at iteration 328.
# [I 2025-03-05 09:55:56,245] Trial 63 pruned. Trial was pruned at iteration 85.
# [I 2025-03-05 09:55:56,284] Trial 64 pruned. Trial was pruned at iteration 0.
# [I 2025-03-05 09:55:56,591] Trial 65 pruned. Trial was pruned at iteration 26.
# [I 2025-03-05 09:55:56,636] Trial 66 pruned. Trial was pruned at iteration 0.
# [I 2025-03-05 09:55:56,671] Trial 67 pruned. Trial was pruned at iteration 0.
# [I 2025-03-05 09:55:56,716] Trial 68 pruned. Trial was pruned at iteration 0.
# [I 2025-03-05 09:55:56,780] Trial 69 pruned. Trial was pruned at iteration 4.
# [I 2025-03-05 09:56:00,805] Trial 70 finished with value: 0.5033048281295691 and parameters: {'tree_method': 'hist', 'gamma': 0.6990077410186866, 'max_depth': 10, 'eta': 0.18715449886302837, 'min_child_weight': 204.58222555530693, 'subsample': 0.6392939007016925, 'colsample_bytree': 0.9671681078413243, 'lambda': 10.11588960749257, 'alpha': 1.1567755287891244}. Best is trial 53 with value: 0.4013332275648481.
# Trial 70: Best iteration = 996, test rmse = 0.5033048281295691
# [I 2025-03-05 09:56:03,671] Trial 71 finished with value: 0.49520902274410483 and parameters: {'tree_method': 'approx', 'gamma': 0.37885704957785243, 'max_depth': 9, 'eta': 0.25140854202825885, 'min_child_weight': 153.15376069050956, 'subsample': 0.940297414212208, 'colsample_bytree': 0.950250763539661, 'lambda': 6.149059474566187, 'alpha': 1.732342933106737}. Best is trial 53 with value: 0.4013332275648481.
# Trial 71: Best iteration = 696, test rmse = 0.49520902274410483
# [I 2025-03-05 09:56:08,549] Trial 72 finished with value: 0.4789320043808958 and parameters: {'tree_method': 'approx', 'gamma': 0.33311300876229555, 'max_depth': 9, 'eta': 0.24254506180776708, 'min_child_weight': 142.57487018721503, 'subsample': 0.8061056185462813, 'colsample_bytree': 0.9201990141681056, 'lambda': 6.531125694588168, 'alpha': 2.255346675455039}. Best is trial 53 with value: 0.4013332275648481.
# Trial 72: Best iteration = 1273, test rmse = 0.4789320043808958
# [I 2025-03-05 09:56:09,631] Trial 73 pruned. Trial was pruned at iteration 156.
# [I 2025-03-05 09:56:29,703] Trial 74 finished with value: 0.40722555998751697 and parameters: {'tree_method': 'approx', 'gamma': 0.014235397148636295, 'max_depth': 7, 'eta': 0.15963139851829214, 'min_child_weight': 140.28960600198997, 'subsample': 0.7480079811397169, 'colsample_bytree': 0.9096573768179721, 'lambda': 7.236427922581823, 'alpha': 2.9645339580450454}. Best is trial 53 with value: 0.4013332275648481.
# Trial 74: Best iteration = 2520, test rmse = 0.40722555998751697
# [I 2025-03-05 09:56:30,684] Trial 75 pruned. Trial was pruned at iteration 166.
# [I 2025-03-05 09:56:31,233] Trial 76 pruned. Trial was pruned at iteration 59.
# [I 2025-03-05 09:56:31,258] Trial 77 pruned. Trial was pruned at iteration 0.
# [I 2025-03-05 09:56:31,410] Trial 78 pruned. Trial was pruned at iteration 13.
# [I 2025-03-05 09:56:31,441] Trial 79 pruned. Trial was pruned at iteration 0.
# [I 2025-03-05 09:56:31,468] Trial 80 pruned. Trial was pruned at iteration 0.
# [I 2025-03-05 09:56:36,288] Trial 81 finished with value: 0.47949712274602646 and parameters: {'tree_method': 'approx', 'gamma': 0.38473886791024425, 'max_depth': 11, 'eta': 0.1723848661000581, 'min_child_weight': 133.07475983038972, 'subsample': 0.7146352057585428, 'colsample_bytree': 0.8770673660668522, 'lambda': 7.696726887425883, 'alpha': 2.490790036469867}. Best is trial 53 with value: 0.4013332275648481.
# [I 2025-03-05 09:56:36,319] Trial 82 pruned. Trial was pruned at iteration 0.
# [I 2025-03-05 09:56:36,354] Trial 83 pruned. Trial was pruned at iteration 0.
# Trial 81: Best iteration = 812, test rmse = 0.47949712274602646
# [I 2025-03-05 09:56:41,092] Trial 84 finished with value: 0.4796820558560308 and parameters: {'tree_method': 'approx', 'gamma': 0.35483787382688214, 'max_depth': 10, 'eta': 0.20825199339290923, 'min_child_weight': 145.52837949274925, 'subsample': 0.7605489567833613, 'colsample_bytree': 0.9021106626872383, 'lambda': 9.794473560697048, 'alpha': 4.215796542616292}. Best is trial 53 with value: 0.4013332275648481.
# Trial 84: Best iteration = 1081, test rmse = 0.4796820558560308
# [I 2025-03-05 09:56:42,087] Trial 85 pruned. Trial was pruned at iteration 118.
# [I 2025-03-05 09:56:42,121] Trial 86 pruned. Trial was pruned at iteration 0.
# [I 2025-03-05 09:56:42,155] Trial 87 pruned. Trial was pruned at iteration 0.
# [I 2025-03-05 09:56:42,188] Trial 88 pruned. Trial was pruned at iteration 0.
# [I 2025-03-05 09:56:44,375] Trial 89 pruned. Trial was pruned at iteration 247.
# [I 2025-03-05 09:56:44,410] Trial 90 pruned. Trial was pruned at iteration 0.
# [I 2025-03-05 09:56:48,599] Trial 91 pruned. Trial was pruned at iteration 1047.
# [I 2025-03-05 09:56:49,623] Trial 92 pruned. Trial was pruned at iteration 167.
# [I 2025-03-05 09:56:49,675] Trial 93 pruned. Trial was pruned at iteration 1.
# [I 2025-03-05 09:56:50,442] Trial 94 pruned. Trial was pruned at iteration 84.
# [I 2025-03-05 09:56:50,472] Trial 95 pruned. Trial was pruned at iteration 0.
# [I 2025-03-05 09:56:54,237] Trial 96 finished with value: 0.49415037265592515 and parameters: {'tree_method': 'approx', 'gamma': 0.5288351348791397, 'max_depth': 9, 'eta': 0.2591047519429265, 'min_child_weight': 184.7973182739587, 'subsample': 0.6958542037969632, 'colsample_bytree': 0.9538426966200888, 'lambda': 8.085239920108345, 'alpha': 0.8163148438737681}. Best is trial 53 with value: 0.4013332275648481.
# [I 2025-03-05 09:56:54,272] Trial 97 pruned. Trial was pruned at iteration 0.
# [I 2025-03-05 09:56:54,295] Trial 98 pruned. Trial was pruned at iteration 0.
# [I 2025-03-05 09:56:54,329] Trial 99 pruned. Trial was pruned at iteration 0.
# Trial 96: Best iteration = 651, test rmse = 0.49415037265592515
#  Best parameters: {'tree_method': 'approx', 'gamma': 0.01065800546467793, 'max_depth': 10, 'eta': 0.1394889206682504, 'min_child_weight': 176.77611674394547, 'subsample': 0.7047628931542494, 'colsample_bytree': 0.9966322863195164, 'lambda': 4.032262320175688, 'alpha': 1.5223773036096937}
#  Best Accuracy: 0.4013332275648481

# %%
best_params = study.best_params
#best_params
for trial in study.trials:
    print(f"Trial {trial.number}: Best iteration = {trial.user_attrs.get('best_iteration')}, best test rmse = {trial.value}")
# Out:
# Trial 0: Best iteration = None, best test rmse = 0.5560105601178513
# Trial 1: Best iteration = None, best test rmse = 0.6205851945069992
# Trial 2: Best iteration = None, best test rmse = 0.6455724745529354
# Trial 3: Best iteration = None, best test rmse = 0.6155483731391094
# Trial 4: Best iteration = None, best test rmse = 0.6603761534192263
# Trial 5: Best iteration = None, best test rmse = 0.6692323263134818
# Trial 6: Best iteration = None, best test rmse = 0.6164733233980979
# Trial 7: Best iteration = None, best test rmse = 0.6692017387789672
# Trial 8: Best iteration = None, best test rmse = 0.6552255333262468
# Trial 9: Best iteration = None, best test rmse = 0.5853648518092269
# Trial 10: Best iteration = None, best test rmse = 0.6692765518392534
# Trial 11: Best iteration = None, best test rmse = 0.6690724088809408
# Trial 12: Best iteration = None, best test rmse = 0.5675816629454999
# Trial 13: Best iteration = None, best test rmse = 0.5715916109106063
# Trial 14: Best iteration = None, best test rmse = 0.5600892959962196
# Trial 15: Best iteration = None, best test rmse = 0.5397978190859224
# Trial 16: Best iteration = None, best test rmse = 0.6370081040691115
# Trial 17: Best iteration = None, best test rmse = 0.5031884390943875
# Trial 18: Best iteration = None, best test rmse = 0.45216360043937864
# Trial 19: Best iteration = None, best test rmse = 0.6679391863713048
# Trial 20: Best iteration = None, best test rmse = 0.668178113911991
# Trial 21: Best iteration = None, best test rmse = 0.5233696136479814
# Trial 22: Best iteration = None, best test rmse = 0.48115586838289703
# Trial 23: Best iteration = None, best test rmse = 0.6680178625378201
# Trial 24: Best iteration = None, best test rmse = 0.6296307110036146
# Trial 25: Best iteration = None, best test rmse = 0.6682082137201917
# Trial 26: Best iteration = None, best test rmse = 0.5020278217159646
# Trial 27: Best iteration = None, best test rmse = 0.6029158035117821
# Trial 28: Best iteration = None, best test rmse = 0.6684510754019002
# Trial 29: Best iteration = None, best test rmse = 0.5505199785413672
# Trial 30: Best iteration = None, best test rmse = 0.6682638294475505
# Trial 31: Best iteration = None, best test rmse = 0.5203106979512944
# Trial 32: Best iteration = None, best test rmse = 0.6682846070760443
# Trial 33: Best iteration = None, best test rmse = 0.6222167955772158
# Trial 34: Best iteration = None, best test rmse = 0.4129444657535727
# Trial 35: Best iteration = None, best test rmse = 0.5522284402252072
# Trial 36: Best iteration = None, best test rmse = 0.6683434245652076
# Trial 37: Best iteration = None, best test rmse = 0.6673518697214623
# Trial 38: Best iteration = None, best test rmse = 0.668444398062092
# Trial 39: Best iteration = None, best test rmse = 0.669122899673927
# Trial 40: Best iteration = None, best test rmse = 0.5482156000545609
# Trial 41: Best iteration = None, best test rmse = 0.6638627874310469
# Trial 42: Best iteration = None, best test rmse = 0.5101015600652081
# Trial 43: Best iteration = None, best test rmse = 0.5245390083253952
# Trial 44: Best iteration = None, best test rmse = 0.6684296810785076
# Trial 45: Best iteration = None, best test rmse = 0.6682667021112788
# Trial 46: Best iteration = None, best test rmse = 0.42670122778911934
# Trial 47: Best iteration = None, best test rmse = 0.5572594780872288
# Trial 48: Best iteration = None, best test rmse = 0.4253525829580549
# Trial 49: Best iteration = None, best test rmse = 0.6453671656874387
# Trial 50: Best iteration = None, best test rmse = 0.6692705790152994
# Trial 51: Best iteration = None, best test rmse = 0.5478312675518131
# Trial 52: Best iteration = None, best test rmse = 0.4237536917437833
# Trial 53: Best iteration = None, best test rmse = 0.4013332275648481
# Trial 54: Best iteration = None, best test rmse = 0.5763991283020866
# Trial 55: Best iteration = None, best test rmse = 0.6634841379183799
# Trial 56: Best iteration = None, best test rmse = 0.5335796123351983
# Trial 57: Best iteration = None, best test rmse = 0.4968416707112381
# Trial 58: Best iteration = None, best test rmse = 0.666793018772758
# Trial 59: Best iteration = None, best test rmse = 0.6676038014712639
# Trial 60: Best iteration = None, best test rmse = 0.5800253303544044
# Trial 61: Best iteration = None, best test rmse = 0.6672757469643176
# Trial 62: Best iteration = None, best test rmse = 0.527533386615897
# Trial 63: Best iteration = None, best test rmse = 0.5745057137543184
# Trial 64: Best iteration = None, best test rmse = 0.6669544950179582
# Trial 65: Best iteration = None, best test rmse = 0.6213852616186688
# Trial 66: Best iteration = None, best test rmse = 0.6668949967933642
# Trial 67: Best iteration = None, best test rmse = 0.6689846492454732
# Trial 68: Best iteration = None, best test rmse = 0.6691737053666772
# Trial 69: Best iteration = None, best test rmse = 0.6548223195183838
# Trial 70: Best iteration = None, best test rmse = 0.5033048281295691
# Trial 71: Best iteration = None, best test rmse = 0.49520902274410483
# Trial 72: Best iteration = None, best test rmse = 0.4789320043808958
# Trial 73: Best iteration = None, best test rmse = 0.5450716996235658
# Trial 74: Best iteration = None, best test rmse = 0.40722555998751697
# Trial 75: Best iteration = None, best test rmse = 0.5393562700387866
# Trial 76: Best iteration = None, best test rmse = 0.5868238145306163
# Trial 77: Best iteration = None, best test rmse = 0.6669436550635129
# Trial 78: Best iteration = None, best test rmse = 0.6359190766269546
# Trial 79: Best iteration = None, best test rmse = 0.6692521034984941
# Trial 80: Best iteration = None, best test rmse = 0.6668151584252413
# Trial 81: Best iteration = None, best test rmse = 0.47949712274602646
# Trial 82: Best iteration = None, best test rmse = 0.6654196446787439
# Trial 83: Best iteration = None, best test rmse = 0.6653032741370684
# Trial 84: Best iteration = None, best test rmse = 0.4796820558560308
# Trial 85: Best iteration = None, best test rmse = 0.5571984790882331
# Trial 86: Best iteration = None, best test rmse = 0.6672217869963616
# Trial 87: Best iteration = None, best test rmse = 0.6650747887850378
# Trial 88: Best iteration = None, best test rmse = 0.6661523292057049
# Trial 89: Best iteration = None, best test rmse = 0.5193354538606451
# Trial 90: Best iteration = None, best test rmse = 0.6672377423239488
# Trial 91: Best iteration = None, best test rmse = 0.4900168592880553
# Trial 92: Best iteration = None, best test rmse = 0.5371492907512777
# Trial 93: Best iteration = None, best test rmse = 0.6608212353107078
# Trial 94: Best iteration = None, best test rmse = 0.5678041422867518
# Trial 95: Best iteration = None, best test rmse = 0.6658295696205452
# Trial 96: Best iteration = None, best test rmse = 0.49415037265592515
# Trial 97: Best iteration = None, best test rmse = 0.6692433865094649
# Trial 98: Best iteration = None, best test rmse = 0.6665531188591373
# Trial 99: Best iteration = None, best test rmse = 0.6679152883925191

# %%
low_learning_rate = 0.0326
num_boosting_rounds = 20000
params = {}
params.update(base_params)
params.update(study.best_params)
#params['learning_rate'] = low_learning_rate
params['scale_pos_weight']
# Out:
# 2.0

# %%
model_stage2 = xgb.train(params=params, dtrain=dtrain, num_boost_round=num_boosting_rounds, 
                         evals=[(dtrain, 'train'), (dtest, 'test')], 
                         early_stopping_rounds=50,
                         verbose_eval=500
                )
# Out:
# [0]	train-rmse:0.64652	test-rmse:0.66555
# [500]	train-rmse:0.19209	test-rmse:0.44844
# [1000]	train-rmse:0.10178	test-rmse:0.41634
# [1500]	train-rmse:0.07645	test-rmse:0.40833
# [2000]	train-rmse:0.07042	test-rmse:0.40656
# [2500]	train-rmse:0.06791	test-rmse:0.40565
# [2764]	train-rmse:0.06703	test-rmse:0.40551

# %%
model_stage2.best_iteration # got the best iteration from stage 2 training
# Out:
# 2714

# %%
def learning_rate_decay(epoch):
    return 0.1 * (0.99 ** epoch)

# %% [markdown]
# #### Set the num boosting

# %%
num_boosting_rounds = model_stage2.best_iteration

# %%
import math

def cosine_decay(current_round, num_boost_round):
    initial_lr = 0.2  # Starting learning rate
    final_lr = 0.01  # Minimum learning rate
    return final_lr + (initial_lr - final_lr) * (1 + math.cos(math.pi * current_round / num_boost_round)) / 2

# %%
model_final = xgb.train(params=params, 
                        dtrain=dtrain,
                        num_boost_round = num_boosting_rounds,
                        evals=[(dtest, 'test')],
                        callbacks=[xgb.callback.LearningRateScheduler(lambda current_round: cosine_decay(current_round, num_boosting_rounds))],
                        verbose_eval=100)
# Out:
# [0]	test-rmse:0.66555
# [100]	test-rmse:0.53753
# [200]	test-rmse:0.49111
# [300]	test-rmse:0.46414
# [400]	test-rmse:0.44643
# [500]	test-rmse:0.43642
# [600]	test-rmse:0.42903
# [700]	test-rmse:0.42361
# [800]	test-rmse:0.41980
# [900]	test-rmse:0.41726
# [1000]	test-rmse:0.41576
# [1100]	test-rmse:0.41484
# [1200]	test-rmse:0.41425
# [1300]	test-rmse:0.41401
# [1400]	test-rmse:0.41362
# [1500]	test-rmse:0.41344
# [1600]	test-rmse:0.41322
# [1700]	test-rmse:0.41310
# [1800]	test-rmse:0.41300
# [1900]	test-rmse:0.41282
# [2000]	test-rmse:0.41274
# [2100]	test-rmse:0.41266
# [2200]	test-rmse:0.41256
# [2300]	test-rmse:0.41243
# [2400]	test-rmse:0.41236
# [2500]	test-rmse:0.41232
# [2600]	test-rmse:0.41229
# [2700]	test-rmse:0.41212
# [2800]	test-rmse:0.41210
# [2900]	test-rmse:0.41203
# [3000]	test-rmse:0.41201
# [3100]	test-rmse:0.41201
# [3200]	test-rmse:0.41200
# [3300]	test-rmse:0.41198
# [3400]	test-rmse:0.41195
# [3500]	test-rmse:0.41194
# [3600]	test-rmse:0.41188
# [3700]	test-rmse:0.41183
# [3800]	test-rmse:0.41172
# [3900]	test-rmse:0.41170
# [4000]	test-rmse:0.41162
# [4100]	test-rmse:0.41163
# [4200]	test-rmse:0.41162
# [4300]	test-rmse:0.41160
# [4400]	test-rmse:0.41153
# [4500]	test-rmse:0.41151
# [4600]	test-rmse:0.41154
# [4700]	test-rmse:0.41149
# [4800]	test-rmse:0.41153
# [4900]	test-rmse:0.41148
# [5000]	test-rmse:0.41147
# [5100]	test-rmse:0.41144
# [5200]	test-rmse:0.41143
# [5300]	test-rmse:0.41138
# [5400]	test-rmse:0.41139
# [5500]	test-rmse:0.41137
# [5600]	test-rmse:0.41138
# [5700]	test-rmse:0.41139
# [5800]	test-rmse:0.41140
# [5900]	test-rmse:0.41138
# [6000]	test-rmse:0.41140
# [6100]	test-rmse:0.41142
# [6200]	test-rmse:0.41137
# [6300]	test-rmse:0.41140
# [6400]	test-rmse:0.41141
# [6500]	test-rmse:0.41141
# [6600]	test-rmse:0.41143
# [6700]	test-rmse:0.41144
# [6800]	test-rmse:0.41147
# [6900]	test-rmse:0.41146
# [7000]	test-rmse:0.41144
# [7100]	test-rmse:0.41143
# [7200]	test-rmse:0.41146
# [7300]	test-rmse:0.41144
# [7400]	test-rmse:0.41143
# [7500]	test-rmse:0.41145
# [7600]	test-rmse:0.41143
# [7700]	test-rmse:0.41143
# [7800]	test-rmse:0.41144
# [7900]	test-rmse:0.41142
# [8000]	test-rmse:0.41140
# [8100]	test-rmse:0.41135
# [8200]	test-rmse:0.41134
# [8300]	test-rmse:0.41135
# [8400]	test-rmse:0.41136
# [8500]	test-rmse:0.41133
# [8600]	test-rmse:0.41134
# [8700]	test-rmse:0.41135
# [8800]	test-rmse:0.41134
# [8900]	test-rmse:0.41136
# [9000]	test-rmse:0.41134
# [9100]	test-rmse:0.41134
# [9200]	test-rmse:0.41135
# [9300]	test-rmse:0.41133
# [9400]	test-rmse:0.41132
# [9500]	test-rmse:0.41132
# [9600]	test-rmse:0.41130
# [9700]	test-rmse:0.41129
# [9800]	test-rmse:0.41128
# [9900]	test-rmse:0.41128
# [10000]	test-rmse:0.41127
# [10100]	test-rmse:0.41129
# [10200]	test-rmse:0.41127
# [10300]	test-rmse:0.41127
# [10400]	test-rmse:0.41127
# [10500]	test-rmse:0.41128
# [10600]	test-rmse:0.41125
# [10700]	test-rmse:0.41125
# [10800]	test-rmse:0.41124
# [10900]	test-rmse:0.41123
# [11000]	test-rmse:0.41122
# [11100]	test-rmse:0.41121
# [11200]	test-rmse:0.41124
# [11300]	test-rmse:0.41122
# [11400]	test-rmse:0.41121
# [11500]	test-rmse:0.41121
# [11600]	test-rmse:0.41120
# [11700]	test-rmse:0.41120
# [11800]	test-rmse:0.41121
# [11900]	test-rmse:0.41122
# [12000]	test-rmse:0.41122
# [12100]	test-rmse:0.41121
# [12200]	test-rmse:0.41120
# [12300]	test-rmse:0.41119
# [12400]	test-rmse:0.41119
# [12500]	test-rmse:0.41117
# [12600]	test-rmse:0.41119
# [12700]	test-rmse:0.41119
# [12800]	test-rmse:0.41118
# [12900]	test-rmse:0.41118
# [13000]	test-rmse:0.41117
# [13100]	test-rmse:0.41118
# [13200]	test-rmse:0.41117
# [13300]	test-rmse:0.41117
# [13400]	test-rmse:0.41117
# [13500]	test-rmse:0.41116
# [13600]	test-rmse:0.41116
# [13700]	test-rmse:0.41115
# [13800]	test-rmse:0.41115
# [13900]	test-rmse:0.41115
# [14000]	test-rmse:0.41115
# [14100]	test-rmse:0.41115
# [14200]	test-rmse:0.41114
# [14300]	test-rmse:0.41114
# [14400]	test-rmse:0.41115
# [14500]	test-rmse:0.41114
# [14600]	test-rmse:0.41114
# [14700]	test-rmse:0.41115
# [14800]	test-rmse:0.41115
# [14900]	test-rmse:0.41114
# [15000]	test-rmse:0.41114
# [15100]	test-rmse:0.41115
# [15200]	test-rmse:0.41114
# [15300]	test-rmse:0.41114
# [15400]	test-rmse:0.41114
# [15500]	test-rmse:0.41114
# [15600]	test-rmse:0.41114
# [15700]	test-rmse:0.41113
# [15800]	test-rmse:0.41113
# [15900]	test-rmse:0.41112
# [16000]	test-rmse:0.41112
# [16100]	test-rmse:0.41112
# [16200]	test-rmse:0.41112
# [16300]	test-rmse:0.41113
# [16400]	test-rmse:0.41113
# [16500]	test-rmse:0.41113
# [16600]	test-rmse:0.41113
# [16700]	test-rmse:0.41113
# [16800]	test-rmse:0.41112
# [16900]	test-rmse:0.41112
# [17000]	test-rmse:0.41112
# [17100]	test-rmse:0.41112
# [17200]	test-rmse:0.41111
# [17300]	test-rmse:0.41111
# [17400]	test-rmse:0.41111
# [17500]	test-rmse:0.41111
# [17600]	test-rmse:0.41111
# [17700]	test-rmse:0.41111
# [17800]	test-rmse:0.41111
# [17900]	test-rmse:0.41111
# [18000]	test-rmse:0.41111
# [18100]	test-rmse:0.41111
# [18200]	test-rmse:0.41112
# [18300]	test-rmse:0.41112
# [18400]	test-rmse:0.41112
# [18500]	test-rmse:0.41111
# [18600]	test-rmse:0.41111
# [18700]	test-rmse:0.41111
# [18800]	test-rmse:0.41111
# [18900]	test-rmse:0.41111
# [19000]	test-rmse:0.41111
# [19100]	test-rmse:0.41111
# [19200]	test-rmse:0.41111
# [19300]	test-rmse:0.41111
# [19400]	test-rmse:0.41111
# [19500]	test-rmse:0.41111
# [19600]	test-rmse:0.41111
# [19700]	test-rmse:0.41111
# [19800]	test-rmse:0.41111
# [19900]	test-rmse:0.41111
# [19999]	test-rmse:0.41111

# %%
#model_path = f'../{config['model_save_name']}'
#model_final.save_model(model_path)

# %%
new_data_start_date = pd.to_datetime('2024-01-01')
new_data_end_date = pd.to_datetime('2024-03-30')
new_data = all_trading_data[(all_trading_data['Date'] >= new_data_start_date) & (all_trading_data['Date'] <= new_data_end_date)]
new_data = new_data.reset_index(drop=True)

# %%
new_data.shape
# Out:
# (4758, 7)

# %%
bolband_period = config['bolband_period']
donchn_period = config['donchn_period']
max_MA_period = 100
max_EMA_period = 20
tchr_period = config['tchr_period']
adwm_period = config['adwm_period']
atr_period = config['atr_period']
volume_ma_period = config['volume_ma_period']
print(f" Fourier window : {fourier_lookback_window}")
max_window = max(bolband_period, 
                 donchn_period, 
                 max_MA_period, 
                 max_EMA_period,
                 tchr_period,
                 adwm_period,
                 atr_period,
                 volume_ma_period, fourier_lookback_window)
print(f"Max window : {max_window}")
# Out:
#  Fourier window : 100
# Max window : 100

# %%
def process_data(raw_data, scaler):

    trading_signals = pd.DataFrame(columns=['Date','High', 'Low', 'Open', 'Close', 'BuyPower', 'SellPower', 'Signal', 'Take_Profit_Level'])                   
    # This is the dataframe to which we will be adding the rows live
    historical_data = pd.DataFrame(columns=['Date','High', 'Low', 'Open', 'Close', 'Volume'])
    numeric_columns = ['High', 'Low', 'Open', 'Close', 'Volume'] 
    historical_data[numeric_columns] = historical_data[numeric_columns].apply(pd.to_numeric)
    all_training_features = get_all_training_features()
    predictions = []
    for index,row in raw_data.iterrows():

        if index % 100 == 0:
            logging.info(f'Index : {index}')
        new_row = pd.DataFrame({'Date': [row['Date']], 'High': [row['High']], 'Low': [row['Low']], 'Open': [row['Open']], 'Close': [row['Close']], 'Volume': [row['Volume']]})
        signal_row = pd.DataFrame({'Date': [row['Date']], 'High': [row['High']], 'Low': [row['Low']], 'Open': [row['Open']], 'Close': [row['Close']], 'Signal': ['N']})
        trading_signals = pd.concat([trading_signals, signal_row], ignore_index=True)
        historical_data = pd.concat([historical_data, new_row], ignore_index=True)
        historical_data['Volume'] = historical_data['Volume'].astype(int)
        #if len(historical_data) > max_window:
        #    historical_data = historical_data.iloc[-max_window:].reset_index(drop=True)
        if len(historical_data) > max_window:
            #print("Hist data length : ", len(historical_data))
            updated_data = add_new_features_df(historical_data)
            historical_data = historical_data.iloc[-max_window:].reset_index(drop=True)
            #print("Updated data length : ", len(updated_data))
            data_transformed = transform_features(updated_data)
            #print("Data transformed length : ", len(data_transformed))
            #data_transformed = data_transformed.dropna() 
            #data_transformed.reset_index(drop=True, inplace=True)
            inf_features = data_transformed.iloc[-max_window:].reset_index(drop=True)
            #print(f"inf_features shape : {inf_features.shape} and training features : {training_features_upd}")
            #print(inf_features.tail())
            inf_features[all_training_features] = scaler.transform(inf_features[all_training_features])
            last_row_features = inf_features.iloc[[-1]]
            last_row_features = last_row_features[all_training_features]
            if last_row_features.isna().any().any():
                print(f'The inference row at index : {index} contains na')
                print(historical_data[['Volume']].tail())
                break
                continue
        
            last_row_dm = xgb.DMatrix(last_row_features)
            prediction = model_final.predict(last_row_dm)
 
            buy_power, sell_power = prediction[0]
            trading_signals.loc[trading_signals.index[-1], 'BuyPower'] = buy_power
            trading_signals.loc[trading_signals.index[-1], 'SellPower'] = sell_power
            trading_signals.loc[trading_signals.index[-1], 'Take_Profit_Level'] = updated_data['Take_Profit_Level'].iloc[-1]
        
    return trading_signals

# %%
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=pd.errors.PerformanceWarning)

# %%
tr_signals = process_data(new_data, rscaler)

# %%
def calculate_trade(trading_signals):
    trade_positions = []
    #trade_enter_buy = config['trade_enter_buy']
    #trade_enter_sell = config['trade_enter_sell']
    fixed_profit = True
    fixed_profit_value = 1.0
    trade_enter_buy = 0.17
    trade_enter_sell = 0.17
    bar_distance = 300 # in seconds  
    barNo_before_EOD = 20
    min_bar_enter_trade_before_EOD = 14
    EOD_Time = '16:00'
    trades = []
    balance = 0
    profit_amount = 10
    profit_count = 0
    loss_count = 0
    partial_profit_count = 0
    partial_loss_count = 0
    buy_count = 0
    sell_count = 0
    #risk = config['risk']
    risk = 0.16
    loss_amount = profit_amount * risk
    positions = pd.DataFrame(columns=['Entry', 'EntryDate', 'Exit', 'ExitDate', 'Profit', 'Type'])
                    
    for index,row in trading_signals.iterrows():
        buy_power = row['BuyPower']
        sell_power = row['SellPower']
        #print(f'Buy Power : {buy_power}, Sell Power : {sell_power}')

        #predicted_class_index = np.argmax(prob_prediction, axis=1)          #predictions.append(prediction[0])
        

        if len(trades) == 0:
            eod_dt_time = row['Date'].replace(hour=int(EOD_Time.split(':')[0]), minute=int(EOD_Time.split(':')[1]))
            latest_trade_enter_time = eod_dt_time - timedelta(seconds=min_bar_enter_trade_before_EOD * bar_distance)
            if row['Date'] <= latest_trade_enter_time: 
                if buy_power > sell_power and buy_power > trade_enter_buy:
                    if fixed_profit:
                        take_profit = fixed_profit_value
                    else:
                        take_profit = row['Take_Profit_Level'] 
                    trades.append({"Type": "B", 
                                "TakeProfit": row['Close'] + take_profit,
                                "StopLoss": row['Close'] - (take_profit * config['risk']),
                                "Profit": take_profit,
                                "Active": "Y",
                                'Entry': row['Close'],
                                'EntryDate': row['Date']
                                })
                    buy_count += 1
                elif sell_power > buy_power and sell_power > trade_enter_sell:
                    take_profit = row['Take_Profit_Level'] 
                    trades.append({"Type": "S", 
                                "TakeProfit": row['Close'] - take_profit,
                                "Profit": take_profit,
                                "StopLoss": row['Close'] + (take_profit * config['risk']),
                                "Active": "Y",
                                'Entry': row['Close'],
                                'EntryDate': row['Date']
                                })
                    sell_count += 1
        else:
            trade = trades[0]
            eod_dt_time = row['Date'].replace(hour=int(EOD_Time.split(':')[0]), minute=int(EOD_Time.split(':')[1]))
            max_exit_time = eod_dt_time - timedelta(seconds=barNo_before_EOD * bar_distance)
            if row['Date'] >= max_exit_time:
                trade['Active'] = 'N'
                if trade['Type'] == 'B':
                    profit = (row['Close'] - trade['Entry']) * profit_amount
                else:
                    profit = (trade['Entry'] - row['Close']) * profit_amount
                
                if profit < 0:
                    partial_loss_count += 1
                    print(f"EOD Exit , Loss, New Balance : {balance}")
                else:
                    partial_profit_count += 1
                    print(f"EOD Exit, Profit, New Balance : {balance}")
                pos_row = pd.DataFrame({'Entry': [trade['Entry']], 'EntryDate': [trade['EntryDate']], 'Exit': [row['Close']], 'ExitDate': [row['Date']] , 'Profit': profit, 'Type': [trade['Type']]})
                positions = pd.concat([positions, pos_row], ignore_index=True)
            else:
                if buy_power > sell_power and buy_power > trade_enter_buy and trade['Type'] == 'S':
                    trade['Active'] = 'N'
                    profit = (trade['Entry'] - row['Close']) * profit_amount
                    balance += profit 
                    if profit < 0:
                        partial_loss_count += 1
                        print(f"Partial Loss, New Balance : {balance}")
                    else:
                        partial_profit_count += 1
                        print(f"Partial Profit, New Balance : {balance}")
                    pos_row = pd.DataFrame({'Entry': [trade['Entry']], 'EntryDate': [trade['EntryDate']], 'Exit': [row['Close']], 'ExitDate': [row['Date']] , 'Profit': profit, 'Type': [trade['Type']]})
                    positions = pd.concat([positions, pos_row], ignore_index=True)

                elif sell_power > buy_power and sell_power > trade_enter_sell and trades[0]['Type'] == 'B':
                    trade['Active'] = 'N'
                    profit = (row['Close'] - trade['Entry']) * profit_amount
                    balance += profit
                    if profit < 0:
                        partial_loss_count += 1
                        print(f"Partial Loss, New Balance : {balance}")
                    else:
                        partial_profit_count += 1
                        print(f"Partial Profit, New Balance : {balance}")
                    pos_row = pd.DataFrame({'Entry': [trade['Entry']], 'EntryDate': [trade['EntryDate']], 'Exit': [row['Close']], 'ExitDate': [row['Date']] , 'Profit': profit, 'Type': [trade['Type']]})
                    positions = pd.concat([positions, pos_row], ignore_index=True)
        
        
        for trade in trades:
            if (trade['Type'] == 'B' and row['High'] >= trade['TakeProfit']) or (trade['Type'] == 'S' and row['Low'] <= trade['TakeProfit']):
                trade['Active'] = 'N'
                balance += (trade['Profit'] * profit_amount)
                profit_count += 1
                print(f"Take Profit, New Balance : {balance}")             
                pos_row = pd.DataFrame({'Entry': [trade['Entry']], 'EntryDate': [trade['EntryDate']], 'Exit': [row['Close']], 'ExitDate': [row['Date']] , 'Profit': (trade['Profit'] * profit_amount), 'Type': [trade['Type']]})
                positions = pd.concat([positions, pos_row], ignore_index=True)
            elif (trade['Type'] == 'B' and row['Low'] <= trade['StopLoss']) or (trade['Type'] == 'S' and row['High'] >= trade['StopLoss']):
                trade['Active'] = 'N'
                balance -= (trade['Profit'] * loss_amount)
                loss_count += 1
                print(f"Stop Loss, New Balance : {balance}")
                pos_row = pd.DataFrame({'Entry': [trade['Entry']], 'EntryDate': [trade['EntryDate']], 'Exit': [row['Close']], 'ExitDate': [row['Date']] , 'Profit': (trade['Profit'] * -loss_amount), 'Type': [trade['Type']]})
                positions = pd.concat([positions, pos_row], ignore_index=True)


        # Filter out all trades that are not active
        trades = [trade for trade in trades if trade['Active'] == 'Y']
        
    print(f"Final Balance : {balance} \n Take Profit count : {profit_count} \n Stop Loss count : {loss_count} \n Partial Profit count : {partial_profit_count} \n Partial Loss count : {partial_loss_count}")
    print(f"Buy count : {buy_count} \n Sell count : {sell_count}")
    
    return positions

# %%
new_data.isna().any(axis=1).sum()
# Out:
# np.int64(0)

# %%
new_data.head()
# Out:
#                  Date Symbol     Open    High     Low   Close   Volume
# 0 2024-01-02 09:30:00    SPY  472.160  472.80  472.05  472.67  2339778
# 1 2024-01-02 09:35:00    SPY  472.670  472.74  471.88  471.92  1574945
# 2 2024-01-02 09:40:00    SPY  471.920  472.10  471.71  471.80  1634708
# 3 2024-01-02 09:45:00    SPY  471.790  472.09  471.39  471.39  1398881
# 4 2024-01-02 09:50:00    SPY  471.395  471.95  471.36  471.42  1396561

# %%
positions_df = calculate_trade(tr_signals.copy())
#tr_signals.tail()
# Out:
# Partial Loss, New Balance : -1.6499999999996362
# Stop Loss, New Balance : -3.2499999999996363
# Partial Loss, New Balance : -6.449999999999568
# Partial Loss, New Balance : -6.974999999999659
# Take Profit, New Balance : 3.0250000000003414
# Partial Loss, New Balance : 1.4440000000004378
# Stop Loss, New Balance : -0.15599999999956227
# Partial Profit, New Balance : 5.794000000000143
# Stop Loss, New Balance : 4.194000000000143
# EOD Exit , Loss, New Balance : 4.194000000000143
# EOD Exit , Loss, New Balance : 4.194000000000143
# EOD Exit, Profit, New Balance : 4.194000000000143
# Partial Loss, New Balance : -5.7559999999999025
# Partial Profit, New Balance : -2.2059999999997206
# Partial Loss, New Balance : -8.90599999999988
# Partial Loss, New Balance : -10.755999999999903
# Partial Profit, New Balance : -8.254999999999585
# Partial Loss, New Balance : -10.954999999999972
# Stop Loss, New Balance : -12.554999999999971
# Partial Profit, New Balance : -11.454999999999835
# Partial Profit, New Balance : -9.354999999999471
# Partial Loss, New Balance : -9.503999999999586
# Partial Profit, New Balance : -9.040999999999848
# Partial Loss, New Balance : -11.266999999999847
# Stop Loss, New Balance : -12.866999999999846
# EOD Exit , Loss, New Balance : -12.866999999999846
# EOD Exit, Profit, New Balance : -12.866999999999846
# EOD Exit, Profit, New Balance : -12.866999999999846
# EOD Exit , Loss, New Balance : -12.866999999999846
# Stop Loss, New Balance : -14.466999999999846
# Partial Loss, New Balance : -15.466999999999505
# Partial Profit, New Balance : -15.362999999999463
# Partial Profit, New Balance : 0.43800000000069517
# Take Profit, New Balance : 10.438000000000695
# Partial Profit, New Balance : 14.73900000000108
# Partial Profit, New Balance : 23.1390000000014
# Take Profit, New Balance : 33.1390000000014
# Partial Profit, New Balance : 36.11900000000142
# Partial Loss, New Balance : 32.81900000000101
# Partial Profit, New Balance : 34.208000000000794
# Take Profit, New Balance : 44.208000000000794
# Partial Profit, New Balance : 44.85800000000077
# Stop Loss, New Balance : 43.25800000000077
# Partial Loss, New Balance : 41.45800000000127
# Partial Profit, New Balance : 52.95800000000161
# Take Profit, New Balance : 62.95800000000161
# Partial Profit, New Balance : 67.25700000000137
# EOD Exit , Loss, New Balance : 67.25700000000137
# EOD Exit, Profit, New Balance : 67.25700000000137
# EOD Exit , Loss, New Balance : 67.25700000000137
# EOD Exit , Loss, New Balance : 67.25700000000137
# Stop Loss, New Balance : 65.65700000000137
# Partial Profit, New Balance : 67.65700000000126
# Partial Loss, New Balance : 56.62600000000086
# Partial Profit, New Balance : 58.17600000000115
# Partial Loss, New Balance : 56.97600000000111
# Partial Profit, New Balance : 63.626000000000744
# Partial Profit, New Balance : 67.22600000000088
# EOD Exit , Loss, New Balance : 67.22600000000088
# EOD Exit , Loss, New Balance : 67.22600000000088
# EOD Exit, Profit, New Balance : 67.22600000000088
# EOD Exit , Loss, New Balance : 67.22600000000088
# Stop Loss, New Balance : 65.62600000000089
# Partial Loss, New Balance : 62.00200000000052
# Partial Loss, New Balance : 53.22200000000066
# Partial Loss, New Balance : 49.92300000000057
# Partial Loss, New Balance : 49.12300000000073
# Partial Profit, New Balance : 51.77300000000116
# Partial Loss, New Balance : 51.24200000000144
# Partial Loss, New Balance : 49.24200000000155
# Partial Loss, New Balance : 48.692000000001485
# Stop Loss, New Balance : 47.092000000001484
# Partial Profit, New Balance : 51.84200000000171
# Partial Profit, New Balance : 54.15400000000172
# EOD Exit, Profit, New Balance : 54.15400000000172
# EOD Exit, Profit, New Balance : 54.15400000000172
# EOD Exit , Loss, New Balance : 54.15400000000172
# EOD Exit, Profit, New Balance : 54.15400000000172
# Stop Loss, New Balance : 52.55400000000172
# Partial Loss, New Balance : 52.354000000001335
# Partial Loss, New Balance : 46.104000000001335
# Stop Loss, New Balance : 44.504000000001334
# Partial Profit, New Balance : 49.80400000000106
# Partial Profit, New Balance : 51.40500000000106
# Partial Loss, New Balance : 43.605000000000764
# Stop Loss, New Balance : 42.00500000000076
# Partial Profit, New Balance : 43.30500000000072
# Partial Profit, New Balance : 46.50500000000065
# Partial Loss, New Balance : 43.505000000000535
# Stop Loss, New Balance : 41.905000000000534
# Partial Profit, New Balance : 42.255000000000216
# Partial Loss, New Balance : 35.15500000000042
# EOD Exit, Profit, New Balance : 35.15500000000042
# EOD Exit , Loss, New Balance : 35.15500000000042
# EOD Exit, Profit, New Balance : 35.15500000000042
# EOD Exit , Loss, New Balance : 35.15500000000042
# Partial Profit, New Balance : 49.75400000000047
# Stop Loss, New Balance : 48.154000000000465
# Take Profit, New Balance : 58.154000000000465
# Take Profit, New Balance : 68.15400000000047
# Partial Profit, New Balance : 71.31400000000077
# Partial Profit, New Balance : 78.01400000000093
# Stop Loss, New Balance : 76.41400000000094
# Partial Profit, New Balance : 81.38200000000101
# Stop Loss, New Balance : 79.78200000000102
# Partial Profit, New Balance : 85.12200000000094
# EOD Exit , Loss, New Balance : 85.12200000000094
# EOD Exit, Profit, New Balance : 85.12200000000094
# EOD Exit, Profit, New Balance : 85.12200000000094
# EOD Exit , Loss, New Balance : 85.12200000000094
# Partial Profit, New Balance : 85.23600000000131
# Partial Profit, New Balance : 90.63700000000127
# Partial Profit, New Balance : 96.83700000000131
# Partial Profit, New Balance : 99.03700000000158
# Stop Loss, New Balance : 97.43700000000159
# Partial Profit, New Balance : 98.18700000000148
# Partial Profit, New Balance : 100.0370000000015
# Partial Loss, New Balance : 99.73600000000145
# Partial Loss, New Balance : 98.23600000000111
# Partial Profit, New Balance : 100.83600000000102
# EOD Exit, Profit, New Balance : 100.83600000000102
# EOD Exit , Loss, New Balance : 100.83600000000102
# Stop Loss, New Balance : 99.23600000000103
# EOD Exit, Profit, New Balance : 99.23600000000103
# EOD Exit, Profit, New Balance : 99.23600000000103
# Partial Loss, New Balance : 88.5360000000011
# Partial Profit, New Balance : 99.43600000000085
# Partial Profit, New Balance : 99.49500000000081
# Partial Profit, New Balance : 101.02800000000083
# Partial Loss, New Balance : 99.33400000000087
# EOD Exit, Profit, New Balance : 99.33400000000087
# EOD Exit , Loss, New Balance : 99.33400000000087
# EOD Exit , Loss, New Balance : 99.33400000000087
# EOD Exit , Loss, New Balance : 99.33400000000087
# Partial Profit, New Balance : 101.98400000000073
# Partial Loss, New Balance : 92.53400000000023
# Partial Profit, New Balance : 93.23500000000048
# Stop Loss, New Balance : 91.63500000000049
# Partial Profit, New Balance : 94.12400000000041
# Partial Profit, New Balance : 97.57400000000011
# Partial Profit, New Balance : 99.17799999999993
# Partial Loss, New Balance : 95.62999999999981
# Partial Profit, New Balance : 103.92999999999965
# Partial Profit, New Balance : 105.1299999999997
# Partial Loss, New Balance : 98.12999999999924
# EOD Exit, Profit, New Balance : 98.12999999999924
# EOD Exit , Loss, New Balance : 98.12999999999924
# EOD Exit, Profit, New Balance : 98.12999999999924
# Stop Loss, New Balance : 96.52999999999925
# Partial Profit, New Balance : 100.42999999999911
# Partial Loss, New Balance : 97.62999999999882
# Stop Loss, New Balance : 96.02999999999882
# Partial Profit, New Balance : 99.42899999999882
# Take Profit, New Balance : 109.42899999999882
# Stop Loss, New Balance : 107.82899999999883
# Partial Loss, New Balance : 107.61899999999868
# Stop Loss, New Balance : 106.01899999999868
# Partial Loss, New Balance : 105.22999999999836
# Stop Loss, New Balance : 103.62999999999836
# Take Profit, New Balance : 113.62999999999836
# Partial Loss, New Balance : 112.2299999999985
# Partial Profit, New Balance : 115.6289999999985
# EOD Exit , Loss, New Balance : 115.6289999999985
# EOD Exit, Profit, New Balance : 115.6289999999985
# EOD Exit, Profit, New Balance : 115.6289999999985
# EOD Exit , Loss, New Balance : 115.6289999999985
# Partial Loss, New Balance : 111.8789999999985
# Stop Loss, New Balance : 110.2789999999985
# Take Profit, New Balance : 120.2789999999985
# Partial Loss, New Balance : 119.67899999999848
# Partial Loss, New Balance : 117.37799999999798
# Partial Profit, New Balance : 118.87799999999775
# Partial Profit, New Balance : 119.47799999999778
# Partial Loss, New Balance : 113.37799999999764
# Partial Profit, New Balance : 115.97799999999755
# Partial Profit, New Balance : 118.87799999999775
# Partial Loss, New Balance : 116.47799999999823
# Partial Profit, New Balance : 120.57899999999823
# EOD Exit , Loss, New Balance : 120.57899999999823
# EOD Exit, Profit, New Balance : 120.57899999999823
# EOD Exit, Profit, New Balance : 120.57899999999823
# EOD Exit, Profit, New Balance : 120.57899999999823
# Stop Loss, New Balance : 118.97899999999824
# Partial Profit, New Balance : 123.77899999999842
# Partial Profit, New Balance : 124.37899999999844
# Partial Profit, New Balance : 127.07899999999826
# Partial Profit, New Balance : 130.78599999999824
# Partial Profit, New Balance : 135.58599999999785
# Partial Profit, New Balance : 139.03599999999756
# Stop Loss, New Balance : 137.43599999999756
# Partial Profit, New Balance : 140.13499999999763
# Partial Loss, New Balance : 137.6849999999976
# Stop Loss, New Balance : 136.0849999999976
# EOD Exit, Profit, New Balance : 136.0849999999976
# EOD Exit, Profit, New Balance : 136.0849999999976
# EOD Exit, Profit, New Balance : 136.0849999999976
# Partial Loss, New Balance : 133.78499999999798
# Partial Profit, New Balance : 134.43499999999796
# Partial Profit, New Balance : 142.23499999999768
# Partial Profit, New Balance : 144.68499999999773
# Partial Loss, New Balance : 144.13499999999766
# Partial Loss, New Balance : 137.3349999999976
# EOD Exit, Profit, New Balance : 137.3349999999976
# EOD Exit , Loss, New Balance : 137.3349999999976
# EOD Exit, Profit, New Balance : 137.3349999999976
# EOD Exit, Profit, New Balance : 137.3349999999976
# Partial Profit, New Balance : 147.23499999999768
# Stop Loss, New Balance : 145.6349999999977
# Take Profit, New Balance : 155.6349999999977
# Stop Loss, New Balance : 154.0349999999977
# Partial Profit, New Balance : 156.43499999999779
# Partial Profit, New Balance : 157.48499999999797
# Partial Profit, New Balance : 159.78499999999815
# Partial Loss, New Balance : 159.48499999999842
# Partial Profit, New Balance : 163.63499999999806
# Partial Profit, New Balance : 165.93499999999767
# Partial Profit, New Balance : 176.63999999999805
# Stop Loss, New Balance : 175.03999999999806
# Partial Loss, New Balance : 174.65099999999794
# EOD Exit, Profit, New Balance : 174.65099999999794
# EOD Exit, Profit, New Balance : 174.65099999999794
# EOD Exit , Loss, New Balance : 174.65099999999794
# EOD Exit , Loss, New Balance : 174.65099999999794
# Partial Profit, New Balance : 174.8009999999978
# Partial Loss, New Balance : 171.9009999999976
# Partial Loss, New Balance : 171.75099999999716
# Partial Loss, New Balance : 165.3509999999973
# Stop Loss, New Balance : 163.7509999999973
# Partial Loss, New Balance : 161.224999999997
# Partial Loss, New Balance : 158.87499999999744
# Stop Loss, New Balance : 157.27499999999745
# EOD Exit , Loss, New Balance : 157.27499999999745
# EOD Exit, Profit, New Balance : 157.27499999999745
# EOD Exit, Profit, New Balance : 157.27499999999745
# EOD Exit, Profit, New Balance : 157.27499999999745
# Stop Loss, New Balance : 155.67499999999745
# Stop Loss, New Balance : 154.07499999999746
# Stop Loss, New Balance : 152.47499999999746
# Partial Profit, New Balance : 154.5249999999973
# Partial Profit, New Balance : 160.2749999999972
# Partial Profit, New Balance : 162.974999999997
# Partial Loss, New Balance : 160.87499999999665
# Stop Loss, New Balance : 159.27499999999665
# Partial Loss, New Balance : 157.66799999999645
# Partial Profit, New Balance : 157.86699999999652
# EOD Exit, Profit, New Balance : 157.86699999999652
# EOD Exit, Profit, New Balance : 157.86699999999652
# EOD Exit, Profit, New Balance : 157.86699999999652
# EOD Exit , Loss, New Balance : 157.86699999999652
# Partial Profit, New Balance : 158.46699999999655
# Partial Profit, New Balance : 165.46699999999643
# Partial Loss, New Balance : 159.5669999999961
# Partial Profit, New Balance : 159.7749999999962
# Partial Profit, New Balance : 159.97499999999658
# Partial Loss, New Balance : 156.93499999999685
# Partial Loss, New Balance : 156.331999999997
# Partial Loss, New Balance : 152.22699999999688
# EOD Exit, Profit, New Balance : 152.22699999999688
# EOD Exit, Profit, New Balance : 152.22699999999688
# EOD Exit , Loss, New Balance : 152.22699999999688
# EOD Exit, Profit, New Balance : 152.22699999999688
# Partial Loss, New Balance : 152.22599999999656
# Partial Profit, New Balance : 155.17799999999679
# Partial Profit, New Balance : 159.47799999999685
# Partial Profit, New Balance : 164.27799999999704
# Partial Profit, New Balance : 164.97799999999754
# Partial Profit, New Balance : 175.72799999999742
# Partial Loss, New Balance : 171.03799999999748
# Stop Loss, New Balance : 169.4379999999975
# EOD Exit, Profit, New Balance : 169.4379999999975
# EOD Exit , Loss, New Balance : 169.4379999999975
# EOD Exit , Loss, New Balance : 169.4379999999975
# EOD Exit , Loss, New Balance : 169.4379999999975
# Partial Profit, New Balance : 177.8379999999978
# Partial Loss, New Balance : 174.73599999999772
# Partial Profit, New Balance : 186.25799999999822
# Partial Loss, New Balance : 180.9579999999985
# Stop Loss, New Balance : 179.3579999999985
# Partial Loss, New Balance : 178.6819999999988
# Partial Profit, New Balance : 186.88199999999873
# Partial Profit, New Balance : 187.19899999999873
# Partial Profit, New Balance : 195.39899999999867
# EOD Exit , Loss, New Balance : 195.39899999999867
# Stop Loss, New Balance : 193.79899999999867
# EOD Exit , Loss, New Balance : 193.79899999999867
# EOD Exit , Loss, New Balance : 193.79899999999867
# EOD Exit, Profit, New Balance : 193.79899999999867
# Partial Profit, New Balance : 196.12299999999908
# Partial Profit, New Balance : 201.01599999999922
# Partial Profit, New Balance : 202.41599999999966
# Stop Loss, New Balance : 200.81599999999966
# Partial Profit, New Balance : 203.71599999999987
# Partial Profit, New Balance : 211.8159999999999
# Stop Loss, New Balance : 210.2159999999999
# Stop Loss, New Balance : 208.6159999999999
# Partial Loss, New Balance : 208.41600000000008
# Partial Loss, New Balance : 208.26400000000015
# Partial Loss, New Balance : 192.41400000000036
# Partial Profit, New Balance : 199.61400000000063
# Partial Profit, New Balance : 205.31400000000113
# Take Profit, New Balance : 215.31400000000113
# Take Profit, New Balance : 225.31400000000113
# EOD Exit, Profit, New Balance : 225.31400000000113
# EOD Exit , Loss, New Balance : 225.31400000000113
# EOD Exit , Loss, New Balance : 225.31400000000113
# EOD Exit , Loss, New Balance : 225.31400000000113
# Partial Profit, New Balance : 229.76400000000106
# Partial Loss, New Balance : 210.26400000000118
# Take Profit, New Balance : 220.26400000000118
# Partial Profit, New Balance : 222.36400000000097
# Partial Profit, New Balance : 226.76400000000095
# Partial Profit, New Balance : 236.06500000000077
# Partial Profit, New Balance : 237.11500000000095
# Partial Loss, New Balance : 233.82400000000055
# Partial Profit, New Balance : 237.6240000000005
# Take Profit, New Balance : 247.6240000000005
# EOD Exit, Profit, New Balance : 247.6240000000005
# EOD Exit , Loss, New Balance : 247.6240000000005
# EOD Exit , Loss, New Balance : 247.6240000000005
# EOD Exit , Loss, New Balance : 247.6240000000005
# Stop Loss, New Balance : 246.0240000000005
# Stop Loss, New Balance : 244.42400000000052
# Stop Loss, New Balance : 242.82400000000052
# Partial Profit, New Balance : 243.87400000000014
# Partial Profit, New Balance : 246.67500000000018
# Partial Profit, New Balance : 247.12499999999977
# Partial Loss, New Balance : 238.09199999999976
# EOD Exit , Loss, New Balance : 238.09199999999976
# EOD Exit , Loss, New Balance : 238.09199999999976
# EOD Exit, Profit, New Balance : 238.09199999999976
# EOD Exit, Profit, New Balance : 238.09199999999976
# Partial Profit, New Balance : 245.79699999999946
# Stop Loss, New Balance : 244.19699999999946
# Stop Loss, New Balance : 242.59699999999947
# Take Profit, New Balance : 252.59699999999947
# Stop Loss, New Balance : 250.99699999999947
# Take Profit, New Balance : 260.9969999999995
# Partial Profit, New Balance : 261.69799999999975
# EOD Exit, Profit, New Balance : 261.69799999999975
# EOD Exit, Profit, New Balance : 261.69799999999975
# EOD Exit , Loss, New Balance : 261.69799999999975
# EOD Exit , Loss, New Balance : 261.69799999999975
# Partial Profit, New Balance : 261.97799999999995
# Stop Loss, New Balance : 260.37799999999993
# Partial Profit, New Balance : 264.078
# Partial Loss, New Balance : 263.07799999999975
# Partial Profit, New Balance : 267.87799999999936
# Partial Profit, New Balance : 268.0279999999992
# Stop Loss, New Balance : 266.4279999999992
# Take Profit, New Balance : 276.4279999999992
# Partial Profit, New Balance : 283.2779999999992
# Partial Loss, New Balance : 283.0689999999994
# EOD Exit , Loss, New Balance : 283.0689999999994
# EOD Exit, Profit, New Balance : 283.0689999999994
# EOD Exit , Loss, New Balance : 283.0689999999994
# EOD Exit , Loss, New Balance : 283.0689999999994
# Partial Profit, New Balance : 284.76899999999955
# Partial Profit, New Balance : 286.36899999999923
# Stop Loss, New Balance : 284.7689999999992
# Partial Profit, New Balance : 286.9689999999995
# Partial Profit, New Balance : 289.9689999999996
# Partial Loss, New Balance : 289.5689999999994
# Partial Loss, New Balance : 284.3669999999995
# Partial Loss, New Balance : 283.71699999999953
# Partial Profit, New Balance : 283.81699999999944
# Partial Profit, New Balance : 286.5669999999992
# EOD Exit, Profit, New Balance : 286.5669999999992
# EOD Exit, Profit, New Balance : 286.5669999999992
# EOD Exit, Profit, New Balance : 286.5669999999992
# EOD Exit, Profit, New Balance : 286.5669999999992
# Partial Loss, New Balance : 278.1669999999989
# Partial Profit, New Balance : 280.7669999999988
# EOD Exit , Loss, New Balance : 280.7669999999988
# EOD Exit , Loss, New Balance : 280.7669999999988
# EOD Exit , Loss, New Balance : 280.7669999999988
# EOD Exit, Profit, New Balance : 280.7669999999988
# Partial Loss, New Balance : 280.51699999999903
# Partial Loss, New Balance : 279.41599999999914
# Partial Profit, New Balance : 285.66599999999914
# Partial Loss, New Balance : 284.1659999999988
# Partial Profit, New Balance : 289.9159999999987
# Partial Profit, New Balance : 293.81599999999855
# Partial Loss, New Balance : 289.6159999999984
# Partial Profit, New Balance : 291.11599999999817
# Partial Profit, New Balance : 307.61599999999794
# Stop Loss, New Balance : 306.0159999999979
# EOD Exit , Loss, New Balance : 306.0159999999979
# EOD Exit , Loss, New Balance : 306.0159999999979
# EOD Exit , Loss, New Balance : 306.0159999999979
# Stop Loss, New Balance : 304.4159999999979
# Stop Loss, New Balance : 302.81599999999787
# Stop Loss, New Balance : 301.21599999999785
# Partial Loss, New Balance : 298.6799999999978
# Partial Loss, New Balance : 288.1299999999977
# Stop Loss, New Balance : 286.5299999999977
# Stop Loss, New Balance : 284.9299999999977
# Partial Profit, New Balance : 288.23999999999785
# EOD Exit, Profit, New Balance : 288.23999999999785
# EOD Exit , Loss, New Balance : 288.23999999999785
# EOD Exit, Profit, New Balance : 288.23999999999785
# EOD Exit , Loss, New Balance : 288.23999999999785
# Stop Loss, New Balance : 286.6399999999978
# Partial Loss, New Balance : 279.23999999999774
# Stop Loss, New Balance : 277.6399999999977
# Partial Profit, New Balance : 278.53999999999803
# Partial Profit, New Balance : 280.0399999999978
# Partial Profit, New Balance : 284.7409999999978
# Stop Loss, New Balance : 283.1409999999978
# Partial Loss, New Balance : 277.59099999999773
# Stop Loss, New Balance : 275.9909999999977
# Partial Profit, New Balance : 281.7909999999981
# Partial Profit, New Balance : 287.39099999999814
# Partial Profit, New Balance : 292.13099999999804
# Take Profit, New Balance : 302.13099999999804
# Stop Loss, New Balance : 300.530999999998
# Take Profit, New Balance : 310.530999999998
# Stop Loss, New Balance : 308.930999999998
# Partial Profit, New Balance : 312.9809999999977
# EOD Exit , Loss, New Balance : 312.9809999999977
# EOD Exit , Loss, New Balance : 312.9809999999977
# EOD Exit, Profit, New Balance : 312.9809999999977
# EOD Exit, Profit, New Balance : 312.9809999999977
# Partial Profit, New Balance : 314.530999999998
# Partial Loss, New Balance : 308.03099999999824
# Stop Loss, New Balance : 306.4309999999982
# Partial Profit, New Balance : 307.13199999999847
# Take Profit, New Balance : 317.13199999999847
# Partial Profit, New Balance : 318.7319999999987
# Partial Loss, New Balance : 308.5319999999989
# Partial Profit, New Balance : 310.5319999999988
# Partial Profit, New Balance : 311.73199999999883
# Partial Loss, New Balance : 311.2219999999984
# EOD Exit , Loss, New Balance : 311.2219999999984
# EOD Exit , Loss, New Balance : 311.2219999999984
# EOD Exit, Profit, New Balance : 311.2219999999984
# EOD Exit , Loss, New Balance : 311.2219999999984
# Partial Profit, New Balance : 312.62199999999825
# Stop Loss, New Balance : 311.02199999999823
# Stop Loss, New Balance : 309.4219999999982
# Partial Loss, New Balance : 301.7219999999984
# Take Profit, New Balance : 311.7219999999984
# Partial Profit, New Balance : 313.56199999999865
# Partial Loss, New Balance : 312.4619999999985
# Partial Loss, New Balance : 312.15699999999833
# Partial Profit, New Balance : 314.1969999999984
# Partial Loss, New Balance : 313.1969999999982
# Partial Loss, New Balance : 304.8889999999981
# Stop Loss, New Balance : 303.28899999999805
# Partial Profit, New Balance : 309.23899999999776
# Partial Loss, New Balance : 306.8379999999979
# EOD Exit, Profit, New Balance : 306.8379999999979
# EOD Exit, Profit, New Balance : 306.8379999999979
# EOD Exit , Loss, New Balance : 306.8379999999979
# Stop Loss, New Balance : 305.2379999999979
# EOD Exit , Loss, New Balance : 305.2379999999979
# Stop Loss, New Balance : 303.6379999999979
# Take Profit, New Balance : 313.6379999999979
# Stop Loss, New Balance : 312.03799999999785
# Stop Loss, New Balance : 310.4379999999978
# Stop Loss, New Balance : 308.8379999999978
# Partial Profit, New Balance : 312.8879999999981
# Partial Profit, New Balance : 315.1879999999977
# Partial Profit, New Balance : 318.58799999999746
# Stop Loss, New Balance : 316.98799999999744
# Partial Profit, New Balance : 317.0879999999979
# Partial Profit, New Balance : 328.00999999999783
# Partial Profit, New Balance : 328.6939999999978
# Stop Loss, New Balance : 327.0939999999978
# Partial Profit, New Balance : 335.1939999999978
# Partial Profit, New Balance : 339.6939999999977
# Partial Profit, New Balance : 343.2759999999972
# EOD Exit , Loss, New Balance : 343.2759999999972
# EOD Exit, Profit, New Balance : 343.2759999999972
# EOD Exit, Profit, New Balance : 343.2759999999972
# Stop Loss, New Balance : 341.6759999999972
# EOD Exit, Profit, New Balance : 341.6759999999972
# Partial Profit, New Balance : 341.6759999999972
# Partial Loss, New Balance : 335.7759999999969
# Partial Loss, New Balance : 329.6259999999968
# Stop Loss, New Balance : 328.02599999999677
# Partial Loss, New Balance : 327.92599999999686
# Partial Loss, New Balance : 325.52599999999677
# Partial Profit, New Balance : 328.4269999999967
# Partial Profit, New Balance : 328.6239999999967
# Partial Loss, New Balance : 326.5249999999967
# Partial Profit, New Balance : 330.2249999999967
# Partial Profit, New Balance : 333.32599999999707
# Partial Loss, New Balance : 329.85199999999656
# Partial Profit, New Balance : 334.06299999999624
# Stop Loss, New Balance : 332.4629999999962
# Partial Profit, New Balance : 337.81299999999646
# EOD Exit , Loss, New Balance : 337.81299999999646
# EOD Exit, Profit, New Balance : 337.81299999999646
# EOD Exit, Profit, New Balance : 337.81299999999646
# Partial Loss, New Balance : 333.76299999999617
# Partial Profit, New Balance : 346.5629999999959
# Take Profit, New Balance : 356.5629999999959
# Partial Loss, New Balance : 354.1579999999959
# Partial Loss, New Balance : 351.45899999999585
# Stop Loss, New Balance : 349.85899999999583
# Stop Loss, New Balance : 348.2589999999958
# Partial Profit, New Balance : 352.7589999999957
# Partial Profit, New Balance : 352.9589999999955
# Partial Loss, New Balance : 350.65899999999533
# Partial Loss, New Balance : 350.3589999999956
# Partial Loss, New Balance : 346.35899999999583
# Partial Profit, New Balance : 347.1579999999959
# Partial Profit, New Balance : 354.10799999999585
# EOD Exit , Loss, New Balance : 354.10799999999585
# EOD Exit, Profit, New Balance : 354.10799999999585
# EOD Exit, Profit, New Balance : 354.10799999999585
# EOD Exit , Loss, New Balance : 354.10799999999585
# Partial Profit, New Balance : 356.00799999999583
# Partial Profit, New Balance : 360.207999999996
# Stop Loss, New Balance : 358.60799999999597
# Stop Loss, New Balance : 357.00799999999595
# Partial Profit, New Balance : 363.30699999999615
# Partial Loss, New Balance : 361.95699999999624
# Partial Loss, New Balance : 361.0569999999959
# Partial Profit, New Balance : 363.0569999999958
# Stop Loss, New Balance : 361.4569999999958
# EOD Exit , Loss, New Balance : 361.4569999999958
# Stop Loss, New Balance : 359.85699999999576
# EOD Exit , Loss, New Balance : 359.85699999999576
# EOD Exit, Profit, New Balance : 359.85699999999576
# EOD Exit , Loss, New Balance : 359.85699999999576
# Partial Profit, New Balance : 370.856999999996
# Partial Profit, New Balance : 372.8569999999959
# Partial Profit, New Balance : 379.25799999999606
# Partial Loss, New Balance : 377.5209999999961
# EOD Exit, Profit, New Balance : 377.5209999999961
# EOD Exit, Profit, New Balance : 377.5209999999961
# EOD Exit, Profit, New Balance : 377.5209999999961
# EOD Exit, Profit, New Balance : 377.5209999999961
# Stop Loss, New Balance : 375.92099999999607
# Partial Profit, New Balance : 378.4219999999958
# Stop Loss, New Balance : 376.8219999999958
# Partial Loss, New Balance : 374.952999999996
# Stop Loss, New Balance : 373.352999999996
# Partial Profit, New Balance : 375.1529999999955
# EOD Exit , Loss, New Balance : 375.1529999999955
# EOD Exit, Profit, New Balance : 375.1529999999955
# EOD Exit, Profit, New Balance : 375.1529999999955
# Partial Loss, New Balance : 361.55299999999534
# Partial Loss, New Balance : 360.9039999999951
# Partial Profit, New Balance : 361.70499999999527
# Partial Loss, New Balance : 361.30499999999506
# Stop Loss, New Balance : 359.70499999999504
# Partial Loss, New Balance : 359.60499999999456
# EOD Exit, Profit, New Balance : 359.60499999999456
# EOD Exit, Profit, New Balance : 359.60499999999456
# EOD Exit, Profit, New Balance : 359.60499999999456
# EOD Exit , Loss, New Balance : 359.60499999999456
# Partial Profit, New Balance : 362.10499999999456
# Partial Profit, New Balance : 365.4549999999949
# Take Profit, New Balance : 375.4549999999949
# Partial Profit, New Balance : 379.25799999999526
# Partial Loss, New Balance : 377.9079999999948
# Stop Loss, New Balance : 376.30799999999476
# Partial Loss, New Balance : 364.90799999999433
# Partial Loss, New Balance : 364.75799999999447
# Partial Profit, New Balance : 367.50799999999424
# Partial Loss, New Balance : 365.20799999999406
# Partial Loss, New Balance : 364.90799999999433
# EOD Exit , Loss, New Balance : 364.90799999999433
# EOD Exit , Loss, New Balance : 364.90799999999433
# EOD Exit , Loss, New Balance : 364.90799999999433
# EOD Exit , Loss, New Balance : 364.90799999999433
# Partial Loss, New Balance : 360.7089999999945
# Partial Profit, New Balance : 366.00799999999447
# Partial Profit, New Balance : 366.8079999999949
# Partial Loss, New Balance : 366.519999999995
# Partial Loss, New Balance : 355.3699999999949
# Partial Loss, New Balance : 354.66999999999496
# Partial Profit, New Balance : 355.26999999999555
# Partial Loss, New Balance : 353.0199999999953
# EOD Exit, Profit, New Balance : 353.0199999999953
# EOD Exit , Loss, New Balance : 353.0199999999953
# EOD Exit, Profit, New Balance : 353.0199999999953
# EOD Exit, Profit, New Balance : 353.0199999999953
# Partial Profit, New Balance : 357.81999999999437
# Partial Profit, New Balance : 358.5209999999946
# Partial Profit, New Balance : 359.8829999999949
# Partial Profit, New Balance : 361.78299999999433
# Partial Profit, New Balance : 363.73199999999395
# Partial Profit, New Balance : 365.4819999999935
# Partial Profit, New Balance : 367.37899999999365
# Partial Loss, New Balance : 367.1289999999939
# EOD Exit , Loss, New Balance : 367.1289999999939
# EOD Exit, Profit, New Balance : 367.1289999999939
# Stop Loss, New Balance : 365.52899999999386
# EOD Exit, Profit, New Balance : 365.52899999999386
# EOD Exit , Loss, New Balance : 365.52899999999386
# Partial Loss, New Balance : 363.5269999999939
# Partial Profit, New Balance : 379.5769999999935
# Stop Loss, New Balance : 377.9769999999935
# Partial Profit, New Balance : 380.92699999999365
# Partial Profit, New Balance : 383.12699999999336
# Partial Loss, New Balance : 382.5279999999931
# Partial Loss, New Balance : 381.1779999999932
# Partial Profit, New Balance : 382.1779999999934
# Partial Loss, New Balance : 377.87799999999334
# Stop Loss, New Balance : 376.2779999999933
# EOD Exit , Loss, New Balance : 376.2779999999933
# EOD Exit, Profit, New Balance : 376.2779999999933
# EOD Exit, Profit, New Balance : 376.2779999999933
# EOD Exit, Profit, New Balance : 376.2779999999933
# Stop Loss, New Balance : 374.6779999999933
# Partial Profit, New Balance : 388.0279999999931
# Partial Profit, New Balance : 394.52799999999286
# Partial Loss, New Balance : 383.1409999999926
# Partial Profit, New Balance : 383.6159999999927
# Partial Profit, New Balance : 389.51599999999246
# Partial Loss, New Balance : 383.6159999999927
# Partial Loss, New Balance : 383.315999999993
# Partial Profit, New Balance : 387.9159999999928
# Stop Loss, New Balance : 386.31599999999275
# Partial Profit, New Balance : 398.0159999999929
# EOD Exit, Profit, New Balance : 398.0159999999929
# EOD Exit, Profit, New Balance : 398.0159999999929
# EOD Exit , Loss, New Balance : 398.0159999999929
# Stop Loss, New Balance : 396.4159999999929
# EOD Exit , Loss, New Balance : 396.4159999999929
# Stop Loss, New Balance : 394.81599999999287
# Partial Loss, New Balance : 383.71599999999273
# Partial Loss, New Balance : 382.4159999999928
# Partial Profit, New Balance : 384.3159999999933
# Partial Loss, New Balance : 381.4289999999927
# Stop Loss, New Balance : 379.8289999999927
# Take Profit, New Balance : 389.8289999999927
# EOD Exit , Loss, New Balance : 389.8289999999927
# Stop Loss, New Balance : 388.22899999999265
# EOD Exit, Profit, New Balance : 388.22899999999265
# EOD Exit, Profit, New Balance : 388.22899999999265
# EOD Exit, Profit, New Balance : 388.22899999999265
# Partial Profit, New Balance : 388.42899999999247
# Partial Loss, New Balance : 379.32899999999165
# Partial Profit, New Balance : 380.01699999999175
# Take Profit, New Balance : 390.01699999999175
# Stop Loss, New Balance : 388.41699999999173
# Stop Loss, New Balance : 386.8169999999917
# Stop Loss, New Balance : 385.2169999999917
# Stop Loss, New Balance : 383.61699999999166
# Stop Loss, New Balance : 382.01699999999164
# Take Profit, New Balance : 392.01699999999164
# Stop Loss, New Balance : 390.4169999999916
# Partial Profit, New Balance : 397.62399999999127
# Partial Profit, New Balance : 418.3249999999915
# Stop Loss, New Balance : 416.7249999999915
# Partial Loss, New Balance : 416.174999999992
# Partial Loss, New Balance : 405.17499999999177
# EOD Exit , Loss, New Balance : 405.17499999999177
# EOD Exit , Loss, New Balance : 405.17499999999177
# EOD Exit , Loss, New Balance : 405.17499999999177
# EOD Exit, Profit, New Balance : 405.17499999999177
# Partial Profit, New Balance : 413.9749999999917
# Stop Loss, New Balance : 412.3749999999917
# Partial Profit, New Balance : 420.67499999999154
# Partial Profit, New Balance : 431.4249999999914
# Take Profit, New Balance : 441.4249999999914
# Partial Loss, New Balance : 424.8249999999912
# Stop Loss, New Balance : 423.22499999999116
# Partial Profit, New Balance : 424.5249999999911
# Partial Loss, New Balance : 419.1249999999909
# Partial Profit, New Balance : 421.1249999999908
# Partial Profit, New Balance : 425.82499999999106
# Partial Loss, New Balance : 424.42499999999063
# Partial Loss, New Balance : 418.02399999999045
# EOD Exit, Profit, New Balance : 418.02399999999045
# EOD Exit , Loss, New Balance : 418.02399999999045
# Partial Profit, New Balance : 431.82399999998984
# Stop Loss, New Balance : 430.2239999999898
# Partial Loss, New Balance : 419.32299999998975
# Stop Loss, New Balance : 417.7229999999897
# Partial Profit, New Balance : 429.42299999999045
# Take Profit, New Balance : 439.42299999999045
# Partial Loss, New Balance : 430.32299999998963
# Take Profit, New Balance : 440.32299999998963
# Stop Loss, New Balance : 438.7229999999896
# Stop Loss, New Balance : 437.1229999999896
# Partial Loss, New Balance : 433.1229999999898
# Stop Loss, New Balance : 431.5229999999898
# Partial Profit, New Balance : 441.72299999999075
# Partial Profit, New Balance : 446.42199999999013
# Partial Loss, New Balance : 444.8089999999903
# Partial Profit, New Balance : 447.7099999999908
# EOD Exit , Loss, New Balance : 447.7099999999908
# EOD Exit , Loss, New Balance : 447.7099999999908
# EOD Exit, Profit, New Balance : 447.7099999999908
# EOD Exit , Loss, New Balance : 447.7099999999908
# Partial Profit, New Balance : 452.55999999999096
# Partial Profit, New Balance : 454.3599999999916
# Partial Profit, New Balance : 456.5609999999916
# Partial Profit, New Balance : 458.1609999999913
# Partial Profit, New Balance : 460.1609999999906
# Partial Profit, New Balance : 467.1609999999911
# Partial Profit, New Balance : 470.71099999999126
# Partial Loss, New Balance : 468.81099999999185
# EOD Exit, Profit, New Balance : 468.81099999999185
# EOD Exit, Profit, New Balance : 468.81099999999185
# EOD Exit, Profit, New Balance : 468.81099999999185
# EOD Exit , Loss, New Balance : 468.81099999999185
# Partial Profit, New Balance : 494.56099999999117
# Stop Loss, New Balance : 492.96099999999115
# Partial Profit, New Balance : 500.56099999999105
# Partial Profit, New Balance : 503.06199999999194
# Partial Loss, New Balance : 494.51199999999176
# Stop Loss, New Balance : 492.91199999999174
# Partial Loss, New Balance : 490.6129999999913
# Stop Loss, New Balance : 489.0129999999913
# Partial Loss, New Balance : 485.31299999999123
# Partial Loss, New Balance : 483.3129999999919
# Partial Profit, New Balance : 484.21299999999223
# Partial Profit, New Balance : 486.42299999999227
# Stop Loss, New Balance : 484.82299999999225
# EOD Exit , Loss, New Balance : 484.82299999999225
# EOD Exit, Profit, New Balance : 484.82299999999225
# EOD Exit, Profit, New Balance : 484.82299999999225
# EOD Exit, Profit, New Balance : 484.82299999999225
# Partial Profit, New Balance : 489.2229999999922
# Take Profit, New Balance : 499.2229999999922
# Stop Loss, New Balance : 497.6229999999922
# Stop Loss, New Balance : 496.0229999999922
# Stop Loss, New Balance : 494.42299999999216
# Take Profit, New Balance : 504.42299999999216
# Partial Profit, New Balance : 509.9229999999917
# Partial Profit, New Balance : 519.5229999999915
# Partial Loss, New Balance : 518.8729999999915
# Partial Profit, New Balance : 523.1239999999914
# Stop Loss, New Balance : 521.5239999999914
# Take Profit, New Balance : 531.5239999999914
# Partial Profit, New Balance : 535.1369999999916
# EOD Exit , Loss, New Balance : 535.1369999999916
# EOD Exit , Loss, New Balance : 535.1369999999916
# EOD Exit, Profit, New Balance : 535.1369999999916
# EOD Exit , Loss, New Balance : 535.1369999999916
# Partial Profit, New Balance : 540.3369999999915
# Partial Profit, New Balance : 551.5369999999915
# Take Profit, New Balance : 561.5369999999915
# Partial Profit, New Balance : 563.8369999999906
# Partial Profit, New Balance : 563.8869999999905
# Stop Loss, New Balance : 562.2869999999905
# Partial Loss, New Balance : 558.5369999999905
# Stop Loss, New Balance : 556.9369999999905
# Partial Profit, New Balance : 560.1759999999903
# Partial Profit, New Balance : 563.8259999999904
# Partial Loss, New Balance : 561.9259999999898
# Partial Loss, New Balance : 559.9209999999895
# Partial Loss, New Balance : 557.4209999999895
# Partial Profit, New Balance : 557.8549999999897
# Partial Profit, New Balance : 561.0049999999891
# Partial Profit, New Balance : 564.00399999999
# Partial Profit, New Balance : 567.75399999999
# EOD Exit, Profit, New Balance : 567.75399999999
# EOD Exit, Profit, New Balance : 567.75399999999
# EOD Exit, Profit, New Balance : 567.75399999999
# EOD Exit, Profit, New Balance : 567.75399999999
# Partial Profit, New Balance : 571.7539999999898
# Partial Profit, New Balance : 573.54199999999
# Partial Loss, New Balance : 568.1549999999905
# Partial Profit, New Balance : 570.4549999999907
# Partial Loss, New Balance : 569.8549999999913
# Partial Profit, New Balance : 577.3049999999913
# Take Profit, New Balance : 587.3049999999913
# Partial Loss, New Balance : 585.4549999999907
# Partial Loss, New Balance : 584.8049999999913
# Stop Loss, New Balance : 583.2049999999913
# Partial Profit, New Balance : 584.4039999999916
# Partial Loss, New Balance : 577.970999999992
# Partial Loss, New Balance : 575.0889999999913
# Partial Profit, New Balance : 575.1889999999923
# Partial Loss, New Balance : 571.0399999999925
# Partial Loss, New Balance : 570.9909999999923
# Partial Loss, New Balance : 569.0919999999926
# EOD Exit, Profit, New Balance : 569.0919999999926
# EOD Exit, Profit, New Balance : 569.0919999999926
# EOD Exit , Loss, New Balance : 569.0919999999926
# Partial Profit, New Balance : 570.2419999999927
# Partial Profit, New Balance : 570.9919999999931
# Partial Profit, New Balance : 575.7179999999937
# Partial Profit, New Balance : 578.4179999999935
# Partial Loss, New Balance : 578.0679999999938
# Partial Profit, New Balance : 579.9179999999944
# Partial Loss, New Balance : 577.3179999999934
# Partial Loss, New Balance : 576.517999999993
# Partial Loss, New Balance : 574.9709999999936
# Partial Loss, New Balance : 574.1709999999944
# Partial Loss, New Balance : 572.4709999999948
# Stop Loss, New Balance : 570.8709999999948
# Take Profit, New Balance : 580.8709999999948
# Take Profit, New Balance : 590.8709999999948
# Stop Loss, New Balance : 589.2709999999947
# EOD Exit , Loss, New Balance : 589.2709999999947
# Take Profit, New Balance : 599.2709999999947
# EOD Exit , Loss, New Balance : 599.2709999999947
# EOD Exit, Profit, New Balance : 599.2709999999947
# Partial Loss, New Balance : 595.070999999994
# Partial Profit, New Balance : 597.570999999994
# Stop Loss, New Balance : 595.970999999994
# Stop Loss, New Balance : 594.370999999994
# Partial Profit, New Balance : 599.1209999999942
# Partial Profit, New Balance : 602.3209999999947
# Partial Profit, New Balance : 604.6709999999948
# Partial Profit, New Balance : 607.3459999999952
# Partial Loss, New Balance : 601.644999999995
# Stop Loss, New Balance : 600.044999999995
# Partial Loss, New Balance : 599.1949999999946
# Partial Profit, New Balance : 600.3949999999946
# EOD Exit , Loss, New Balance : 600.3949999999946
# EOD Exit , Loss, New Balance : 600.3949999999946
# EOD Exit, Profit, New Balance : 600.3949999999946
# EOD Exit , Loss, New Balance : 600.3949999999946
# Partial Loss, New Balance : 597.8939999999938
# Partial Profit, New Balance : 602.4949999999939
# Partial Profit, New Balance : 608.7809999999939
# Partial Profit, New Balance : 612.580999999995
# Partial Profit, New Balance : 614.2309999999947
# Partial Profit, New Balance : 615.7309999999944
# Partial Loss, New Balance : 613.1809999999945
# Partial Profit, New Balance : 613.830999999995
# Partial Profit, New Balance : 615.4809999999947
# Partial Profit, New Balance : 618.431999999994
# EOD Exit , Loss, New Balance : 618.431999999994
# Stop Loss, New Balance : 616.831999999994
# EOD Exit, Profit, New Balance : 616.831999999994
# Partial Profit, New Balance : 621.9819999999938
# Partial Profit, New Balance : 624.4919999999936
# Partial Loss, New Balance : 621.0419999999933
# Partial Profit, New Balance : 621.9419999999936
# Partial Profit, New Balance : 622.8919999999939
# Partial Profit, New Balance : 623.3969999999945
# Partial Loss, New Balance : 622.846999999995
# Partial Loss, New Balance : 620.6969999999947
# Partial Loss, New Balance : 618.4969999999944
# Partial Loss, New Balance : 616.4969999999939
# Partial Loss, New Balance : 616.1919999999932
# EOD Exit , Loss, New Balance : 616.1919999999932
# EOD Exit , Loss, New Balance : 616.1919999999932
# EOD Exit, Profit, New Balance : 616.1919999999932
# Partial Loss, New Balance : 615.5419999999938
# Partial Loss, New Balance : 615.341999999994
# Partial Profit, New Balance : 615.341999999994
# Partial Loss, New Balance : 614.6919999999934
# Partial Profit, New Balance : 614.7919999999945
# Stop Loss, New Balance : 613.1919999999944
# EOD Exit, Profit, New Balance : 613.1919999999944
# EOD Exit, Profit, New Balance : 613.1919999999944
# EOD Exit , Loss, New Balance : 613.1919999999944
# EOD Exit, Profit, New Balance : 613.1919999999944
# Partial Loss, New Balance : 610.9919999999953
# Partial Profit, New Balance : 619.4419999999956
# Partial Loss, New Balance : 617.3399999999957
# Partial Profit, New Balance : 621.5799999999955
# Partial Profit, New Balance : 622.8299999999955
# Partial Loss, New Balance : 617.8299999999955
# Partial Loss, New Balance : 615.7699999999965
# EOD Exit , Loss, New Balance : 615.7699999999965
# EOD Exit , Loss, New Balance : 615.7699999999965
# EOD Exit , Loss, New Balance : 615.7699999999965
# EOD Exit , Loss, New Balance : 615.7699999999965
# Partial Loss, New Balance : 613.4699999999963
# Partial Profit, New Balance : 617.2699999999962
# Partial Profit, New Balance : 619.1699999999968
# Partial Loss, New Balance : 618.3699999999975
# Partial Loss, New Balance : 618.0699999999966
# Partial Profit, New Balance : 621.8189999999969
# EOD Exit, Profit, New Balance : 621.8189999999969
# EOD Exit, Profit, New Balance : 621.8189999999969
# EOD Exit, Profit, New Balance : 621.8189999999969
# EOD Exit , Loss, New Balance : 621.8189999999969
# Final Balance : 621.8189999999969
#  Take Profit count : 39
#  Stop Loss count : 131
#  Partial Profit count : 398
#  Partial Loss count : 302
# Buy count : 435
#  Sell count : 397

# %%
positions_df['ExitDate'] = pd.to_datetime(positions_df['ExitDate'])
positions_df = positions_df.sort_values(by='ExitDate')
positions_df['Balance'] = positions_df['Profit'].cumsum()

plt.figure(figsize=(20, 10))
plt.plot(positions_df['ExitDate'], positions_df['Balance'], marker='o', linestyle='-', color='b', label='Balance')
plt.xlabel('Date')
plt.ylabel('Balance')
plt.title('Balance over time')
plt.axhline(y=0, color='r', linestyle='--', linewidth=1)
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.show()

# %%
def calculate_trade_optuna(trading_signals, trading_params):
    trade_positions = []
    #trade_enter_buy = config['trade_enter_buy']
    #trade_enter_sell = config['trade_enter_sell']
    fixed_profit = True
    fixed_profit_value = trading_params['fixed_profit_value']
    trade_enter_buy = trading_params['trade_enter']
    trade_enter_sell = trading_params['trade_enter']
    bar_distance = 300 # in seconds  
    barNo_before_EOD = trading_params['barNo_before_EOD']
    min_bar_enter_trade_before_EOD = trading_params['min_bar_enter_trade_before_EOD']
    risk = trading_params['risk']
    EOD_Time = '16:00'
    trades = []
    balance = 0
    profit_amount = 10
    profit_count = 0
    loss_count = 0
    partial_profit_count = 0
    partial_loss_count = 0
    buy_count = 0
    sell_count = 0
    loss_amount = profit_amount * risk
                    
    for index,row in trading_signals.iterrows():
        buy_power = row['BuyPower']
        sell_power = row['SellPower']
        #print(f'Buy Power : {buy_power}, Sell Power : {sell_power}')

        #predicted_class_index = np.argmax(prob_prediction, axis=1)          #predictions.append(prediction[0])
        

        if len(trades) == 0:
            eod_dt_time = row['Date'].replace(hour=int(EOD_Time.split(':')[0]), minute=int(EOD_Time.split(':')[1]))
            latest_trade_enter_time = eod_dt_time - timedelta(seconds=min_bar_enter_trade_before_EOD * bar_distance)
            if row['Date'] <= latest_trade_enter_time: 
                if buy_power > sell_power and buy_power > trade_enter_buy:
                    if fixed_profit:
                        take_profit = fixed_profit_value
                    else:
                        take_profit = row['Take_Profit_Level'] 
                    trades.append({"Type": "B", 
                                "TakeProfit": row['Close'] + take_profit,
                                "StopLoss": row['Close'] - (take_profit * config['risk']),
                                "Profit": take_profit,
                                "Active": "Y",
                                'Entry': row['Close'],
                                'EntryDate': row['Date']
                                })
                    buy_count += 1
                elif sell_power > buy_power and sell_power > trade_enter_sell:
                    take_profit = row['Take_Profit_Level'] 
                    trades.append({"Type": "S", 
                                "TakeProfit": row['Close'] - take_profit,
                                "Profit": take_profit,
                                "StopLoss": row['Close'] + (take_profit * config['risk']),
                                "Active": "Y",
                                'Entry': row['Close'],
                                'EntryDate': row['Date']
                                })
                    sell_count += 1
        else:
            trade = trades[0]
            eod_dt_time = row['Date'].replace(hour=int(EOD_Time.split(':')[0]), minute=int(EOD_Time.split(':')[1]))
            max_exit_time = eod_dt_time - timedelta(seconds=barNo_before_EOD * bar_distance)
            if row['Date'] >= max_exit_time:
                trade['Active'] = 'N'
                if trade['Type'] == 'B':
                    profit = (row['Close'] - trade['Entry']) * profit_amount
                else:
                    profit = (trade['Entry'] - row['Close']) * profit_amount
                
                if profit < 0:
                    partial_loss_count += 1
                    #print(f"EOD Exit , Loss, New Balance : {balance}")
                else:
                    partial_profit_count += 1
                    #print(f"EOD Exit, Profit, New Balance : {balance}")
            else:
                if buy_power > sell_power and buy_power > trade_enter_buy and trade['Type'] == 'S':
                    trade['Active'] = 'N'
                    profit = (trade['Entry'] - row['Close']) * profit_amount
                    balance += profit 
                    if profit < 0:
                        partial_loss_count += 1
                        #print(f"Partial Loss, New Balance : {balance}")
                    else:
                        partial_profit_count += 1
                        #print(f"Partial Profit, New Balance : {balance}")

                elif sell_power > buy_power and sell_power > trade_enter_sell and trades[0]['Type'] == 'B':
                    trade['Active'] = 'N'
                    profit = (row['Close'] - trade['Entry']) * profit_amount
                    balance += profit
                    if profit < 0:
                        partial_loss_count += 1
                        #print(f"Partial Loss, New Balance : {balance}")
                    else:
                        partial_profit_count += 1
                        #print(f"Partial Profit, New Balance : {balance}")
        
        
        for trade in trades:
            if (trade['Type'] == 'B' and row['High'] >= trade['TakeProfit']) or (trade['Type'] == 'S' and row['Low'] <= trade['TakeProfit']):
                trade['Active'] = 'N'
                balance += (trade['Profit'] * profit_amount)
                profit_count += 1
                #print(f"Take Profit, New Balance : {balance}")             
            elif (trade['Type'] == 'B' and row['Low'] <= trade['StopLoss']) or (trade['Type'] == 'S' and row['High'] >= trade['StopLoss']):
                trade['Active'] = 'N'
                balance -= (trade['Profit'] * loss_amount)
                loss_count += 1
                #print(f"Stop Loss, New Balance : {balance}")


        # Filter out all trades that are not active
        trades = [trade for trade in trades if trade['Active'] == 'Y']
    return balance    
    #print(f"Final Balance : {balance} \n Take Profit count : {profit_count} \n Stop Loss count : {loss_count} \n Partial Profit count : {partial_profit_count} \n Partial Loss count : {partial_loss_count}")
    #print(f"Buy count : {buy_count} \n Sell count : {sell_count}")

# %%
def trading_objective(trial):
    params = {
        'trade_enter': trial.suggest_float('trade_enter', 0.1, 2.0),
        'fixed_profit_value': trial.suggest_float('fixed_profit_value', 0.4, 4.0),
        'barNo_before_EOD': trial.suggest_int('barNo_before_EOD', 1, 30),
        'min_bar_enter_trade_before_EOD': trial.suggest_int('min_bar_enter_trade_before_EOD', 5, 30),
        'risk': trial.suggest_float('risk', 0.1, 2.0)
    }

    balance = calculate_trade_optuna(tr_signals, params)

    return balance

# %%
trading_study = optuna.create_study(direction='maximize') # for metric auc its maximuze, and for mlogloss its minimie
trading_study.optimize(trading_objective, n_trials=200)
# Out:
# [I 2025-03-05 10:36:05,021] A new study created in memory with name: no-name-0cb633ff-4881-41a2-a8ce-e0ae2ebea199
# [I 2025-03-05 10:36:05,136] Trial 0 finished with value: -470.12874673424903 and parameters: {'trade_enter': 1.2459225582693338, 'fixed_profit_value': 1.8577484345168043, 'barNo_before_EOD': 11, 'min_bar_enter_trade_before_EOD': 11, 'risk': 1.5007513136966295}. Best is trial 0 with value: -470.12874673424903.
# [I 2025-03-05 10:36:05,234] Trial 1 finished with value: -448.77225239650954 and parameters: {'trade_enter': 0.9448590336559187, 'fixed_profit_value': 0.9774476673055689, 'barNo_before_EOD': 20, 'min_bar_enter_trade_before_EOD': 24, 'risk': 1.6753108839143898}. Best is trial 1 with value: -448.77225239650954.
# [I 2025-03-05 10:36:05,338] Trial 2 finished with value: -1547.1034727714007 and parameters: {'trade_enter': 0.2391006871080238, 'fixed_profit_value': 1.2638158802311763, 'barNo_before_EOD': 5, 'min_bar_enter_trade_before_EOD': 15, 'risk': 1.8200496583848154}. Best is trial 1 with value: -448.77225239650954.
# [I 2025-03-05 10:36:05,435] Trial 3 finished with value: -153.14537233394776 and parameters: {'trade_enter': 1.1514114026996252, 'fixed_profit_value': 2.2225091503778223, 'barNo_before_EOD': 21, 'min_bar_enter_trade_before_EOD': 24, 'risk': 0.985710235005403}. Best is trial 3 with value: -153.14537233394776.
# [I 2025-03-05 10:36:05,530] Trial 4 finished with value: -344.9686627044349 and parameters: {'trade_enter': 1.092167437843224, 'fixed_profit_value': 0.4098726249292451, 'barNo_before_EOD': 23, 'min_bar_enter_trade_before_EOD': 17, 'risk': 1.5775999029383687}. Best is trial 3 with value: -153.14537233394776.
# [I 2025-03-05 10:36:05,630] Trial 5 finished with value: -93.29465886449165 and parameters: {'trade_enter': 0.6485524932477335, 'fixed_profit_value': 2.891152647063685, 'barNo_before_EOD': 23, 'min_bar_enter_trade_before_EOD': 21, 'risk': 0.9004707972892725}. Best is trial 5 with value: -93.29465886449165.
# [I 2025-03-05 10:36:05,724] Trial 6 finished with value: -19.864653145670292 and parameters: {'trade_enter': 1.644974785015478, 'fixed_profit_value': 2.2125887598676255, 'barNo_before_EOD': 14, 'min_bar_enter_trade_before_EOD': 24, 'risk': 1.0158602382586048}. Best is trial 6 with value: -19.864653145670292.
# [I 2025-03-05 10:36:05,826] Trial 7 finished with value: -20.157554289883933 and parameters: {'trade_enter': 0.1762109965681284, 'fixed_profit_value': 3.6272316836601712, 'barNo_before_EOD': 22, 'min_bar_enter_trade_before_EOD': 24, 'risk': 1.2792833028909707}. Best is trial 6 with value: -19.864653145670292.
# [I 2025-03-05 10:36:05,920] Trial 8 finished with value: 63.82120486044154 and parameters: {'trade_enter': 1.491471510426215, 'fixed_profit_value': 3.60657685709659, 'barNo_before_EOD': 13, 'min_bar_enter_trade_before_EOD': 5, 'risk': 1.6410166779540327}. Best is trial 8 with value: 63.82120486044154.
# [I 2025-03-05 10:36:06,014] Trial 9 finished with value: -55.27756456824686 and parameters: {'trade_enter': 1.339226607480552, 'fixed_profit_value': 3.892242768301056, 'barNo_before_EOD': 26, 'min_bar_enter_trade_before_EOD': 17, 'risk': 1.215743353978025}. Best is trial 8 with value: 63.82120486044154.
# [I 2025-03-05 10:36:06,120] Trial 10 finished with value: 52.157833432357236 and parameters: {'trade_enter': 1.9029052466373295, 'fixed_profit_value': 3.1371820753607347, 'barNo_before_EOD': 2, 'min_bar_enter_trade_before_EOD': 5, 'risk': 0.22418469962295584}. Best is trial 8 with value: 63.82120486044154.
# [I 2025-03-05 10:36:06,220] Trial 11 finished with value: -9.085612591613916 and parameters: {'trade_enter': 1.9954810461074142, 'fixed_profit_value': 3.191402070205199, 'barNo_before_EOD': 1, 'min_bar_enter_trade_before_EOD': 5, 'risk': 0.19241377846054875}. Best is trial 8 with value: 63.82120486044154.
# [I 2025-03-05 10:36:06,321] Trial 12 finished with value: 14.322120116247739 and parameters: {'trade_enter': 1.8815790718782792, 'fixed_profit_value': 2.9716634990504507, 'barNo_before_EOD': 8, 'min_bar_enter_trade_before_EOD': 5, 'risk': 0.2000956700522771}. Best is trial 8 with value: 63.82120486044154.
# [I 2025-03-05 10:36:06,424] Trial 13 finished with value: 81.19658265739562 and parameters: {'trade_enter': 1.5815491488046878, 'fixed_profit_value': 3.4472579093367743, 'barNo_before_EOD': 1, 'min_bar_enter_trade_before_EOD': 9, 'risk': 0.5771180366640853}. Best is trial 13 with value: 81.19658265739562.
# [I 2025-03-05 10:36:06,530] Trial 14 finished with value: 81.74391804678001 and parameters: {'trade_enter': 1.53952963368513, 'fixed_profit_value': 3.99088852135331, 'barNo_before_EOD': 15, 'min_bar_enter_trade_before_EOD': 11, 'risk': 0.6349570161354676}. Best is trial 14 with value: 81.74391804678001.
# [I 2025-03-05 10:36:06,634] Trial 15 finished with value: 5.426588085312513 and parameters: {'trade_enter': 1.6138232591644592, 'fixed_profit_value': 3.998913527579802, 'barNo_before_EOD': 17, 'min_bar_enter_trade_before_EOD': 11, 'risk': 0.6172029413605549}. Best is trial 14 with value: 81.74391804678001.
# [I 2025-03-05 10:36:06,742] Trial 16 finished with value: 111.53060613225352 and parameters: {'trade_enter': 0.7179447519799393, 'fixed_profit_value': 2.5845594735967135, 'barNo_before_EOD': 28, 'min_bar_enter_trade_before_EOD': 10, 'risk': 0.6428566090182766}. Best is trial 16 with value: 111.53060613225352.
# [I 2025-03-05 10:36:06,853] Trial 17 finished with value: 87.28125395022339 and parameters: {'trade_enter': 0.7673147973190533, 'fixed_profit_value': 2.693642740065303, 'barNo_before_EOD': 30, 'min_bar_enter_trade_before_EOD': 10, 'risk': 0.6226721092579244}. Best is trial 16 with value: 111.53060613225352.
# [I 2025-03-05 10:36:06,960] Trial 18 finished with value: 143.9972704106206 and parameters: {'trade_enter': 0.708982428555757, 'fixed_profit_value': 2.580681531759879, 'barNo_before_EOD': 30, 'min_bar_enter_trade_before_EOD': 29, 'risk': 0.46584653417903943}. Best is trial 18 with value: 143.9972704106206.
# [I 2025-03-05 10:36:07,069] Trial 19 finished with value: 298.71690986754464 and parameters: {'trade_enter': 0.48746616323597725, 'fixed_profit_value': 2.5655511818693064, 'barNo_before_EOD': 30, 'min_bar_enter_trade_before_EOD': 30, 'risk': 0.4272682570206999}. Best is trial 19 with value: 298.71690986754464.
# [I 2025-03-05 10:36:07,177] Trial 20 finished with value: 315.27612808099695 and parameters: {'trade_enter': 0.48785809208030734, 'fixed_profit_value': 1.788571781899313, 'barNo_before_EOD': 26, 'min_bar_enter_trade_before_EOD': 30, 'risk': 0.3985762498550143}. Best is trial 20 with value: 315.27612808099695.
# [I 2025-03-05 10:36:07,285] Trial 21 finished with value: 355.15018424823205 and parameters: {'trade_enter': 0.43339949910023406, 'fixed_profit_value': 1.8558019599471602, 'barNo_before_EOD': 30, 'min_bar_enter_trade_before_EOD': 30, 'risk': 0.4124071642536978}. Best is trial 21 with value: 355.15018424823205.
# [I 2025-03-05 10:36:07,392] Trial 22 finished with value: 314.32519351262226 and parameters: {'trade_enter': 0.46424485609625776, 'fixed_profit_value': 1.657106929147078, 'barNo_before_EOD': 26, 'min_bar_enter_trade_before_EOD': 30, 'risk': 0.3722402322705869}. Best is trial 21 with value: 355.15018424823205.
# [I 2025-03-05 10:36:07,506] Trial 23 finished with value: 0.4158843432714008 and parameters: {'trade_enter': 0.3700076755240616, 'fixed_profit_value': 1.6510720447774474, 'barNo_before_EOD': 26, 'min_bar_enter_trade_before_EOD': 27, 'risk': 0.8081028386729483}. Best is trial 21 with value: 355.15018424823205.
# [I 2025-03-05 10:36:07,614] Trial 24 finished with value: 320.969730299268 and parameters: {'trade_enter': 0.4229506454047294, 'fixed_profit_value': 1.699094925300598, 'barNo_before_EOD': 26, 'min_bar_enter_trade_before_EOD': 28, 'risk': 0.3485539997801454}. Best is trial 21 with value: 355.15018424823205.
# [I 2025-03-05 10:36:07,719] Trial 25 finished with value: 186.09699613546854 and parameters: {'trade_enter': 0.9071518990882427, 'fixed_profit_value': 1.1548086295959201, 'barNo_before_EOD': 19, 'min_bar_enter_trade_before_EOD': 27, 'risk': 0.3544295188105051}. Best is trial 21 with value: 355.15018424823205.
# [I 2025-03-05 10:36:07,829] Trial 26 finished with value: 157.0914470225429 and parameters: {'trade_enter': 0.10773459499209809, 'fixed_profit_value': 1.9565408311137158, 'barNo_before_EOD': 25, 'min_bar_enter_trade_before_EOD': 27, 'risk': 0.7988502429465185}. Best is trial 21 with value: 355.15018424823205.
# [I 2025-03-05 10:36:07,938] Trial 27 finished with value: 534.4780287473072 and parameters: {'trade_enter': 0.33062083334886083, 'fixed_profit_value': 1.435616214200914, 'barNo_before_EOD': 18, 'min_bar_enter_trade_before_EOD': 21, 'risk': 0.14647851821680574}. Best is trial 27 with value: 534.4780287473072.
# [I 2025-03-05 10:36:08,055] Trial 28 finished with value: 570.4163845635849 and parameters: {'trade_enter': 0.24783434379087518, 'fixed_profit_value': 1.322031323822162, 'barNo_before_EOD': 17, 'min_bar_enter_trade_before_EOD': 21, 'risk': 0.10927918603265559}. Best is trial 28 with value: 570.4163845635849.
# [I 2025-03-05 10:36:08,172] Trial 29 finished with value: 645.8327679705708 and parameters: {'trade_enter': 0.3024963645310927, 'fixed_profit_value': 0.6819354368743857, 'barNo_before_EOD': 10, 'min_bar_enter_trade_before_EOD': 20, 'risk': 0.12526581096072253}. Best is trial 29 with value: 645.8327679705708.
# [I 2025-03-05 10:36:08,289] Trial 30 finished with value: 650.3031523696258 and parameters: {'trade_enter': 0.26528092874983933, 'fixed_profit_value': 0.8321139285699196, 'barNo_before_EOD': 10, 'min_bar_enter_trade_before_EOD': 20, 'risk': 0.15574802771413823}. Best is trial 30 with value: 650.3031523696258.
# [I 2025-03-05 10:36:08,404] Trial 31 finished with value: 625.6650819491454 and parameters: {'trade_enter': 0.2627664698783879, 'fixed_profit_value': 0.7186390578563526, 'barNo_before_EOD': 11, 'min_bar_enter_trade_before_EOD': 20, 'risk': 0.1275503214335867}. Best is trial 30 with value: 650.3031523696258.
# [I 2025-03-05 10:36:08,517] Trial 32 finished with value: 643.8871466201806 and parameters: {'trade_enter': 0.28905413285856063, 'fixed_profit_value': 0.6750532585994952, 'barNo_before_EOD': 10, 'min_bar_enter_trade_before_EOD': 20, 'risk': 0.12024076103569917}. Best is trial 30 with value: 650.3031523696258.
# [I 2025-03-05 10:36:08,626] Trial 33 finished with value: 477.4946658322462 and parameters: {'trade_enter': 0.5959429985563247, 'fixed_profit_value': 0.6708376414679434, 'barNo_before_EOD': 10, 'min_bar_enter_trade_before_EOD': 20, 'risk': 0.2504170070525546}. Best is trial 30 with value: 650.3031523696258.
# [I 2025-03-05 10:36:08,739] Trial 34 finished with value: 406.1767492185282 and parameters: {'trade_enter': 0.27499760110970933, 'fixed_profit_value': 0.8869220011873897, 'barNo_before_EOD': 7, 'min_bar_enter_trade_before_EOD': 19, 'risk': 0.26016713772704103}. Best is trial 30 with value: 650.3031523696258.
# [I 2025-03-05 10:36:08,852] Trial 35 finished with value: -3324.979811715999 and parameters: {'trade_enter': 0.17596158266782286, 'fixed_profit_value': 0.4352267004422806, 'barNo_before_EOD': 11, 'min_bar_enter_trade_before_EOD': 15, 'risk': 1.9181972926090183}. Best is trial 30 with value: 650.3031523696258.
# [I 2025-03-05 10:36:08,965] Trial 36 finished with value: 704.4413705609593 and parameters: {'trade_enter': 0.10231928879002739, 'fixed_profit_value': 0.8331949607506259, 'barNo_before_EOD': 5, 'min_bar_enter_trade_before_EOD': 15, 'risk': 0.11749743474975949}. Best is trial 36 with value: 704.4413705609593.
# [I 2025-03-05 10:36:09,079] Trial 37 finished with value: 377.96912253390974 and parameters: {'trade_enter': 0.11233778480803591, 'fixed_profit_value': 0.9847160256274532, 'barNo_before_EOD': 4, 'min_bar_enter_trade_before_EOD': 14, 'risk': 0.2867317270179573}. Best is trial 36 with value: 704.4413705609593.
# [I 2025-03-05 10:36:09,186] Trial 38 finished with value: 68.94608118804851 and parameters: {'trade_enter': 0.848647579284217, 'fixed_profit_value': 0.636381529122814, 'barNo_before_EOD': 6, 'min_bar_enter_trade_before_EOD': 13, 'risk': 0.5050806194835523}. Best is trial 36 with value: 704.4413705609593.
# [I 2025-03-05 10:36:09,296] Trial 39 finished with value: -410.9664411167154 and parameters: {'trade_enter': 0.5823922822871805, 'fixed_profit_value': 1.0793978926495833, 'barNo_before_EOD': 9, 'min_bar_enter_trade_before_EOD': 18, 'risk': 1.260090935910187}. Best is trial 36 with value: 704.4413705609593.
# [I 2025-03-05 10:36:09,405] Trial 40 finished with value: 729.1390465373561 and parameters: {'trade_enter': 0.5530879308518195, 'fixed_profit_value': 0.8441549197824942, 'barNo_before_EOD': 13, 'min_bar_enter_trade_before_EOD': 23, 'risk': 0.10257303373370058}. Best is trial 40 with value: 729.1390465373561.
# [I 2025-03-05 10:36:09,516] Trial 41 finished with value: 766.5151574518809 and parameters: {'trade_enter': 0.33294783981004605, 'fixed_profit_value': 0.8025980244579585, 'barNo_before_EOD': 13, 'min_bar_enter_trade_before_EOD': 23, 'risk': 0.10466129001640778}. Best is trial 41 with value: 766.5151574518809.
# [I 2025-03-05 10:36:09,627] Trial 42 finished with value: 495.2318114396684 and parameters: {'trade_enter': 0.191753787065512, 'fixed_profit_value': 0.9012416558782396, 'barNo_before_EOD': 13, 'min_bar_enter_trade_before_EOD': 23, 'risk': 0.2662866144482985}. Best is trial 41 with value: 766.5151574518809.
# [I 2025-03-05 10:36:09,738] Trial 43 finished with value: 558.3251534752106 and parameters: {'trade_enter': 0.5543326050539178, 'fixed_profit_value': 0.41989741337699094, 'barNo_before_EOD': 4, 'min_bar_enter_trade_before_EOD': 25, 'risk': 0.10060898586179118}. Best is trial 41 with value: 766.5151574518809.
# [I 2025-03-05 10:36:09,852] Trial 44 finished with value: -676.4807445085316 and parameters: {'trade_enter': 0.3752475497610651, 'fixed_profit_value': 1.31481024634123, 'barNo_before_EOD': 13, 'min_bar_enter_trade_before_EOD': 23, 'risk': 1.3820481113544083}. Best is trial 41 with value: 766.5151574518809.
# [I 2025-03-05 10:36:09,958] Trial 45 finished with value: 187.68375187284764 and parameters: {'trade_enter': 1.154442446694669, 'fixed_profit_value': 0.8103124436724228, 'barNo_before_EOD': 8, 'min_bar_enter_trade_before_EOD': 16, 'risk': 0.3227030138253907}. Best is trial 41 with value: 766.5151574518809.
# [I 2025-03-05 10:36:10,069] Trial 46 finished with value: -928.2515638527241 and parameters: {'trade_enter': 0.3447509827010885, 'fixed_profit_value': 0.5608889628994633, 'barNo_before_EOD': 15, 'min_bar_enter_trade_before_EOD': 25, 'risk': 1.1343208481790292}. Best is trial 41 with value: 766.5151574518809.
# [I 2025-03-05 10:36:10,181] Trial 47 finished with value: 536.0165030017943 and parameters: {'trade_enter': 0.15071433356489475, 'fixed_profit_value': 1.1405618643271709, 'barNo_before_EOD': 12, 'min_bar_enter_trade_before_EOD': 18, 'risk': 0.20691544395824857}. Best is trial 41 with value: 766.5151574518809.
# [I 2025-03-05 10:36:10,294] Trial 48 finished with value: 177.6454482974072 and parameters: {'trade_enter': 0.198401245745022, 'fixed_profit_value': 1.5063824172321265, 'barNo_before_EOD': 6, 'min_bar_enter_trade_before_EOD': 22, 'risk': 0.5397083874621151}. Best is trial 41 with value: 766.5151574518809.
# [I 2025-03-05 10:36:10,405] Trial 49 finished with value: 505.51356474079694 and parameters: {'trade_enter': 0.6338597262262577, 'fixed_profit_value': 1.0520574189407643, 'barNo_before_EOD': 14, 'min_bar_enter_trade_before_EOD': 16, 'risk': 0.18738984316084328}. Best is trial 41 with value: 766.5151574518809.
# [I 2025-03-05 10:36:10,509] Trial 50 finished with value: 197.19630985669744 and parameters: {'trade_enter': 1.3831487577328505, 'fixed_profit_value': 0.8347028984442623, 'barNo_before_EOD': 16, 'min_bar_enter_trade_before_EOD': 22, 'risk': 0.18888180978935432}. Best is trial 41 with value: 766.5151574518809.
# [I 2025-03-05 10:36:10,621] Trial 51 finished with value: 804.8608871154197 and parameters: {'trade_enter': 0.3030622223739877, 'fixed_profit_value': 0.5382636907736691, 'barNo_before_EOD': 10, 'min_bar_enter_trade_before_EOD': 19, 'risk': 0.10492784465701134}. Best is trial 51 with value: 804.8608871154197.
# [I 2025-03-05 10:36:10,736] Trial 52 finished with value: 420.4067829918809 and parameters: {'trade_enter': 0.30491165823459954, 'fixed_profit_value': 0.5090979812607715, 'barNo_before_EOD': 9, 'min_bar_enter_trade_before_EOD': 19, 'risk': 0.2870336731226305}. Best is trial 51 with value: 804.8608871154197.
# [I 2025-03-05 10:36:10,846] Trial 53 finished with value: 556.7159770816368 and parameters: {'trade_enter': 0.53957542713015, 'fixed_profit_value': 0.7562522991284936, 'barNo_before_EOD': 12, 'min_bar_enter_trade_before_EOD': 25, 'risk': 0.18567436150009142}. Best is trial 51 with value: 804.8608871154197.
# [I 2025-03-05 10:36:10,959] Trial 54 finished with value: 339.414544069759 and parameters: {'trade_enter': 0.4007237560025576, 'fixed_profit_value': 0.5595930353198657, 'barNo_before_EOD': 8, 'min_bar_enter_trade_before_EOD': 17, 'risk': 0.30042811222487176}. Best is trial 51 with value: 804.8608871154197.
# [I 2025-03-05 10:36:11,071] Trial 55 finished with value: 662.1403391781563 and parameters: {'trade_enter': 0.20543507855476487, 'fixed_profit_value': 1.2247171311036158, 'barNo_before_EOD': 14, 'min_bar_enter_trade_before_EOD': 23, 'risk': 0.10046319523077007}. Best is trial 51 with value: 804.8608871154197.
# [I 2025-03-05 10:36:11,178] Trial 56 finished with value: 247.52002030104762 and parameters: {'trade_enter': 1.0228512100367944, 'fixed_profit_value': 2.0690988223305835, 'barNo_before_EOD': 14, 'min_bar_enter_trade_before_EOD': 23, 'risk': 0.46725547109258375}. Best is trial 51 with value: 804.8608871154197.
# [I 2025-03-05 10:36:11,291] Trial 57 finished with value: -1689.1673349775801 and parameters: {'trade_enter': 0.10112156789079037, 'fixed_profit_value': 0.9565119856651305, 'barNo_before_EOD': 3, 'min_bar_enter_trade_before_EOD': 22, 'risk': 1.7154559779771565}. Best is trial 51 with value: 804.8608871154197.
# [I 2025-03-05 10:36:11,406] Trial 58 finished with value: 41.741020870416705 and parameters: {'trade_enter': 0.1908088203286581, 'fixed_profit_value': 1.2407125215189772, 'barNo_before_EOD': 21, 'min_bar_enter_trade_before_EOD': 24, 'risk': 0.7065650813645559}. Best is trial 51 with value: 804.8608871154197.
# [I 2025-03-05 10:36:11,515] Trial 59 finished with value: 534.2637020596902 and parameters: {'trade_enter': 0.5109151272923832, 'fixed_profit_value': 1.4547843109621106, 'barNo_before_EOD': 15, 'min_bar_enter_trade_before_EOD': 26, 'risk': 0.22098971750798238}. Best is trial 51 with value: 804.8608871154197.
# [I 2025-03-05 10:36:11,629] Trial 60 finished with value: 565.4792902928201 and parameters: {'trade_enter': 0.2206417928398577, 'fixed_profit_value': 1.2053039041099747, 'barNo_before_EOD': 16, 'min_bar_enter_trade_before_EOD': 13, 'risk': 0.17311516373070823}. Best is trial 51 with value: 804.8608871154197.
# [I 2025-03-05 10:36:11,740] Trial 61 finished with value: 710.0080445477771 and parameters: {'trade_enter': 0.32703538713362834, 'fixed_profit_value': 0.9972663575164433, 'barNo_before_EOD': 12, 'min_bar_enter_trade_before_EOD': 19, 'risk': 0.10215052412283125}. Best is trial 51 with value: 804.8608871154197.
# [I 2025-03-05 10:36:11,854] Trial 62 finished with value: 337.761635804276 and parameters: {'trade_enter': 0.4214269065681289, 'fixed_profit_value': 1.0318232096952211, 'barNo_before_EOD': 12, 'min_bar_enter_trade_before_EOD': 19, 'risk': 0.3420866662237035}. Best is trial 51 with value: 804.8608871154197.
# [I 2025-03-05 10:36:11,965] Trial 63 finished with value: 559.846385097676 and parameters: {'trade_enter': 0.3609470574951222, 'fixed_profit_value': 0.8898061194689765, 'barNo_before_EOD': 14, 'min_bar_enter_trade_before_EOD': 21, 'risk': 0.2379094674544192}. Best is trial 51 with value: 804.8608871154197.
# [I 2025-03-05 10:36:12,068] Trial 64 finished with value: 26.7101977233002 and parameters: {'trade_enter': 1.7305310294938305, 'fixed_profit_value': 0.7810192349338713, 'barNo_before_EOD': 12, 'min_bar_enter_trade_before_EOD': 16, 'risk': 0.14524345547167303}. Best is trial 51 with value: 804.8608871154197.
# [I 2025-03-05 10:36:12,181] Trial 65 finished with value: 805.2960596750189 and parameters: {'trade_enter': 0.25747915303154084, 'fixed_profit_value': 0.5257870033354133, 'barNo_before_EOD': 9, 'min_bar_enter_trade_before_EOD': 18, 'risk': 0.1014383718439914}. Best is trial 65 with value: 805.2960596750189.
# [I 2025-03-05 10:36:12,290] Trial 66 finished with value: -573.063821611399 and parameters: {'trade_enter': 0.699321005583555, 'fixed_profit_value': 0.5477298842656098, 'barNo_before_EOD': 9, 'min_bar_enter_trade_before_EOD': 18, 'risk': 0.9478995071106454}. Best is trial 65 with value: 805.2960596750189.
# [I 2025-03-05 10:36:12,402] Trial 67 finished with value: 179.84169071522965 and parameters: {'trade_enter': 0.45763906337378785, 'fixed_profit_value': 0.44287027909959126, 'barNo_before_EOD': 6, 'min_bar_enter_trade_before_EOD': 17, 'risk': 0.4043555384894743}. Best is trial 65 with value: 805.2960596750189.
# [I 2025-03-05 10:36:12,515] Trial 68 finished with value: 461.2611851023755 and parameters: {'trade_enter': 0.24096559304070236, 'fixed_profit_value': 2.426130321567226, 'barNo_before_EOD': 13, 'min_bar_enter_trade_before_EOD': 15, 'risk': 0.11311823166837978}. Best is trial 65 with value: 805.2960596750189.
# [I 2025-03-05 10:36:12,629] Trial 69 finished with value: -2202.760531029594 and parameters: {'trade_enter': 0.14291588619297405, 'fixed_profit_value': 0.6353711851507832, 'barNo_before_EOD': 11, 'min_bar_enter_trade_before_EOD': 13, 'risk': 1.5108517372722543}. Best is trial 65 with value: 805.2960596750189.
# [I 2025-03-05 10:36:12,741] Trial 70 finished with value: 465.0371153404075 and parameters: {'trade_enter': 0.32650424918596854, 'fixed_profit_value': 1.37302278088436, 'barNo_before_EOD': 18, 'min_bar_enter_trade_before_EOD': 22, 'risk': 0.23168824352952122}. Best is trial 65 with value: 805.2960596750189.
# [I 2025-03-05 10:36:12,857] Trial 71 finished with value: 591.9067519418261 and parameters: {'trade_enter': 0.25193619755871294, 'fixed_profit_value': 0.8013918039546806, 'barNo_before_EOD': 10, 'min_bar_enter_trade_before_EOD': 20, 'risk': 0.1637319670036446}. Best is trial 65 with value: 805.2960596750189.
# [I 2025-03-05 10:36:12,972] Trial 72 finished with value: 682.8679282087536 and parameters: {'trade_enter': 0.2960794677130916, 'fixed_profit_value': 0.9543692820938503, 'barNo_before_EOD': 7, 'min_bar_enter_trade_before_EOD': 19, 'risk': 0.10600282355669564}. Best is trial 65 with value: 805.2960596750189.
# [I 2025-03-05 10:36:13,082] Trial 73 finished with value: 733.5684763078933 and parameters: {'trade_enter': 0.39732060199170205, 'fixed_profit_value': 0.9619725399511774, 'barNo_before_EOD': 8, 'min_bar_enter_trade_before_EOD': 19, 'risk': 0.10009393744444273}. Best is trial 65 with value: 805.2960596750189.
# [I 2025-03-05 10:36:13,194] Trial 74 finished with value: 449.98702683586424 and parameters: {'trade_enter': 0.4573519311617976, 'fixed_profit_value': 0.9710893590828984, 'barNo_before_EOD': 7, 'min_bar_enter_trade_before_EOD': 19, 'risk': 0.3198031635996892}. Best is trial 65 with value: 805.2960596750189.
# [I 2025-03-05 10:36:13,309] Trial 75 finished with value: 484.2871901589221 and parameters: {'trade_enter': 0.40833357459038033, 'fixed_profit_value': 1.1260139448640951, 'barNo_before_EOD': 5, 'min_bar_enter_trade_before_EOD': 17, 'risk': 0.23129022236427282}. Best is trial 65 with value: 805.2960596750189.
# [I 2025-03-05 10:36:13,425] Trial 76 finished with value: 760.6331540278362 and parameters: {'trade_enter': 0.32468624653455824, 'fixed_profit_value': 0.603269569046375, 'barNo_before_EOD': 7, 'min_bar_enter_trade_before_EOD': 18, 'risk': 0.10021911598632205}. Best is trial 65 with value: 805.2960596750189.
# [I 2025-03-05 10:36:13,537] Trial 77 finished with value: 246.70874291963648 and parameters: {'trade_enter': 0.4926071039079042, 'fixed_profit_value': 0.6162972144069191, 'barNo_before_EOD': 9, 'min_bar_enter_trade_before_EOD': 7, 'risk': 0.36915485511552987}. Best is trial 65 with value: 805.2960596750189.
# [I 2025-03-05 10:36:13,646] Trial 78 finished with value: 119.85706377010258 and parameters: {'trade_enter': 0.8020465030608187, 'fixed_profit_value': 0.4810968605496083, 'barNo_before_EOD': 5, 'min_bar_enter_trade_before_EOD': 14, 'risk': 0.44291898300912325}. Best is trial 65 with value: 805.2960596750189.
# [I 2025-03-05 10:36:13,759] Trial 79 finished with value: 612.7691727765865 and parameters: {'trade_enter': 0.15153960254444301, 'fixed_profit_value': 0.7021821663320478, 'barNo_before_EOD': 8, 'min_bar_enter_trade_before_EOD': 18, 'risk': 0.16497284930124048}. Best is trial 65 with value: 805.2960596750189.
# [I 2025-03-05 10:36:13,873] Trial 80 finished with value: 474.22630382206626 and parameters: {'trade_enter': 0.36134768746607365, 'fixed_profit_value': 0.741874388669814, 'barNo_before_EOD': 3, 'min_bar_enter_trade_before_EOD': 14, 'risk': 0.2657145982725543}. Best is trial 65 with value: 805.2960596750189.
# [I 2025-03-05 10:36:13,985] Trial 81 finished with value: 719.8446111719143 and parameters: {'trade_enter': 0.29821242167672113, 'fixed_profit_value': 0.8907166796610022, 'barNo_before_EOD': 7, 'min_bar_enter_trade_before_EOD': 19, 'risk': 0.10282019331782193}. Best is trial 65 with value: 805.2960596750189.
# [I 2025-03-05 10:36:14,097] Trial 82 finished with value: 685.4014351256994 and parameters: {'trade_enter': 0.3318863011328791, 'fixed_profit_value': 0.5940857642532584, 'barNo_before_EOD': 7, 'min_bar_enter_trade_before_EOD': 21, 'risk': 0.16094898573843702}. Best is trial 65 with value: 805.2960596750189.
# [I 2025-03-05 10:36:14,210] Trial 83 finished with value: 683.8475489322976 and parameters: {'trade_enter': 0.2755675372444377, 'fixed_profit_value': 0.8983499937396255, 'barNo_before_EOD': 11, 'min_bar_enter_trade_before_EOD': 18, 'risk': 0.10014731113912115}. Best is trial 65 with value: 805.2960596750189.
# [I 2025-03-05 10:36:14,326] Trial 84 finished with value: 542.4421849467058 and parameters: {'trade_enter': 0.39597600014938517, 'fixed_profit_value': 0.42456903371743904, 'barNo_before_EOD': 8, 'min_bar_enter_trade_before_EOD': 16, 'risk': 0.21234651101333926}. Best is trial 65 with value: 805.2960596750189.
# [I 2025-03-05 10:36:14,435] Trial 85 finished with value: 349.8683509545654 and parameters: {'trade_enter': 0.6533201045126023, 'fixed_profit_value': 1.0698138853601424, 'barNo_before_EOD': 4, 'min_bar_enter_trade_before_EOD': 19, 'risk': 0.28793148265321994}. Best is trial 65 with value: 805.2960596750189.
# [I 2025-03-05 10:36:14,548] Trial 86 finished with value: 660.0697529843109 and parameters: {'trade_enter': 0.21586815778637847, 'fixed_profit_value': 0.844347013587089, 'barNo_before_EOD': 6, 'min_bar_enter_trade_before_EOD': 21, 'risk': 0.15481740718635378}. Best is trial 65 with value: 805.2960596750189.
# [I 2025-03-05 10:36:14,661] Trial 87 finished with value: 575.2271755891951 and parameters: {'trade_enter': 0.1404655917259735, 'fixed_profit_value': 0.6619896107521698, 'barNo_before_EOD': 10, 'min_bar_enter_trade_before_EOD': 17, 'risk': 0.20806359391028217}. Best is trial 65 with value: 805.2960596750189.
# [I 2025-03-05 10:36:14,771] Trial 88 finished with value: 380.2945823390202 and parameters: {'trade_enter': 0.546020174821952, 'fixed_profit_value': 0.5285824762986653, 'barNo_before_EOD': 9, 'min_bar_enter_trade_before_EOD': 20, 'risk': 0.26822261836904604}. Best is trial 65 with value: 805.2960596750189.
# [I 2025-03-05 10:36:14,882] Trial 89 finished with value: 598.1094554166895 and parameters: {'trade_enter': 0.4406474152499582, 'fixed_profit_value': 0.764489731364471, 'barNo_before_EOD': 13, 'min_bar_enter_trade_before_EOD': 15, 'risk': 0.1445328102606667}. Best is trial 65 with value: 805.2960596750189.
# [I 2025-03-05 10:36:14,993] Trial 90 finished with value: 334.4659752736821 and parameters: {'trade_enter': 0.3390620771808945, 'fixed_profit_value': 1.5539293877462828, 'barNo_before_EOD': 11, 'min_bar_enter_trade_before_EOD': 18, 'risk': 0.3429205610255228}. Best is trial 65 with value: 805.2960596750189.
# [I 2025-03-05 10:36:15,104] Trial 91 finished with value: 594.5448326763972 and parameters: {'trade_enter': 0.3162240441100914, 'fixed_profit_value': 0.6463760973779035, 'barNo_before_EOD': 7, 'min_bar_enter_trade_before_EOD': 21, 'risk': 0.163158166222303}. Best is trial 65 with value: 805.2960596750189.
# [I 2025-03-05 10:36:15,219] Trial 92 finished with value: 476.6361907175519 and parameters: {'trade_enter': 0.3699532763120289, 'fixed_profit_value': 0.5320782420431536, 'barNo_before_EOD': 7, 'min_bar_enter_trade_before_EOD': 24, 'risk': 0.18924510744953718}. Best is trial 65 with value: 805.2960596750189.
# [I 2025-03-05 10:36:15,332] Trial 93 finished with value: 780.4014956727142 and parameters: {'trade_enter': 0.24952081796900064, 'fixed_profit_value': 0.580148868492681, 'barNo_before_EOD': 6, 'min_bar_enter_trade_before_EOD': 21, 'risk': 0.1000919132421557}. Best is trial 65 with value: 805.2960596750189.
# [I 2025-03-05 10:36:15,444] Trial 94 finished with value: -1172.605864901534 and parameters: {'trade_enter': 0.2828593496988616, 'fixed_profit_value': 0.4026765898544342, 'barNo_before_EOD': 5, 'min_bar_enter_trade_before_EOD': 22, 'risk': 1.0907296149604966}. Best is trial 65 with value: 805.2960596750189.
# [I 2025-03-05 10:36:15,557] Trial 95 finished with value: 591.4563054738022 and parameters: {'trade_enter': 0.23934020273986195, 'fixed_profit_value': 1.022343705441676, 'barNo_before_EOD': 6, 'min_bar_enter_trade_before_EOD': 20, 'risk': 0.13362162721727766}. Best is trial 65 with value: 805.2960596750189.
# [I 2025-03-05 10:36:15,692] Trial 96 finished with value: 368.9169277644648 and parameters: {'trade_enter': 0.1659386005666055, 'fixed_profit_value': 3.3867141820165005, 'barNo_before_EOD': 8, 'min_bar_enter_trade_before_EOD': 24, 'risk': 0.10171614793658677}. Best is trial 65 with value: 805.2960596750189.
# [I 2025-03-05 10:36:15,803] Trial 97 finished with value: 367.69136248183787 and parameters: {'trade_enter': 0.5176318477738873, 'fixed_profit_value': 0.7172702775065469, 'barNo_before_EOD': 5, 'min_bar_enter_trade_before_EOD': 19, 'risk': 0.24074072380622974}. Best is trial 65 with value: 805.2960596750189.
# [I 2025-03-05 10:36:15,916] Trial 98 finished with value: 620.8633502735173 and parameters: {'trade_enter': 0.2155966406262951, 'fixed_profit_value': 0.918582751289958, 'barNo_before_EOD': 9, 'min_bar_enter_trade_before_EOD': 23, 'risk': 0.20099444646454745}. Best is trial 65 with value: 805.2960596750189.
# [I 2025-03-05 10:36:16,028] Trial 99 finished with value: 664.8921919488697 and parameters: {'trade_enter': 0.10483979438380611, 'fixed_profit_value': 0.825491057298935, 'barNo_before_EOD': 2, 'min_bar_enter_trade_before_EOD': 16, 'risk': 0.1417827244963314}. Best is trial 65 with value: 805.2960596750189.
# [I 2025-03-05 10:36:16,142] Trial 100 finished with value: 336.37408892620107 and parameters: {'trade_enter': 0.4035497141549586, 'fixed_profit_value': 0.5111132312120119, 'barNo_before_EOD': 12, 'min_bar_enter_trade_before_EOD': 17, 'risk': 0.3103747836482673}. Best is trial 65 with value: 805.2960596750189.
# [I 2025-03-05 10:36:16,254] Trial 101 finished with value: 709.818950402785 and parameters: {'trade_enter': 0.3266023133985533, 'fixed_profit_value': 0.5888387316924597, 'barNo_before_EOD': 7, 'min_bar_enter_trade_before_EOD': 21, 'risk': 0.14650393953843613}. Best is trial 65 with value: 805.2960596750189.
# [I 2025-03-05 10:36:16,369] Trial 102 finished with value: 566.1481966067995 and parameters: {'trade_enter': 0.2969793576211598, 'fixed_profit_value': 0.61803542823643, 'barNo_before_EOD': 8, 'min_bar_enter_trade_before_EOD': 20, 'risk': 0.2006640764524285}. Best is trial 65 with value: 805.2960596750189.
# [I 2025-03-05 10:36:16,510] Trial 103 finished with value: 392.0293367002739 and parameters: {'trade_enter': 0.2600027487084696, 'fixed_profit_value': 0.7365922471005257, 'barNo_before_EOD': 4, 'min_bar_enter_trade_before_EOD': 21, 'risk': 0.2564235323168514}. Best is trial 65 with value: 805.2960596750189.
# [I 2025-03-05 10:36:16,623] Trial 104 finished with value: 677.0201905317849 and parameters: {'trade_enter': 0.1895779248245779, 'fixed_profit_value': 0.861195324589946, 'barNo_before_EOD': 6, 'min_bar_enter_trade_before_EOD': 19, 'risk': 0.12959721157354023}. Best is trial 65 with value: 805.2960596750189.
# [I 2025-03-05 10:36:16,735] Trial 105 finished with value: 700.5924990791165 and parameters: {'trade_enter': 0.47219424080948014, 'fixed_profit_value': 0.5808727720109625, 'barNo_before_EOD': 10, 'min_bar_enter_trade_before_EOD': 18, 'risk': 0.10433904543353925}. Best is trial 65 with value: 805.2960596750189.
# [I 2025-03-05 10:36:16,847] Trial 106 finished with value: 560.9360269596406 and parameters: {'trade_enter': 0.37412358815360136, 'fixed_profit_value': 1.132964148748818, 'barNo_before_EOD': 8, 'min_bar_enter_trade_before_EOD': 20, 'risk': 0.16719787495362978}. Best is trial 65 with value: 805.2960596750189.
# [I 2025-03-05 10:36:16,953] Trial 107 finished with value: 117.97324203622908 and parameters: {'trade_enter': 1.276728021680854, 'fixed_profit_value': 0.6974262794092896, 'barNo_before_EOD': 11, 'min_bar_enter_trade_before_EOD': 22, 'risk': 0.24027378150570955}. Best is trial 65 with value: 805.2960596750189.
# [I 2025-03-05 10:36:17,064] Trial 108 finished with value: 643.3817786462777 and parameters: {'trade_enter': 0.4390365080826849, 'fixed_profit_value': 0.9906495901593525, 'barNo_before_EOD': 7, 'min_bar_enter_trade_before_EOD': 23, 'risk': 0.1947541405237685}. Best is trial 65 with value: 805.2960596750189.
# [I 2025-03-05 10:36:17,177] Trial 109 finished with value: 750.1695881616437 and parameters: {'trade_enter': 0.3211813500816852, 'fixed_profit_value': 0.5001117136003392, 'barNo_before_EOD': 3, 'min_bar_enter_trade_before_EOD': 18, 'risk': 0.1363848617115186}. Best is trial 65 with value: 805.2960596750189.
# [I 2025-03-05 10:36:17,287] Trial 110 finished with value: -473.3241705483774 and parameters: {'trade_enter': 0.5966509303345414, 'fixed_profit_value': 0.4747753803484378, 'barNo_before_EOD': 3, 'min_bar_enter_trade_before_EOD': 19, 'risk': 0.8250788100508769}. Best is trial 65 with value: 805.2960596750189.
# [I 2025-03-05 10:36:17,404] Trial 111 finished with value: 654.5835595238594 and parameters: {'trade_enter': 0.29931508373196947, 'fixed_profit_value': 0.780670283591, 'barNo_before_EOD': 1, 'min_bar_enter_trade_before_EOD': 18, 'risk': 0.14195637592783403}. Best is trial 65 with value: 805.2960596750189.
# [I 2025-03-05 10:36:17,522] Trial 112 finished with value: 797.2323494993857 and parameters: {'trade_enter': 0.228332299684256, 'fixed_profit_value': 0.5693359396456221, 'barNo_before_EOD': 2, 'min_bar_enter_trade_before_EOD': 17, 'risk': 0.10008257945161049}. Best is trial 65 with value: 805.2960596750189.
# [I 2025-03-05 10:36:17,641] Trial 113 finished with value: 571.9808379018458 and parameters: {'trade_enter': 0.35714148317220057, 'fixed_profit_value': 0.49630503233636836, 'barNo_before_EOD': 2, 'min_bar_enter_trade_before_EOD': 17, 'risk': 0.17790463697933662}. Best is trial 65 with value: 805.2960596750189.
# [I 2025-03-05 10:36:17,753] Trial 114 finished with value: 300.3002339597485 and parameters: {'trade_enter': 0.24362034247684006, 'fixed_profit_value': 2.864306570813694, 'barNo_before_EOD': 3, 'min_bar_enter_trade_before_EOD': 18, 'risk': 0.22634491395901024}. Best is trial 65 with value: 805.2960596750189.
# [I 2025-03-05 10:36:17,867] Trial 115 finished with value: 743.9835269602066 and parameters: {'trade_enter': 0.3168501543093218, 'fixed_profit_value': 0.5854913295491901, 'barNo_before_EOD': 1, 'min_bar_enter_trade_before_EOD': 21, 'risk': 0.10042838832605486}. Best is trial 65 with value: 805.2960596750189.
# [I 2025-03-05 10:36:17,979] Trial 116 finished with value: 604.0098159582354 and parameters: {'trade_enter': 0.39445966018636935, 'fixed_profit_value': 0.6871078998069878, 'barNo_before_EOD': 1, 'min_bar_enter_trade_before_EOD': 19, 'risk': 0.12986360041112216}. Best is trial 65 with value: 805.2960596750189.
# [I 2025-03-05 10:36:18,093] Trial 117 finished with value: 347.67201146499553 and parameters: {'trade_enter': 0.23629875908231818, 'fixed_profit_value': 0.41023872990427523, 'barNo_before_EOD': 2, 'min_bar_enter_trade_before_EOD': 20, 'risk': 0.29300321970731863}. Best is trial 65 with value: 805.2960596750189.
# [I 2025-03-05 10:36:18,208] Trial 118 finished with value: 882.1608226627853 and parameters: {'trade_enter': 0.17406887272069027, 'fixed_profit_value': 0.5997028180376043, 'barNo_before_EOD': 1, 'min_bar_enter_trade_before_EOD': 16, 'risk': 0.10143382499008176}. Best is trial 118 with value: 882.1608226627853.
# [I 2025-03-05 10:36:18,323] Trial 119 finished with value: 673.1189437311805 and parameters: {'trade_enter': 0.1774284687621472, 'fixed_profit_value': 0.5618748483143001, 'barNo_before_EOD': 2, 'min_bar_enter_trade_before_EOD': 16, 'risk': 0.1984698333097445}. Best is trial 118 with value: 882.1608226627853.
# [I 2025-03-05 10:36:18,437] Trial 120 finished with value: 453.27645742284847 and parameters: {'trade_enter': 0.14214217775167415, 'fixed_profit_value': 0.6179057077776768, 'barNo_before_EOD': 1, 'min_bar_enter_trade_before_EOD': 17, 'risk': 0.2582122985796019}. Best is trial 118 with value: 882.1608226627853.
# [I 2025-03-05 10:36:18,550] Trial 121 finished with value: 751.7406542422648 and parameters: {'trade_enter': 0.2743562048040115, 'fixed_profit_value': 0.48560884846682284, 'barNo_before_EOD': 3, 'min_bar_enter_trade_before_EOD': 18, 'risk': 0.1006740108840044}. Best is trial 118 with value: 882.1608226627853.
# [I 2025-03-05 10:36:18,662] Trial 122 finished with value: 617.2940250325164 and parameters: {'trade_enter': 0.27805793528283673, 'fixed_profit_value': 0.49495485052770105, 'barNo_before_EOD': 1, 'min_bar_enter_trade_before_EOD': 18, 'risk': 0.16753703536408648}. Best is trial 118 with value: 882.1608226627853.
# [I 2025-03-05 10:36:18,776] Trial 123 finished with value: 827.1107039786064 and parameters: {'trade_enter': 0.21770412391178348, 'fixed_profit_value': 0.4679560382295175, 'barNo_before_EOD': 3, 'min_bar_enter_trade_before_EOD': 17, 'risk': 0.10117722210684645}. Best is trial 118 with value: 882.1608226627853.
# [I 2025-03-05 10:36:18,888] Trial 124 finished with value: 775.3280218041527 and parameters: {'trade_enter': 0.20034080589708145, 'fixed_profit_value': 0.45590324927630943, 'barNo_before_EOD': 4, 'min_bar_enter_trade_before_EOD': 16, 'risk': 0.1410521555705817}. Best is trial 118 with value: 882.1608226627853.
# [I 2025-03-05 10:36:19,003] Trial 125 finished with value: 813.8546201104526 and parameters: {'trade_enter': 0.20845791837367594, 'fixed_profit_value': 0.46683283564764355, 'barNo_before_EOD': 3, 'min_bar_enter_trade_before_EOD': 16, 'risk': 0.14018776402564181}. Best is trial 118 with value: 882.1608226627853.
# [I 2025-03-05 10:36:19,119] Trial 126 finished with value: 752.5229742759283 and parameters: {'trade_enter': 0.1975568850448963, 'fixed_profit_value': 0.45125645350782284, 'barNo_before_EOD': 3, 'min_bar_enter_trade_before_EOD': 15, 'risk': 0.14331715306077103}. Best is trial 118 with value: 882.1608226627853.
# [I 2025-03-05 10:36:19,235] Trial 127 finished with value: 630.4426797906046 and parameters: {'trade_enter': 0.20061381077751353, 'fixed_profit_value': 0.4610843058263077, 'barNo_before_EOD': 3, 'min_bar_enter_trade_before_EOD': 15, 'risk': 0.2109240966342622}. Best is trial 118 with value: 882.1608226627853.
# [I 2025-03-05 10:36:19,351] Trial 128 finished with value: 811.25651710089 and parameters: {'trade_enter': 0.13901415804175005, 'fixed_profit_value': 0.46279605742321217, 'barNo_before_EOD': 4, 'min_bar_enter_trade_before_EOD': 16, 'risk': 0.1507500354109943}. Best is trial 118 with value: 882.1608226627853.
# [I 2025-03-05 10:36:19,468] Trial 129 finished with value: 229.9890240211001 and parameters: {'trade_enter': 0.1510339220296834, 'fixed_profit_value': 0.40436975394783103, 'barNo_before_EOD': 4, 'min_bar_enter_trade_before_EOD': 16, 'risk': 0.384100021862397}. Best is trial 118 with value: 882.1608226627853.
# [I 2025-03-05 10:36:19,583] Trial 130 finished with value: -1910.2660593452604 and parameters: {'trade_enter': 0.19404898943265847, 'fixed_profit_value': 0.47021852857402247, 'barNo_before_EOD': 4, 'min_bar_enter_trade_before_EOD': 14, 'risk': 1.3351863173398564}. Best is trial 118 with value: 882.1608226627853.
# [I 2025-03-05 10:36:19,698] Trial 131 finished with value: 845.9112522855148 and parameters: {'trade_enter': 0.13800501147204988, 'fixed_profit_value': 0.5160661917115488, 'barNo_before_EOD': 3, 'min_bar_enter_trade_before_EOD': 15, 'risk': 0.14265841002574597}. Best is trial 118 with value: 882.1608226627853.
# [I 2025-03-05 10:36:19,812] Trial 132 finished with value: -3435.892781393146 and parameters: {'trade_enter': 0.13005137474787964, 'fixed_profit_value': 0.545315281750976, 'barNo_before_EOD': 2, 'min_bar_enter_trade_before_EOD': 15, 'risk': 1.9923953574607678}. Best is trial 118 with value: 882.1608226627853.
# [I 2025-03-05 10:36:19,925] Trial 133 finished with value: 674.4686164372973 and parameters: {'trade_enter': 0.21966187787438013, 'fixed_profit_value': 0.6717238910471024, 'barNo_before_EOD': 5, 'min_bar_enter_trade_before_EOD': 16, 'risk': 0.1607120526038564}. Best is trial 118 with value: 882.1608226627853.
# [I 2025-03-05 10:36:20,039] Trial 134 finished with value: 702.7959783182673 and parameters: {'trade_enter': 0.1639645066058766, 'fixed_profit_value': 0.4122843953468286, 'barNo_before_EOD': 4, 'min_bar_enter_trade_before_EOD': 14, 'risk': 0.17418507564547472}. Best is trial 118 with value: 882.1608226627853.
# [I 2025-03-05 10:36:20,176] Trial 135 finished with value: 511.8622377230488 and parameters: {'trade_enter': 0.2542728737384942, 'fixed_profit_value': 0.6288877282996674, 'barNo_before_EOD': 3, 'min_bar_enter_trade_before_EOD': 15, 'risk': 0.22271852242108564}. Best is trial 118 with value: 882.1608226627853.
# [I 2025-03-05 10:36:20,290] Trial 136 finished with value: 760.2471979619967 and parameters: {'trade_enter': 0.11833188895229192, 'fixed_profit_value': 0.5126971912600344, 'barNo_before_EOD': 2, 'min_bar_enter_trade_before_EOD': 17, 'risk': 0.13787349582899622}. Best is trial 118 with value: 882.1608226627853.
# [I 2025-03-05 10:36:20,405] Trial 137 finished with value: 487.63658585999735 and parameters: {'trade_enter': 0.11730445741883214, 'fixed_profit_value': 0.5516551759726348, 'barNo_before_EOD': 2, 'min_bar_enter_trade_before_EOD': 17, 'risk': 0.2706197430044469}. Best is trial 118 with value: 882.1608226627853.
# [I 2025-03-05 10:36:20,518] Trial 138 finished with value: 720.8387584903279 and parameters: {'trade_enter': 0.10337899450925206, 'fixed_profit_value': 0.6622825279567379, 'barNo_before_EOD': 2, 'min_bar_enter_trade_before_EOD': 12, 'risk': 0.1505234558968195}. Best is trial 118 with value: 882.1608226627853.
# [I 2025-03-05 10:36:20,631] Trial 139 finished with value: 405.4653191709326 and parameters: {'trade_enter': 0.1875253011371431, 'fixed_profit_value': 0.7454618642922748, 'barNo_before_EOD': 4, 'min_bar_enter_trade_before_EOD': 16, 'risk': 0.31817345221661064}. Best is trial 118 with value: 882.1608226627853.
# [I 2025-03-05 10:36:20,745] Trial 140 finished with value: 637.2057610006918 and parameters: {'trade_enter': 0.1736269547166296, 'fixed_profit_value': 0.40579087192535257, 'barNo_before_EOD': 4, 'min_bar_enter_trade_before_EOD': 15, 'risk': 0.18895717343513269}. Best is trial 118 with value: 882.1608226627853.
# [I 2025-03-05 10:36:20,861] Trial 141 finished with value: 818.2159422938981 and parameters: {'trade_enter': 0.22737591557116243, 'fixed_profit_value': 0.522221388192867, 'barNo_before_EOD': 3, 'min_bar_enter_trade_before_EOD': 16, 'risk': 0.14008349322252658}. Best is trial 118 with value: 882.1608226627853.
# [I 2025-03-05 10:36:20,976] Trial 142 finished with value: 781.5690056997071 and parameters: {'trade_enter': 0.21222625563524494, 'fixed_profit_value': 0.5509727355447198, 'barNo_before_EOD': 5, 'min_bar_enter_trade_before_EOD': 17, 'risk': 0.1407128003222352}. Best is trial 118 with value: 882.1608226627853.
# [I 2025-03-05 10:36:21,092] Trial 143 finished with value: 536.3858158883356 and parameters: {'trade_enter': 0.22851111713941777, 'fixed_profit_value': 0.5674257686164452, 'barNo_before_EOD': 5, 'min_bar_enter_trade_before_EOD': 17, 'risk': 0.22465369520622663}. Best is trial 118 with value: 882.1608226627853.
# [I 2025-03-05 10:36:21,211] Trial 144 finished with value: 670.2217405895179 and parameters: {'trade_enter': 0.14627691013127722, 'fixed_profit_value': 0.6163259674660154, 'barNo_before_EOD': 2, 'min_bar_enter_trade_before_EOD': 16, 'risk': 0.18884423348738716}. Best is trial 118 with value: 882.1608226627853.
# [I 2025-03-05 10:36:21,326] Trial 145 finished with value: 746.2224989806855 and parameters: {'trade_enter': 0.23971114267201454, 'fixed_profit_value': 0.5344142305502154, 'barNo_before_EOD': 6, 'min_bar_enter_trade_before_EOD': 17, 'risk': 0.13769550606153175}. Best is trial 118 with value: 882.1608226627853.
# [I 2025-03-05 10:36:21,440] Trial 146 finished with value: 441.5854933525718 and parameters: {'trade_enter': 0.15566339330449838, 'fixed_profit_value': 2.3229818711602244, 'barNo_before_EOD': 5, 'min_bar_enter_trade_before_EOD': 16, 'risk': 0.24104244786055862}. Best is trial 118 with value: 882.1608226627853.
# [I 2025-03-05 10:36:21,558] Trial 147 finished with value: 558.1156184434052 and parameters: {'trade_enter': 0.10316898582532952, 'fixed_profit_value': 0.7273521110401946, 'barNo_before_EOD': 3, 'min_bar_enter_trade_before_EOD': 17, 'risk': 0.17142284081729442}. Best is trial 118 with value: 882.1608226627853.
# [I 2025-03-05 10:36:21,674] Trial 148 finished with value: 861.0483970595915 and parameters: {'trade_enter': 0.21137003335174634, 'fixed_profit_value': 0.5013605686403717, 'barNo_before_EOD': 4, 'min_bar_enter_trade_before_EOD': 16, 'risk': 0.13606399801482494}. Best is trial 118 with value: 882.1608226627853.
# [I 2025-03-05 10:36:21,794] Trial 149 finished with value: -2540.049700809229 and parameters: {'trade_enter': 0.25954683584934796, 'fixed_profit_value': 0.6664178996761936, 'barNo_before_EOD': 4, 'min_bar_enter_trade_before_EOD': 14, 'risk': 1.728209013653128}. Best is trial 118 with value: 882.1608226627853.
# [I 2025-03-05 10:36:21,904] Trial 150 finished with value: 393.47313378946495 and parameters: {'trade_enter': 1.0032094521734487, 'fixed_profit_value': 3.7378047542282045, 'barNo_before_EOD': 6, 'min_bar_enter_trade_before_EOD': 16, 'risk': 0.10197927177260906}. Best is trial 118 with value: 882.1608226627853.
# [I 2025-03-05 10:36:22,019] Trial 151 finished with value: 824.1968446860348 and parameters: {'trade_enter': 0.22818857101588275, 'fixed_profit_value': 0.5223165806090958, 'barNo_before_EOD': 4, 'min_bar_enter_trade_before_EOD': 16, 'risk': 0.13597350146308154}. Best is trial 118 with value: 882.1608226627853.
# [I 2025-03-05 10:36:22,135] Trial 152 finished with value: 770.4908913580438 and parameters: {'trade_enter': 0.2216197855841816, 'fixed_profit_value': 0.5866965087113261, 'barNo_before_EOD': 4, 'min_bar_enter_trade_before_EOD': 15, 'risk': 0.13731368474652178}. Best is trial 118 with value: 882.1608226627853.
# [I 2025-03-05 10:36:22,250] Trial 153 finished with value: 704.7835161194155 and parameters: {'trade_enter': 0.21821712401877696, 'fixed_profit_value': 0.47614589652068917, 'barNo_before_EOD': 5, 'min_bar_enter_trade_before_EOD': 15, 'risk': 0.1866081038438258}. Best is trial 118 with value: 882.1608226627853.
# [I 2025-03-05 10:36:22,363] Trial 154 finished with value: 791.564567356152 and parameters: {'trade_enter': 0.1752314516534996, 'fixed_profit_value': 0.5681019201418522, 'barNo_before_EOD': 4, 'min_bar_enter_trade_before_EOD': 16, 'risk': 0.1441317081506587}. Best is trial 118 with value: 882.1608226627853.
# [I 2025-03-05 10:36:22,478] Trial 155 finished with value: 640.1561421423702 and parameters: {'trade_enter': 0.16640493229098607, 'fixed_profit_value': 0.5537715375785764, 'barNo_before_EOD': 4, 'min_bar_enter_trade_before_EOD': 16, 'risk': 0.22677380701745523}. Best is trial 118 with value: 882.1608226627853.
# [I 2025-03-05 10:36:22,594] Trial 156 finished with value: 769.3578098670274 and parameters: {'trade_enter': 0.2077101330549606, 'fixed_profit_value': 0.6079077212467543, 'barNo_before_EOD': 3, 'min_bar_enter_trade_before_EOD': 14, 'risk': 0.13950023989144059}. Best is trial 118 with value: 882.1608226627853.
# [I 2025-03-05 10:36:22,709] Trial 157 finished with value: 407.6137497950133 and parameters: {'trade_enter': 0.2616822693626302, 'fixed_profit_value': 0.4113363470452511, 'barNo_before_EOD': 5, 'min_bar_enter_trade_before_EOD': 16, 'risk': 0.26206616032919006}. Best is trial 118 with value: 882.1608226627853.
# [I 2025-03-05 10:36:22,813] Trial 158 finished with value: 131.2113558842116 and parameters: {'trade_enter': 1.4815702337042223, 'fixed_profit_value': 0.6827212223593111, 'barNo_before_EOD': 4, 'min_bar_enter_trade_before_EOD': 13, 'risk': 0.18296128207183526}. Best is trial 118 with value: 882.1608226627853.
# [I 2025-03-05 10:36:22,926] Trial 159 finished with value: 813.0437934520035 and parameters: {'trade_enter': 0.18310665573076468, 'fixed_profit_value': 0.5107362598876937, 'barNo_before_EOD': 3, 'min_bar_enter_trade_before_EOD': 15, 'risk': 0.13903614582327964}. Best is trial 118 with value: 882.1608226627853.
# [I 2025-03-05 10:36:23,041] Trial 160 finished with value: 422.0423533295627 and parameters: {'trade_enter': 0.1624704569969761, 'fixed_profit_value': 0.493466946350134, 'barNo_before_EOD': 3, 'min_bar_enter_trade_before_EOD': 17, 'risk': 0.29407082541750196}. Best is trial 118 with value: 882.1608226627853.
# [I 2025-03-05 10:36:23,239] Trial 161 finished with value: 834.246483413461 and parameters: {'trade_enter': 0.21744744943498773, 'fixed_profit_value': 0.5536483298940684, 'barNo_before_EOD': 4, 'min_bar_enter_trade_before_EOD': 15, 'risk': 0.13585961006054592}. Best is trial 118 with value: 882.1608226627853.
# [I 2025-03-05 10:36:23,354] Trial 162 finished with value: 590.0099511028243 and parameters: {'trade_enter': 0.1929699678623116, 'fixed_profit_value': 0.40237482502181443, 'barNo_before_EOD': 3, 'min_bar_enter_trade_before_EOD': 15, 'risk': 0.20948283136204024}. Best is trial 118 with value: 882.1608226627853.
# [I 2025-03-05 10:36:23,469] Trial 163 finished with value: 704.9921358275936 and parameters: {'trade_enter': 0.27783058414297446, 'fixed_profit_value': 0.527220069889664, 'barNo_before_EOD': 1, 'min_bar_enter_trade_before_EOD': 16, 'risk': 0.15339710239792553}. Best is trial 118 with value: 882.1608226627853.
# [I 2025-03-05 10:36:23,583] Trial 164 finished with value: 867.8728517308198 and parameters: {'trade_enter': 0.1355870853924838, 'fixed_profit_value': 0.4803387075715768, 'barNo_before_EOD': 5, 'min_bar_enter_trade_before_EOD': 15, 'risk': 0.13200650660948118}. Best is trial 118 with value: 882.1608226627853.
# [I 2025-03-05 10:36:23,698] Trial 165 finished with value: -513.5361679416133 and parameters: {'trade_enter': 0.1322516668240209, 'fixed_profit_value': 0.6391225118154439, 'barNo_before_EOD': 5, 'min_bar_enter_trade_before_EOD': 15, 'risk': 0.7154469075257783}. Best is trial 118 with value: 882.1608226627853.
# [I 2025-03-05 10:36:23,805] Trial 166 finished with value: 196.36564739825866 and parameters: {'trade_enter': 1.1087840065600283, 'fixed_profit_value': 0.7665402914912762, 'barNo_before_EOD': 2, 'min_bar_enter_trade_before_EOD': 14, 'risk': 0.20955152448454978}. Best is trial 118 with value: 882.1608226627853.
# [I 2025-03-05 10:36:23,920] Trial 167 finished with value: 835.3184506553828 and parameters: {'trade_enter': 0.24006507858617998, 'fixed_profit_value': 0.5523178385712084, 'barNo_before_EOD': 6, 'min_bar_enter_trade_before_EOD': 17, 'risk': 0.1016351148334956}. Best is trial 118 with value: 882.1608226627853.
# [I 2025-03-05 10:36:24,032] Trial 168 finished with value: 702.5551877057037 and parameters: {'trade_enter': 0.16584447323227025, 'fixed_profit_value': 0.5088256336136658, 'barNo_before_EOD': 4, 'min_bar_enter_trade_before_EOD': 17, 'risk': 0.1711735177705142}. Best is trial 118 with value: 882.1608226627853.
# [I 2025-03-05 10:36:24,146] Trial 169 finished with value: 703.6298871963202 and parameters: {'trade_enter': 0.2357836643391823, 'fixed_profit_value': 0.7069234233307152, 'barNo_before_EOD': 5, 'min_bar_enter_trade_before_EOD': 15, 'risk': 0.1301535985160117}. Best is trial 118 with value: 882.1608226627853.
# [I 2025-03-05 10:36:24,260] Trial 170 finished with value: 508.61012175203234 and parameters: {'trade_enter': 0.14290666822734113, 'fixed_profit_value': 2.0161845236690565, 'barNo_before_EOD': 2, 'min_bar_enter_trade_before_EOD': 16, 'risk': 0.16753672204452907}. Best is trial 118 with value: 882.1608226627853.
# [I 2025-03-05 10:36:24,375] Trial 171 finished with value: 768.4709021840811 and parameters: {'trade_enter': 0.26318034340433094, 'fixed_profit_value': 0.5602262902445845, 'barNo_before_EOD': 6, 'min_bar_enter_trade_before_EOD': 17, 'risk': 0.10491027595971321}. Best is trial 118 with value: 882.1608226627853.
# [I 2025-03-05 10:36:24,489] Trial 172 finished with value: 787.4641118780679 and parameters: {'trade_enter': 0.2154907976697625, 'fixed_profit_value': 0.6077791041378643, 'barNo_before_EOD': 3, 'min_bar_enter_trade_before_EOD': 16, 'risk': 0.12678564358028563}. Best is trial 118 with value: 882.1608226627853.
# [I 2025-03-05 10:36:24,604] Trial 173 finished with value: 823.1655639082843 and parameters: {'trade_enter': 0.18908351369565773, 'fixed_profit_value': 0.47408127404538764, 'barNo_before_EOD': 3, 'min_bar_enter_trade_before_EOD': 16, 'risk': 0.13459648256096501}. Best is trial 118 with value: 882.1608226627853.
# [I 2025-03-05 10:36:24,719] Trial 174 finished with value: 705.6232150647974 and parameters: {'trade_enter': 0.10004211446581979, 'fixed_profit_value': 0.4744911396113167, 'barNo_before_EOD': 3, 'min_bar_enter_trade_before_EOD': 15, 'risk': 0.19370724346325113}. Best is trial 118 with value: 882.1608226627853.
# [I 2025-03-05 10:36:24,855] Trial 175 finished with value: 539.1301934362751 and parameters: {'trade_enter': 0.17883911721809315, 'fixed_profit_value': 0.4012166312981696, 'barNo_before_EOD': 2, 'min_bar_enter_trade_before_EOD': 16, 'risk': 0.23592887753385025}. Best is trial 118 with value: 882.1608226627853.
# [I 2025-03-05 10:36:24,970] Trial 176 finished with value: 752.2168772035177 and parameters: {'trade_enter': 0.13811873517172973, 'fixed_profit_value': 0.6551891425175732, 'barNo_before_EOD': 3, 'min_bar_enter_trade_before_EOD': 14, 'risk': 0.12955210086540667}. Best is trial 118 with value: 882.1608226627853.
# [I 2025-03-05 10:36:25,087] Trial 177 finished with value: 661.312756233737 and parameters: {'trade_enter': 0.2788257100252478, 'fixed_profit_value': 0.4700205092444113, 'barNo_before_EOD': 1, 'min_bar_enter_trade_before_EOD': 16, 'risk': 0.1697631587314718}. Best is trial 118 with value: 882.1608226627853.
# [I 2025-03-05 10:36:25,202] Trial 178 finished with value: 827.2784591135805 and parameters: {'trade_enter': 0.18521145924381294, 'fixed_profit_value': 0.607762228810778, 'barNo_before_EOD': 3, 'min_bar_enter_trade_before_EOD': 15, 'risk': 0.10180160140542456}. Best is trial 118 with value: 882.1608226627853.
# [I 2025-03-05 10:36:25,316] Trial 179 finished with value: 898.9161413567264 and parameters: {'trade_enter': 0.17924249741483406, 'fixed_profit_value': 0.5143990256037925, 'barNo_before_EOD': 4, 'min_bar_enter_trade_before_EOD': 15, 'risk': 0.10553968437100915}. Best is trial 179 with value: 898.9161413567264.
# [I 2025-03-05 10:36:25,419] Trial 180 finished with value: 19.520096594080947 and parameters: {'trade_enter': 1.7974201374328331, 'fixed_profit_value': 0.48800241485202367, 'barNo_before_EOD': 24, 'min_bar_enter_trade_before_EOD': 13, 'risk': 0.19639693546541612}. Best is trial 179 with value: 898.9161413567264.
# [I 2025-03-05 10:36:25,534] Trial 181 finished with value: 916.1583946803532 and parameters: {'trade_enter': 0.17765803830254628, 'fixed_profit_value': 0.5509129500602916, 'barNo_before_EOD': 4, 'min_bar_enter_trade_before_EOD': 15, 'risk': 0.1002506406409229}. Best is trial 181 with value: 916.1583946803532.
# [I 2025-03-05 10:36:25,649] Trial 182 finished with value: 884.9947240789329 and parameters: {'trade_enter': 0.23460110948191512, 'fixed_profit_value': 0.5115107595852295, 'barNo_before_EOD': 3, 'min_bar_enter_trade_before_EOD': 15, 'risk': 0.10393120920059874}. Best is trial 181 with value: 916.1583946803532.
# [I 2025-03-05 10:36:25,764] Trial 183 finished with value: 875.2412563511168 and parameters: {'trade_enter': 0.1783236064438049, 'fixed_profit_value': 0.4009659841590373, 'barNo_before_EOD': 4, 'min_bar_enter_trade_before_EOD': 14, 'risk': 0.10193781016469773}. Best is trial 181 with value: 916.1583946803532.
# [I 2025-03-05 10:36:25,880] Trial 184 finished with value: 941.9629094966521 and parameters: {'trade_enter': 0.1403586838035738, 'fixed_profit_value': 0.4642880089428512, 'barNo_before_EOD': 4, 'min_bar_enter_trade_before_EOD': 14, 'risk': 0.10164330517098848}. Best is trial 184 with value: 941.9629094966521.
# [I 2025-03-05 10:36:25,994] Trial 185 finished with value: 929.2921848127285 and parameters: {'trade_enter': 0.14034113008486568, 'fixed_profit_value': 0.4518089887899466, 'barNo_before_EOD': 4, 'min_bar_enter_trade_before_EOD': 13, 'risk': 0.10187573183528761}. Best is trial 184 with value: 941.9629094966521.
# [I 2025-03-05 10:36:26,109] Trial 186 finished with value: 918.4124289053891 and parameters: {'trade_enter': 0.17561716523969578, 'fixed_profit_value': 0.44808712050401983, 'barNo_before_EOD': 3, 'min_bar_enter_trade_before_EOD': 13, 'risk': 0.10116360610233804}. Best is trial 184 with value: 941.9629094966521.
# [I 2025-03-05 10:36:26,227] Trial 187 finished with value: 934.4142722368887 and parameters: {'trade_enter': 0.12307283241199651, 'fixed_profit_value': 0.40063252071785616, 'barNo_before_EOD': 4, 'min_bar_enter_trade_before_EOD': 12, 'risk': 0.10080550939189245}. Best is trial 184 with value: 941.9629094966521.
# [I 2025-03-05 10:36:26,344] Trial 188 finished with value: 929.5046999921778 and parameters: {'trade_enter': 0.10125293443754685, 'fixed_profit_value': 0.4065910901143853, 'barNo_before_EOD': 4, 'min_bar_enter_trade_before_EOD': 13, 'risk': 0.10071233321700386}. Best is trial 184 with value: 941.9629094966521.
# [I 2025-03-05 10:36:26,459] Trial 189 finished with value: 935.4816817092875 and parameters: {'trade_enter': 0.10630520163785502, 'fixed_profit_value': 0.41668445225209283, 'barNo_before_EOD': 4, 'min_bar_enter_trade_before_EOD': 12, 'risk': 0.10393359015134972}. Best is trial 184 with value: 941.9629094966521.
# [I 2025-03-05 10:36:26,576] Trial 190 finished with value: 950.3342483396725 and parameters: {'trade_enter': 0.10840718221894872, 'fixed_profit_value': 0.4042491714769513, 'barNo_before_EOD': 5, 'min_bar_enter_trade_before_EOD': 12, 'risk': 0.10456515773236585}. Best is trial 190 with value: 950.3342483396725.
# [I 2025-03-05 10:36:26,691] Trial 191 finished with value: 895.0107317619538 and parameters: {'trade_enter': 0.11170114694907855, 'fixed_profit_value': 0.4197639604281984, 'barNo_before_EOD': 5, 'min_bar_enter_trade_before_EOD': 12, 'risk': 0.114806525639653}. Best is trial 190 with value: 950.3342483396725.
# [I 2025-03-05 10:36:26,808] Trial 192 finished with value: 924.7371368923709 and parameters: {'trade_enter': 0.10689777785522823, 'fixed_profit_value': 0.41436324303230615, 'barNo_before_EOD': 5, 'min_bar_enter_trade_before_EOD': 12, 'risk': 0.10335413581229665}. Best is trial 190 with value: 950.3342483396725.
# [I 2025-03-05 10:36:26,926] Trial 193 finished with value: 918.5679094365765 and parameters: {'trade_enter': 0.11341452354950114, 'fixed_profit_value': 0.4141769915668465, 'barNo_before_EOD': 5, 'min_bar_enter_trade_before_EOD': 12, 'risk': 0.10548734041762373}. Best is trial 190 with value: 950.3342483396725.
# [I 2025-03-05 10:36:27,044] Trial 194 finished with value: 770.2355281594978 and parameters: {'trade_enter': 0.1059997325393875, 'fixed_profit_value': 0.4043948381875222, 'barNo_before_EOD': 5, 'min_bar_enter_trade_before_EOD': 12, 'risk': 0.17819118760310476}. Best is trial 190 with value: 950.3342483396725.
# [I 2025-03-05 10:36:27,160] Trial 195 finished with value: 926.658800467213 and parameters: {'trade_enter': 0.10249023248657152, 'fixed_profit_value': 0.4005306755865937, 'barNo_before_EOD': 5, 'min_bar_enter_trade_before_EOD': 12, 'risk': 0.11013899327157745}. Best is trial 190 with value: 950.3342483396725.
# [I 2025-03-05 10:36:27,278] Trial 196 finished with value: 950.6131967745933 and parameters: {'trade_enter': 0.11112875904794574, 'fixed_profit_value': 0.40822583595920525, 'barNo_before_EOD': 5, 'min_bar_enter_trade_before_EOD': 12, 'risk': 0.10071039789156618}. Best is trial 196 with value: 950.6131967745933.
# [I 2025-03-05 10:36:27,392] Trial 197 finished with value: 949.4030922512276 and parameters: {'trade_enter': 0.10039682212846747, 'fixed_profit_value': 0.4015456479296346, 'barNo_before_EOD': 5, 'min_bar_enter_trade_before_EOD': 12, 'risk': 0.10143031449597739}. Best is trial 196 with value: 950.6131967745933.
# [I 2025-03-05 10:36:27,508] Trial 198 finished with value: 935.5251278544439 and parameters: {'trade_enter': 0.102312668040164, 'fixed_profit_value': 0.41252282670685153, 'barNo_before_EOD': 5, 'min_bar_enter_trade_before_EOD': 11, 'risk': 0.10190974225525781}. Best is trial 196 with value: 950.6131967745933.
# [I 2025-03-05 10:36:27,623] Trial 199 finished with value: 965.3864279914798 and parameters: {'trade_enter': 0.10144822203188049, 'fixed_profit_value': 0.4054052278064447, 'barNo_before_EOD': 6, 'min_bar_enter_trade_before_EOD': 11, 'risk': 0.10271556393588377}. Best is trial 199 with value: 965.3864279914798.

# %%
trading_study.best_params
# Out:
# {'trade_enter': 0.10144822203188049,
#  'fixed_profit_value': 0.4054052278064447,
#  'barNo_before_EOD': 6,
#  'min_bar_enter_trade_before_EOD': 11,
#  'risk': 0.10271556393588377}

# %%
trading_study.best_value
# Out:
# 965.3864279914798

# %%
def calculate_trade_optuna_2values(trading_signals, trading_params):
    trade_positions = []
    #trade_enter_buy = config['trade_enter_buy']
    #trade_enter_sell = config['trade_enter_sell']
    fixed_profit = True
    fixed_profit_value = trading_params['fixed_profit_value']
    trade_enter_buy = trading_params['trade_enter']
    trade_enter_sell = trading_params['trade_enter']
    bar_distance = 300 # in seconds  
    barNo_before_EOD = trading_params['barNo_before_EOD']
    min_bar_enter_trade_before_EOD = trading_params['min_bar_enter_trade_before_EOD']
    risk = trading_params['risk']
    EOD_Time = '16:00'
    trades = []
    balance = 0
    profit_amount = 10
    profit_count = 0
    loss_count = 0
    partial_profit_count = 0
    partial_loss_count = 0
    buy_count = 0
    sell_count = 0
    loss_amount = profit_amount * risk
    total_trade_length = 0
                    
    for index,row in trading_signals.iterrows():
        buy_power = row['BuyPower']
        sell_power = row['SellPower']
        #print(f'Buy Power : {buy_power}, Sell Power : {sell_power}')

        #predicted_class_index = np.argmax(prob_prediction, axis=1)          #predictions.append(prediction[0])
        

        if len(trades) == 0:
            eod_dt_time = row['Date'].replace(hour=int(EOD_Time.split(':')[0]), minute=int(EOD_Time.split(':')[1]))
            latest_trade_enter_time = eod_dt_time - timedelta(seconds=min_bar_enter_trade_before_EOD * bar_distance)
            if row['Date'] <= latest_trade_enter_time: 
                if buy_power > sell_power and buy_power > trade_enter_buy:
                    if fixed_profit:
                        take_profit = fixed_profit_value
                    else:
                        take_profit = row['Take_Profit_Level'] 
                    trades.append({"Type": "B", 
                                "TakeProfit": row['Close'] + take_profit,
                                "StopLoss": row['Close'] - (take_profit * config['risk']),
                                "Profit": take_profit,
                                "Active": "Y",
                                'Entry': row['Close'],
                                'EntryDate': row['Date']
                                })
            
                    buy_count += 1
                elif sell_power > buy_power and sell_power > trade_enter_sell:
                    take_profit = row['Take_Profit_Level'] 
                    trades.append({"Type": "S", 
                                "TakeProfit": row['Close'] - take_profit,
                                "Profit": take_profit,
                                "StopLoss": row['Close'] + (take_profit * config['risk']),
                                "Active": "Y",
                                'Entry': row['Close'],
                                'EntryDate': row['Date']
                                })
                    sell_count += 1
        else:
            trade = trades[0]
            eod_dt_time = row['Date'].replace(hour=int(EOD_Time.split(':')[0]), minute=int(EOD_Time.split(':')[1]))
            max_exit_time = eod_dt_time - timedelta(seconds=barNo_before_EOD * bar_distance)
            if row['Date'] >= max_exit_time:
                trade['Active'] = 'N'
                if trade['Type'] == 'B':
                    profit = (row['Close'] - trade['Entry']) * profit_amount
                else:
                    profit = (trade['Entry'] - row['Close']) * profit_amount
                
                if profit < 0:
                    partial_loss_count += 1
                    #print(f"EOD Exit , Loss, New Balance : {balance}")
                else:
                    partial_profit_count += 1
                    #print(f"EOD Exit, Profit, New Balance : {balance}")
                trade_time = (pd.to_datetime(row['Date']) -  pd.to_datetime(trade['EntryDate'])) // pd.Timedelta(minutes=5)
                total_trade_length += trade_time
            else:
                if buy_power > sell_power and buy_power > trade_enter_buy and trade['Type'] == 'S':
                    trade['Active'] = 'N'
                    profit = (trade['Entry'] - row['Close']) * profit_amount
                    balance += profit 
                    if profit < 0:
                        partial_loss_count += 1
                        #print(f"Partial Loss, New Balance : {balance}")
                    else:
                        partial_profit_count += 1
                        #print(f"Partial Profit, New Balance : {balance}")

                    trade_time = (pd.to_datetime(row['Date']) -  pd.to_datetime(trade['EntryDate'])) // pd.Timedelta(minutes=5)
                    total_trade_length += trade_time

                elif sell_power > buy_power and sell_power > trade_enter_sell and trades[0]['Type'] == 'B':
                    trade['Active'] = 'N'
                    profit = (row['Close'] - trade['Entry']) * profit_amount
                    balance += profit
                    if profit < 0:
                        partial_loss_count += 1
                        #print(f"Partial Loss, New Balance : {balance}")
                    else:
                        partial_profit_count += 1
                        #print(f"Partial Profit, New Balance : {balance}")
                    trade_time = (pd.to_datetime(row['Date']) -  pd.to_datetime(trade['EntryDate'])) // pd.Timedelta(minutes=5)
                    total_trade_length += trade_time
        
        for trade in trades:
            if (trade['Type'] == 'B' and row['High'] >= trade['TakeProfit']) or (trade['Type'] == 'S' and row['Low'] <= trade['TakeProfit']):
                trade['Active'] = 'N'
                balance += (trade['Profit'] * profit_amount)
                profit_count += 1
                #print(f"Take Profit, New Balance : {balance}")  
                trade_time = (pd.to_datetime(row['Date']) -  pd.to_datetime(trade['EntryDate'])) // pd.Timedelta(minutes=5)
                total_trade_length += trade_time           
            elif (trade['Type'] == 'B' and row['Low'] <= trade['StopLoss']) or (trade['Type'] == 'S' and row['High'] >= trade['StopLoss']):
                trade['Active'] = 'N'
                balance -= (trade['Profit'] * loss_amount)
                loss_count += 1
                #print(f"Stop Loss, New Balance : {balance}")
                trade_time = (pd.to_datetime(row['Date']) -  pd.to_datetime(trade['EntryDate'])) // pd.Timedelta(minutes=5)
                total_trade_length += trade_time


        # Filter out all trades that are not active
        trades = [trade for trade in trades if trade['Active'] == 'Y']
    total_trade_count = buy_count + sell_count
    total_loss_count = loss_count + partial_loss_count
    return balance, total_trade_length / total_trade_count   
    #print(f"Final Balance : {balance} \n Take Profit count : {profit_count} \n Stop Loss count : {loss_count} \n Partial Profit count : {partial_profit_count} \n Partial Loss count : {partial_loss_count}")
    #print(f"Buy count : {buy_count} \n Sell count : {sell_count}")

# %%
def trading_objective_2(trial):
    params = {
        'trade_enter': trial.suggest_float('trade_enter', 0.2, 2.0),
        'fixed_profit_value': trial.suggest_float('fixed_profit_value', 0.4, 4.0),
        'barNo_before_EOD': trial.suggest_int('barNo_before_EOD', 1, 30),
        'min_bar_enter_trade_before_EOD': trial.suggest_int('min_bar_enter_trade_before_EOD', 5, 30),
        'risk': trial.suggest_float('risk', 0.1, 2.0)
    }

    balance, trade_length = calculate_trade_optuna_2values(tr_signals, params)

    return balance, trade_length

# %%
trading_study_2 = optuna.create_study(directions=['maximize', 'minimize']) # for metric auc its maximuze, and for mlogloss its minimie
trading_study_2.optimize(trading_objective_2, n_trials=200)
# Out:
# [I 2025-03-05 12:17:03,991] A new study created in memory with name: no-name-863dbf79-4fab-48c7-8c87-8e1d6c847aad
# [I 2025-03-05 12:17:04,100] Trial 0 finished with values: [44.65204121761262, 29.857142857142858] and parameters: {'trade_enter': 1.8234600225199906, 'fixed_profit_value': 1.4884013739204207, 'barNo_before_EOD': 4, 'min_bar_enter_trade_before_EOD': 6, 'risk': 1.992307203596933}.
# [I 2025-03-05 12:17:04,197] Trial 1 finished with values: [-86.20614967670443, 33.6] and parameters: {'trade_enter': 1.7400513332158805, 'fixed_profit_value': 2.389468520061457, 'barNo_before_EOD': 2, 'min_bar_enter_trade_before_EOD': 12, 'risk': 1.5359180497383467}.
# [I 2025-03-05 12:17:04,300] Trial 2 finished with values: [327.63441690505385, 23.601626016260163] and parameters: {'trade_enter': 0.8128783991259911, 'fixed_profit_value': 3.541619150554635, 'barNo_before_EOD': 7, 'min_bar_enter_trade_before_EOD': 30, 'risk': 0.14614938645857178}.
# [I 2025-03-05 12:17:04,396] Trial 3 finished with values: [149.21031040403216, 16.223880597014926] and parameters: {'trade_enter': 1.2977106575600112, 'fixed_profit_value': 1.5732379618373913, 'barNo_before_EOD': 15, 'min_bar_enter_trade_before_EOD': 9, 'risk': 0.34246377463833516}.
# [I 2025-03-05 12:17:04,502] Trial 4 finished with values: [-818.6575724945872, 5.74656188605108] and parameters: {'trade_enter': 0.2551668504276682, 'fixed_profit_value': 1.5766561506710883, 'barNo_before_EOD': 16, 'min_bar_enter_trade_before_EOD': 24, 'risk': 1.7007334453148613}.
# [I 2025-03-05 12:17:04,605] Trial 5 finished with values: [-302.80292990781555, 7.537735849056604] and parameters: {'trade_enter': 0.7545025109194401, 'fixed_profit_value': 2.5589337880354477, 'barNo_before_EOD': 27, 'min_bar_enter_trade_before_EOD': 12, 'risk': 1.8885775415998776}.
# [I 2025-03-05 12:17:04,702] Trial 6 finished with values: [-51.596647101940235, 24.186666666666667] and parameters: {'trade_enter': 1.052942249165466, 'fixed_profit_value': 3.717893646927233, 'barNo_before_EOD': 21, 'min_bar_enter_trade_before_EOD': 25, 'risk': 1.4785198214527056}.
# [I 2025-03-05 12:17:04,808] Trial 7 finished with values: [-577.2640694747074, 5.7481203007518795] and parameters: {'trade_enter': 0.303703578496061, 'fixed_profit_value': 1.464687363084263, 'barNo_before_EOD': 17, 'min_bar_enter_trade_before_EOD': 17, 'risk': 1.2375042259036018}.
# [I 2025-03-05 12:17:04,905] Trial 8 finished with values: [139.69337536379177, 23.897435897435898] and parameters: {'trade_enter': 1.4286108862883995, 'fixed_profit_value': 1.7608502766229905, 'barNo_before_EOD': 10, 'min_bar_enter_trade_before_EOD': 5, 'risk': 0.7744055259301182}.
# [I 2025-03-05 12:17:05,003] Trial 9 finished with values: [-445.00228995811847, 36.88235294117647] and parameters: {'trade_enter': 1.2221157636607636, 'fixed_profit_value': 3.0157638973821532, 'barNo_before_EOD': 1, 'min_bar_enter_trade_before_EOD': 29, 'risk': 1.7522652031810877}.
# [I 2025-03-05 12:17:05,113] Trial 10 finished with values: [-82.47636958251934, 4.004405286343612] and parameters: {'trade_enter': 0.4068723732612485, 'fixed_profit_value': 3.4350380563930165, 'barNo_before_EOD': 30, 'min_bar_enter_trade_before_EOD': 14, 'risk': 1.5839847144183918}.
# [I 2025-03-05 12:17:05,208] Trial 11 finished with values: [-31.660997059299, 25.6] and parameters: {'trade_enter': 1.6239077352728224, 'fixed_profit_value': 1.4349440414890113, 'barNo_before_EOD': 5, 'min_bar_enter_trade_before_EOD': 7, 'risk': 1.2874754143444713}.
# [I 2025-03-05 12:17:05,304] Trial 12 finished with values: [-46.85750201342328, 58.0] and parameters: {'trade_enter': 1.9573784879112437, 'fixed_profit_value': 3.5697112992213276, 'barNo_before_EOD': 14, 'min_bar_enter_trade_before_EOD': 20, 'risk': 0.9923413441540971}.
# [I 2025-03-05 12:17:05,406] Trial 13 finished with values: [189.29543500121972, 16.425414364640883] and parameters: {'trade_enter': 0.7276896391548664, 'fixed_profit_value': 3.1038432059339693, 'barNo_before_EOD': 9, 'min_bar_enter_trade_before_EOD': 19, 'risk': 0.3820585668787819}.
# [I 2025-03-05 12:17:05,502] Trial 14 finished with values: [32.05554947883806, 18.166666666666668] and parameters: {'trade_enter': 1.847842358854274, 'fixed_profit_value': 1.0685183159612688, 'barNo_before_EOD': 24, 'min_bar_enter_trade_before_EOD': 14, 'risk': 0.4962286956790668}.
# [I 2025-03-05 12:17:05,601] Trial 15 finished with values: [-81.57980898161429, 26.52173913043478] and parameters: {'trade_enter': 1.3421994866954834, 'fixed_profit_value': 2.105159335537139, 'barNo_before_EOD': 3, 'min_bar_enter_trade_before_EOD': 10, 'risk': 1.1817337219265798}.
# [I 2025-03-05 12:17:05,697] Trial 16 finished with values: [-29.911355610882225, 52.833333333333336] and parameters: {'trade_enter': 1.7698513203623423, 'fixed_profit_value': 2.932695941819965, 'barNo_before_EOD': 6, 'min_bar_enter_trade_before_EOD': 21, 'risk': 1.0099634637254606}.
# [I 2025-03-05 12:17:05,802] Trial 17 finished with values: [149.78242213299507, 8.049738219895287] and parameters: {'trade_enter': 0.5998827992259507, 'fixed_profit_value': 1.7537050215534613, 'barNo_before_EOD': 15, 'min_bar_enter_trade_before_EOD': 9, 'risk': 0.6119784699447465}.
# [I 2025-03-05 12:17:05,913] Trial 18 finished with values: [-419.532037668932, 4.2941935483870965] and parameters: {'trade_enter': 0.28544500327503547, 'fixed_profit_value': 0.6958592665234559, 'barNo_before_EOD': 5, 'min_bar_enter_trade_before_EOD': 11, 'risk': 0.6558063439065142}.
# [I 2025-03-05 12:17:06,015] Trial 19 finished with values: [229.29515271288753, 14.8125] and parameters: {'trade_enter': 0.9601334454846664, 'fixed_profit_value': 1.0971835689481602, 'barNo_before_EOD': 13, 'min_bar_enter_trade_before_EOD': 12, 'risk': 0.3791251732136737}.
# [I 2025-03-05 12:17:06,112] Trial 20 finished with values: [79.3743218659427, 23.923076923076923] and parameters: {'trade_enter': 1.433506169474351, 'fixed_profit_value': 3.2161224756084112, 'barNo_before_EOD': 15, 'min_bar_enter_trade_before_EOD': 6, 'risk': 1.2244707202772118}.
# [I 2025-03-05 12:17:06,208] Trial 21 finished with values: [-46.72656751022667, 38.6] and parameters: {'trade_enter': 1.9145850929245918, 'fixed_profit_value': 2.8261305418820695, 'barNo_before_EOD': 7, 'min_bar_enter_trade_before_EOD': 16, 'risk': 0.9934742085871875}.
# [I 2025-03-05 12:17:06,303] Trial 22 finished with values: [26.872361946631734, 37.44444444444444] and parameters: {'trade_enter': 1.6837877623113726, 'fixed_profit_value': 2.8784200679217338, 'barNo_before_EOD': 21, 'min_bar_enter_trade_before_EOD': 20, 'risk': 0.10988387002793179}.
# [I 2025-03-05 12:17:06,409] Trial 23 finished with values: [180.51714576232808, 10.736654804270463] and parameters: {'trade_enter': 0.6900208706478153, 'fixed_profit_value': 1.2080846699116008, 'barNo_before_EOD': 9, 'min_bar_enter_trade_before_EOD': 10, 'risk': 0.4843720349797705}.
# [I 2025-03-05 12:17:06,512] Trial 24 finished with values: [300.33555577328576, 7.580060422960725] and parameters: {'trade_enter': 0.7490144076499972, 'fixed_profit_value': 1.7077841683189996, 'barNo_before_EOD': 23, 'min_bar_enter_trade_before_EOD': 9, 'risk': 0.3236483973681884}.
# [I 2025-03-05 12:17:06,613] Trial 25 finished with values: [-427.75964846565245, 28.427083333333332] and parameters: {'trade_enter': 0.9954109994376144, 'fixed_profit_value': 3.3442076312363063, 'barNo_before_EOD': 3, 'min_bar_enter_trade_before_EOD': 16, 'risk': 1.755620394665416}.
# [I 2025-03-05 12:17:06,715] Trial 26 finished with values: [-83.16713824228714, 14.195652173913043] and parameters: {'trade_enter': 0.6468832973582448, 'fixed_profit_value': 2.404223562094004, 'barNo_before_EOD': 3, 'min_bar_enter_trade_before_EOD': 22, 'risk': 0.7805256929007917}.
# [I 2025-03-05 12:17:06,817] Trial 27 finished with values: [-390.4789506045605, 11.553719008264462] and parameters: {'trade_enter': 0.8354638864176085, 'fixed_profit_value': 3.7489206703338787, 'barNo_before_EOD': 16, 'min_bar_enter_trade_before_EOD': 5, 'risk': 1.8008193708110822}.
# [I 2025-03-05 12:17:06,968] Trial 28 finished with values: [-467.5832997303655, 10.097560975609756] and parameters: {'trade_enter': 0.5052464486469619, 'fixed_profit_value': 2.5538012257745537, 'barNo_before_EOD': 10, 'min_bar_enter_trade_before_EOD': 30, 'risk': 1.7304100868676486}.
# [I 2025-03-05 12:17:07,068] Trial 29 finished with values: [123.92560415776781, 11.589285714285714] and parameters: {'trade_enter': 1.1586386628001781, 'fixed_profit_value': 1.9828685579181533, 'barNo_before_EOD': 25, 'min_bar_enter_trade_before_EOD': 9, 'risk': 0.38569525365626756}.
# [I 2025-03-05 12:17:07,166] Trial 30 finished with values: [117.34459028730588, 21.914285714285715] and parameters: {'trade_enter': 1.385318767724521, 'fixed_profit_value': 1.0809042113245821, 'barNo_before_EOD': 12, 'min_bar_enter_trade_before_EOD': 29, 'risk': 1.0178052347621684}.
# [I 2025-03-05 12:17:07,264] Trial 31 finished with values: [67.74373479055677, 17.366666666666667] and parameters: {'trade_enter': 1.2966419994147893, 'fixed_profit_value': 1.053987761756541, 'barNo_before_EOD': 11, 'min_bar_enter_trade_before_EOD': 12, 'risk': 0.6898535769502014}.
# [I 2025-03-05 12:17:07,361] Trial 32 finished with values: [29.443594583455962, 13.303030303030303] and parameters: {'trade_enter': 1.0134336701319175, 'fixed_profit_value': 3.7433312658397573, 'barNo_before_EOD': 28, 'min_bar_enter_trade_before_EOD': 18, 'risk': 0.7995290667038013}.
# [I 2025-03-05 12:17:07,454] Trial 33 finished with values: [21.653342027596025, 35.90909090909091] and parameters: {'trade_enter': 1.7106903230990942, 'fixed_profit_value': 1.4635596341174866, 'barNo_before_EOD': 1, 'min_bar_enter_trade_before_EOD': 18, 'risk': 1.822095005510947}.
# [I 2025-03-05 12:17:07,546] Trial 34 finished with values: [23.7785233682651, 29.25] and parameters: {'trade_enter': 1.9254737510770117, 'fixed_profit_value': 1.1889261684132548, 'barNo_before_EOD': 23, 'min_bar_enter_trade_before_EOD': 30, 'risk': 0.38942497930461556}.
# [I 2025-03-05 12:17:07,639] Trial 35 finished with values: [38.42757793508487, 27.5] and parameters: {'trade_enter': 1.827745391876128, 'fixed_profit_value': 1.280919264502829, 'barNo_before_EOD': 13, 'min_bar_enter_trade_before_EOD': 13, 'risk': 1.005331518277928}.
# [I 2025-03-05 12:17:07,738] Trial 36 finished with values: [-54.538914704943295, 10.986577181208053] and parameters: {'trade_enter': 1.0082677448927666, 'fixed_profit_value': 0.6561685933349759, 'barNo_before_EOD': 14, 'min_bar_enter_trade_before_EOD': 12, 'risk': 0.8984061883234522}.
# [I 2025-03-05 12:17:07,839] Trial 37 finished with values: [185.99664277451316, 6.725] and parameters: {'trade_enter': 0.5230456997244393, 'fixed_profit_value': 2.4355406890217037, 'barNo_before_EOD': 30, 'min_bar_enter_trade_before_EOD': 25, 'risk': 0.7677100091886935}.
# [I 2025-03-05 12:17:07,935] Trial 38 finished with values: [214.13570457794435, 26.903225806451612] and parameters: {'trade_enter': 1.460660175591236, 'fixed_profit_value': 2.6560895479646685, 'barNo_before_EOD': 13, 'min_bar_enter_trade_before_EOD': 14, 'risk': 0.1857154565247184}.
# [I 2025-03-05 12:17:08,028] Trial 39 finished with values: [66.18092197998149, 20.655172413793103] and parameters: {'trade_enter': 1.4105057940128893, 'fixed_profit_value': 1.5673040451695108, 'barNo_before_EOD': 29, 'min_bar_enter_trade_before_EOD': 29, 'risk': 0.4569936132141329}.
# [I 2025-03-05 12:17:08,129] Trial 40 finished with values: [-514.5146867000309, 8.292134831460674] and parameters: {'trade_enter': 0.7355203333320363, 'fixed_profit_value': 1.6014535314340366, 'barNo_before_EOD': 28, 'min_bar_enter_trade_before_EOD': 20, 'risk': 1.6666058218075142}.
# [I 2025-03-05 12:17:08,339] Trial 41 finished with values: [-556.4526253132126, 28.152542372881356] and parameters: {'trade_enter': 1.2188702088384507, 'fixed_profit_value': 1.774395884817209, 'barNo_before_EOD': 7, 'min_bar_enter_trade_before_EOD': 23, 'risk': 1.9287214114990676}.
# [I 2025-03-05 12:17:08,438] Trial 42 finished with values: [-301.19706419403366, 7.112627986348123] and parameters: {'trade_enter': 0.7606996035188435, 'fixed_profit_value': 0.502008854100548, 'barNo_before_EOD': 9, 'min_bar_enter_trade_before_EOD': 23, 'risk': 1.0485040484224177}.
# [I 2025-03-05 12:17:08,539] Trial 43 finished with values: [240.6399706725643, 22.676258992805757] and parameters: {'trade_enter': 0.8562299837668061, 'fixed_profit_value': 3.800797735577176, 'barNo_before_EOD': 6, 'min_bar_enter_trade_before_EOD': 13, 'risk': 0.25154036875597646}.
# [I 2025-03-05 12:17:08,644] Trial 44 finished with values: [183.62399407111195, 5.242537313432836] and parameters: {'trade_enter': 0.4938440323346971, 'fixed_profit_value': 3.3323076343759275, 'barNo_before_EOD': 26, 'min_bar_enter_trade_before_EOD': 13, 'risk': 0.5402445398125701}.
# [I 2025-03-05 12:17:08,747] Trial 45 finished with values: [390.62723871803206, 6.260330578512397] and parameters: {'trade_enter': 0.27003657913867724, 'fixed_profit_value': 1.8872120398683132, 'barNo_before_EOD': 8, 'min_bar_enter_trade_before_EOD': 24, 'risk': 0.2550828547628872}.
# [I 2025-03-05 12:17:08,845] Trial 46 finished with values: [-145.14744835760544, 16.929133858267715] and parameters: {'trade_enter': 0.9576147847976907, 'fixed_profit_value': 1.0925016688430882, 'barNo_before_EOD': 9, 'min_bar_enter_trade_before_EOD': 21, 'risk': 1.0413192510835718}.
# [I 2025-03-05 12:17:08,939] Trial 47 finished with values: [-191.5884129780855, 34.52] and parameters: {'trade_enter': 1.5557380621872423, 'fixed_profit_value': 2.38321966933356, 'barNo_before_EOD': 1, 'min_bar_enter_trade_before_EOD': 18, 'risk': 1.8967849476910728}.
# [I 2025-03-05 12:17:09,039] Trial 48 finished with values: [-375.21524561374525, 15.413461538461538] and parameters: {'trade_enter': 0.6430064871262209, 'fixed_profit_value': 3.449438827813872, 'barNo_before_EOD': 2, 'min_bar_enter_trade_before_EOD': 27, 'risk': 1.4992110558369214}.
# [I 2025-03-05 12:17:09,139] Trial 49 finished with values: [-82.48328711988917, 14.133333333333333] and parameters: {'trade_enter': 0.7954158545109234, 'fixed_profit_value': 2.4622838842504566, 'barNo_before_EOD': 19, 'min_bar_enter_trade_before_EOD': 17, 'risk': 1.0055784600032276}.
# [I 2025-03-05 12:17:09,240] Trial 50 finished with values: [-460.8875104595643, 9.752613240418118] and parameters: {'trade_enter': 0.6820961089420988, 'fixed_profit_value': 3.2380872402121863, 'barNo_before_EOD': 20, 'min_bar_enter_trade_before_EOD': 14, 'risk': 1.992307203596933}.
# [I 2025-03-05 12:17:09,340] Trial 51 finished with values: [112.11154106164844, 14.549295774647888] and parameters: {'trade_enter': 0.6900208706478153, 'fixed_profit_value': 2.8422941860466393, 'barNo_before_EOD': 9, 'min_bar_enter_trade_before_EOD': 19, 'risk': 0.4843720349797705}.
# [I 2025-03-05 12:17:09,443] Trial 52 finished with values: [478.59377210835726, 6.725] and parameters: {'trade_enter': 0.5230456997244393, 'fixed_profit_value': 2.4355406890217037, 'barNo_before_EOD': 30, 'min_bar_enter_trade_before_EOD': 25, 'risk': 0.14614938645857178}.
# [I 2025-03-05 12:17:09,535] Trial 53 finished with values: [-46.72656751022667, 41.0] and parameters: {'trade_enter': 1.9145850929245918, 'fixed_profit_value': 2.8261305418820695, 'barNo_before_EOD': 1, 'min_bar_enter_trade_before_EOD': 16, 'risk': 0.9934742085871875}.
# [I 2025-03-05 12:17:09,638] Trial 54 finished with values: [-480.2872295412918, 4.63448275862069] and parameters: {'trade_enter': 0.5230456997244393, 'fixed_profit_value': 0.6561685933349759, 'barNo_before_EOD': 14, 'min_bar_enter_trade_before_EOD': 12, 'risk': 0.7677100091886935}.
# [I 2025-03-05 12:17:09,740] Trial 55 finished with values: [189.2529107819228, 11.485849056603774] and parameters: {'trade_enter': 0.7276896391548664, 'fixed_profit_value': 3.1038432059339693, 'barNo_before_EOD': 24, 'min_bar_enter_trade_before_EOD': 21, 'risk': 0.4962286956790668}.
# [I 2025-03-05 12:17:09,834] Trial 56 finished with values: [12.781938504929895, 29.4375] and parameters: {'trade_enter': 1.6239077352728224, 'fixed_profit_value': 1.4349440414890113, 'barNo_before_EOD': 5, 'min_bar_enter_trade_before_EOD': 23, 'risk': 0.8350469037262089}.
# [I 2025-03-05 12:17:09,935] Trial 57 finished with values: [-120.20721154286974, 9.5578231292517] and parameters: {'trade_enter': 0.6900208706478153, 'fixed_profit_value': 1.053987761756541, 'barNo_before_EOD': 11, 'min_bar_enter_trade_before_EOD': 12, 'risk': 0.6898535769502014}.
# [I 2025-03-05 12:17:10,030] Trial 58 finished with values: [106.88002331092021, 10.776315789473685] and parameters: {'trade_enter': 1.2977106575600112, 'fixed_profit_value': 1.0685183159612688, 'barNo_before_EOD': 24, 'min_bar_enter_trade_before_EOD': 11, 'risk': 0.34246377463833516}.
# [I 2025-03-05 12:17:10,134] Trial 59 finished with values: [-808.4747900885001, 8.748730964467006] and parameters: {'trade_enter': 0.4938440323346971, 'fixed_profit_value': 1.4349440414890113, 'barNo_before_EOD': 5, 'min_bar_enter_trade_before_EOD': 13, 'risk': 1.2874754143444713}.
# [I 2025-03-05 12:17:10,238] Trial 60 finished with values: [-953.2898813928947, 5.840077071290944] and parameters: {'trade_enter': 0.2551668504276682, 'fixed_profit_value': 1.5766561506710883, 'barNo_before_EOD': 9, 'min_bar_enter_trade_before_EOD': 23, 'risk': 1.7007334453148613}.
# [I 2025-03-05 12:17:10,338] Trial 61 finished with values: [24.59230360635405, 14.504807692307692] and parameters: {'trade_enter': 0.6468832973582448, 'fixed_profit_value': 2.1646194454303327, 'barNo_before_EOD': 1, 'min_bar_enter_trade_before_EOD': 29, 'risk': 0.7805256929007917}.
# [I 2025-03-05 12:17:10,432] Trial 62 finished with values: [67.74373479055677, 17.366666666666667] and parameters: {'trade_enter': 1.2966419994147893, 'fixed_profit_value': 1.053987761756541, 'barNo_before_EOD': 11, 'min_bar_enter_trade_before_EOD': 12, 'risk': 0.6898535769502014}.
# [I 2025-03-05 12:17:10,526] Trial 63 finished with values: [89.00757515193875, 24.97142857142857] and parameters: {'trade_enter': 1.4748173634775763, 'fixed_profit_value': 3.2161224756084112, 'barNo_before_EOD': 15, 'min_bar_enter_trade_before_EOD': 6, 'risk': 1.2244707202772118}.
# [I 2025-03-05 12:17:10,620] Trial 64 finished with values: [43.661711715865465, 17.375] and parameters: {'trade_enter': 1.6689372388531625, 'fixed_profit_value': 1.0685183159612688, 'barNo_before_EOD': 15, 'min_bar_enter_trade_before_EOD': 14, 'risk': 0.6119784699447465}.
# [I 2025-03-05 12:17:10,721] Trial 65 finished with values: [-232.93833367931364, 19.047619047619047] and parameters: {'trade_enter': 0.7606996035188435, 'fixed_profit_value': 2.5538012257745537, 'barNo_before_EOD': 10, 'min_bar_enter_trade_before_EOD': 30, 'risk': 1.7304100868676486}.
# [I 2025-03-05 12:17:10,826] Trial 66 finished with values: [-364.9266065379444, 5.242537313432836] and parameters: {'trade_enter': 0.4938440323346971, 'fixed_profit_value': 3.3323076343759275, 'barNo_before_EOD': 26, 'min_bar_enter_trade_before_EOD': 13, 'risk': 1.8885775415998776}.
# [I 2025-03-05 12:17:10,937] Trial 67 finished with values: [301.77960588173283, 2.06484375] and parameters: {'trade_enter': 0.27003657913867724, 'fixed_profit_value': 0.4387694920569682, 'barNo_before_EOD': 23, 'min_bar_enter_trade_before_EOD': 10, 'risk': 0.3236483973681884}.
# [I 2025-03-05 12:17:11,042] Trial 68 finished with values: [-354.09580112050793, 6.855731225296442] and parameters: {'trade_enter': 0.3899953954728604, 'fixed_profit_value': 2.105159335537139, 'barNo_before_EOD': 10, 'min_bar_enter_trade_before_EOD': 9, 'risk': 1.2903335583684574}.
# [I 2025-03-05 12:17:11,145] Trial 69 finished with values: [294.8415595966915, 6.26246719160105] and parameters: {'trade_enter': 0.7490144076499972, 'fixed_profit_value': 2.4355406890217037, 'barNo_before_EOD': 30, 'min_bar_enter_trade_before_EOD': 9, 'risk': 0.1969673464132436}.
# [I 2025-03-05 12:17:11,243] Trial 70 finished with values: [-14.276395693394878, 27.5] and parameters: {'trade_enter': 1.9573784879112437, 'fixed_profit_value': 1.9828685579181533, 'barNo_before_EOD': 25, 'min_bar_enter_trade_before_EOD': 9, 'risk': 0.7199869923997334}.
# [I 2025-03-05 12:17:11,351] Trial 71 finished with values: [-18.941486779131424, 10.029585798816568] and parameters: {'trade_enter': 0.6430064871262209, 'fixed_profit_value': 3.449438827813872, 'barNo_before_EOD': 10, 'min_bar_enter_trade_before_EOD': 5, 'risk': 0.7744055259301182}.
# [I 2025-03-05 12:17:11,451] Trial 72 finished with values: [-1110.4628690752236, 9.266932270916335] and parameters: {'trade_enter': 0.8354638864176085, 'fixed_profit_value': 0.5577391616253378, 'barNo_before_EOD': 5, 'min_bar_enter_trade_before_EOD': 11, 'risk': 1.8008193708110822}.
# [I 2025-03-05 12:17:11,554] Trial 73 finished with values: [-74.91674672831101, 4.069172932330827] and parameters: {'trade_enter': 0.4068723732612485, 'fixed_profit_value': 3.7433312658397573, 'barNo_before_EOD': 30, 'min_bar_enter_trade_before_EOD': 15, 'risk': 1.6242209741136202}.
# [I 2025-03-05 12:17:11,659] Trial 74 finished with values: [-197.53653027454072, 5.352530541012216] and parameters: {'trade_enter': 0.5052464486469619, 'fixed_profit_value': 0.7384023657529258, 'barNo_before_EOD': 10, 'min_bar_enter_trade_before_EOD': 9, 'risk': 0.6119784699447465}.
# [I 2025-03-05 12:17:11,758] Trial 75 finished with values: [230.33120282035378, 23.743362831858406] and parameters: {'trade_enter': 0.9576147847976907, 'fixed_profit_value': 2.6816015441213725, 'barNo_before_EOD': 9, 'min_bar_enter_trade_before_EOD': 10, 'risk': 0.4843720349797705}.
# [I 2025-03-05 12:17:11,862] Trial 76 finished with values: [-1064.1563869819606, 13.104693140794224] and parameters: {'trade_enter': 0.6468832973582448, 'fixed_profit_value': 2.404223562094004, 'barNo_before_EOD': 3, 'min_bar_enter_trade_before_EOD': 5, 'risk': 1.8008193708110822}.
# [I 2025-03-05 12:17:11,956] Trial 77 finished with values: [21.99711503759103, 44.588235294117645] and parameters: {'trade_enter': 1.5710502389404726, 'fixed_profit_value': 3.1053767499391247, 'barNo_before_EOD': 5, 'min_bar_enter_trade_before_EOD': 30, 'risk': 1.969604402036058}.
# [I 2025-03-05 12:17:12,061] Trial 78 finished with values: [293.7861777036098, 5.118181818181818] and parameters: {'trade_enter': 0.4938440323346971, 'fixed_profit_value': 1.8872120398683132, 'barNo_before_EOD': 26, 'min_bar_enter_trade_before_EOD': 13, 'risk': 0.5402445398125701}.
# [I 2025-03-05 12:17:12,167] Trial 79 finished with values: [-655.787522807159, 3.41840490797546] and parameters: {'trade_enter': 0.4068723732612485, 'fixed_profit_value': 1.2080846699116008, 'barNo_before_EOD': 30, 'min_bar_enter_trade_before_EOD': 10, 'risk': 1.5839847144183918}.
# [I 2025-03-05 12:17:12,276] Trial 80 finished with values: [132.32257271417114, 3.5005767012687428] and parameters: {'trade_enter': 0.28544500327503547, 'fixed_profit_value': 1.9828685579181533, 'barNo_before_EOD': 25, 'min_bar_enter_trade_before_EOD': 9, 'risk': 0.6558063439065142}.
# [I 2025-03-05 12:17:12,371] Trial 81 finished with values: [139.69337536379177, 23.897435897435898] and parameters: {'trade_enter': 1.4286108862883995, 'fixed_profit_value': 1.7608502766229905, 'barNo_before_EOD': 10, 'min_bar_enter_trade_before_EOD': 5, 'risk': 0.7744055259301182}.
# [I 2025-03-05 12:17:12,465] Trial 82 finished with values: [60.646584058724756, 16.148936170212767] and parameters: {'trade_enter': 1.380717217682691, 'fixed_profit_value': 1.1358889873222593, 'barNo_before_EOD': 19, 'min_bar_enter_trade_before_EOD': 17, 'risk': 1.0055784600032276}.
# [I 2025-03-05 12:17:12,560] Trial 83 finished with values: [-86.87167320061394, 27.35] and parameters: {'trade_enter': 1.3971728607746436, 'fixed_profit_value': 1.9040406282177207, 'barNo_before_EOD': 7, 'min_bar_enter_trade_before_EOD': 12, 'risk': 1.3099548310222804}.
# [I 2025-03-05 12:17:12,685] Trial 84 finished with values: [-21.022640528691817, 27.3] and parameters: {'trade_enter': 1.6239077352728224, 'fixed_profit_value': 1.774395884817209, 'barNo_before_EOD': 6, 'min_bar_enter_trade_before_EOD': 7, 'risk': 1.5928862850862504}.
# [I 2025-03-05 12:17:12,778] Trial 85 finished with values: [-63.78485728876796, 55.125] and parameters: {'trade_enter': 1.7400513332158805, 'fixed_profit_value': 3.7433312658397573, 'barNo_before_EOD': 2, 'min_bar_enter_trade_before_EOD': 18, 'risk': 1.7039597288876016}.
# [I 2025-03-05 12:17:12,874] Trial 86 finished with values: [39.90818919860752, 25.692307692307693] and parameters: {'trade_enter': 1.433506169474351, 'fixed_profit_value': 3.7489206703338787, 'barNo_before_EOD': 15, 'min_bar_enter_trade_before_EOD': 7, 'risk': 1.8008193708110822}.
# [I 2025-03-05 12:17:12,972] Trial 87 finished with values: [44.65204121761262, 33.666666666666664] and parameters: {'trade_enter': 1.8234600225199906, 'fixed_profit_value': 1.4884013739204207, 'barNo_before_EOD': 4, 'min_bar_enter_trade_before_EOD': 12, 'risk': 1.992307203596933}.
# [I 2025-03-05 12:17:13,072] Trial 88 finished with values: [233.53906006464447, 12.36888888888889] and parameters: {'trade_enter': 0.7276896391548664, 'fixed_profit_value': 1.2080846699116008, 'barNo_before_EOD': 9, 'min_bar_enter_trade_before_EOD': 19, 'risk': 0.4843720349797705}.
# [I 2025-03-05 12:17:13,170] Trial 89 finished with values: [-190.28692565776234, 13.488505747126437] and parameters: {'trade_enter': 0.7954158545109234, 'fixed_profit_value': 1.0809042113245821, 'barNo_before_EOD': 6, 'min_bar_enter_trade_before_EOD': 29, 'risk': 1.0178052347621684}.
# [I 2025-03-05 12:17:13,273] Trial 90 finished with values: [208.34028428950413, 6.672131147540983] and parameters: {'trade_enter': 0.5998827992259507, 'fixed_profit_value': 3.717893646927233, 'barNo_before_EOD': 21, 'min_bar_enter_trade_before_EOD': 9, 'risk': 0.6119784699447465}.
# [I 2025-03-05 12:17:13,375] Trial 91 finished with values: [72.36295016878968, 23.961165048543688] and parameters: {'trade_enter': 1.0134336701319175, 'fixed_profit_value': 2.105159335537139, 'barNo_before_EOD': 7, 'min_bar_enter_trade_before_EOD': 10, 'risk': 0.7995290667038013}.
# [I 2025-03-05 12:17:13,467] Trial 92 finished with values: [23.7785233682651, 29.25] and parameters: {'trade_enter': 1.9254737510770117, 'fixed_profit_value': 1.1889261684132548, 'barNo_before_EOD': 23, 'min_bar_enter_trade_before_EOD': 30, 'risk': 0.38942497930461556}.
# [I 2025-03-05 12:17:13,559] Trial 93 finished with values: [97.2400853893116, 14.333333333333334] and parameters: {'trade_enter': 1.5681258520837216, 'fixed_profit_value': 0.7528589111406004, 'barNo_before_EOD': 16, 'min_bar_enter_trade_before_EOD': 17, 'risk': 0.2550828547628872}.
# [I 2025-03-05 12:17:13,664] Trial 94 finished with values: [-988.9073663284443, 14.386831275720164] and parameters: {'trade_enter': 0.6401417252346313, 'fixed_profit_value': 3.3442076312363063, 'barNo_before_EOD': 3, 'min_bar_enter_trade_before_EOD': 16, 'risk': 1.755620394665416}.
# [I 2025-03-05 12:17:13,757] Trial 95 finished with values: [-28.076878034603684, 31.2] and parameters: {'trade_enter': 1.9145850929245918, 'fixed_profit_value': 2.8261305418820695, 'barNo_before_EOD': 25, 'min_bar_enter_trade_before_EOD': 9, 'risk': 0.9934742085871875}.
# [I 2025-03-05 12:17:13,863] Trial 96 finished with values: [235.77581739071888, 4.1011080332409975] and parameters: {'trade_enter': 0.4068723732612485, 'fixed_profit_value': 1.9828685579181533, 'barNo_before_EOD': 25, 'min_bar_enter_trade_before_EOD': 9, 'risk': 0.6159897123693742}.
# [I 2025-03-05 12:17:13,956] Trial 97 finished with values: [44.65204121761262, 29.857142857142858] and parameters: {'trade_enter': 1.8234600225199906, 'fixed_profit_value': 1.4884013739204207, 'barNo_before_EOD': 4, 'min_bar_enter_trade_before_EOD': 6, 'risk': 1.992307203596933}.
# [I 2025-03-05 12:17:14,055] Trial 98 finished with values: [331.99653027973096, 10.865116279069767] and parameters: {'trade_enter': 0.7490144076499972, 'fixed_profit_value': 1.8872120398683132, 'barNo_before_EOD': 25, 'min_bar_enter_trade_before_EOD': 22, 'risk': 0.2550828547628872}.
# [I 2025-03-05 12:17:14,159] Trial 99 finished with values: [160.98320857248578, 6.3346693386773545] and parameters: {'trade_enter': 0.27003657913867724, 'fixed_profit_value': 2.183177813747744, 'barNo_before_EOD': 8, 'min_bar_enter_trade_before_EOD': 21, 'risk': 0.6119784699447465}.
# [I 2025-03-05 12:17:14,268] Trial 100 finished with values: [326.6377930245694, 3.7069377990430623] and parameters: {'trade_enter': 0.27003657913867724, 'fixed_profit_value': 2.646783146654191, 'barNo_before_EOD': 23, 'min_bar_enter_trade_before_EOD': 9, 'risk': 0.3236483973681884}.
# [I 2025-03-05 12:17:14,377] Trial 101 finished with values: [357.56369913091663, 3.0216271884654993] and parameters: {'trade_enter': 0.27003657913867724, 'fixed_profit_value': 2.4355406890217037, 'barNo_before_EOD': 30, 'min_bar_enter_trade_before_EOD': 9, 'risk': 0.1969673464132436}.
# [I 2025-03-05 12:17:14,485] Trial 102 finished with values: [-31.856136422807907, 4.187096774193549] and parameters: {'trade_enter': 0.28544500327503547, 'fixed_profit_value': 0.6958592665234559, 'barNo_before_EOD': 9, 'min_bar_enter_trade_before_EOD': 11, 'risk': 0.4843720349797705}.
# [I 2025-03-05 12:17:14,587] Trial 103 finished with values: [81.0097632939233, 9.657794676806084] and parameters: {'trade_enter': 0.6900208706478153, 'fixed_profit_value': 3.1038432059339693, 'barNo_before_EOD': 24, 'min_bar_enter_trade_before_EOD': 19, 'risk': 0.4962286956790668}.
# [I 2025-03-05 12:17:14,723] Trial 104 finished with values: [-70.12376692756393, 40.44444444444444] and parameters: {'trade_enter': 1.6864418997476742, 'fixed_profit_value': 3.1038432059339693, 'barNo_before_EOD': 16, 'min_bar_enter_trade_before_EOD': 24, 'risk': 1.7007334453148613}.
# [I 2025-03-05 12:17:14,829] Trial 105 finished with values: [-22.913330209538174, 6.8977272727272725] and parameters: {'trade_enter': 0.5230456997244393, 'fixed_profit_value': 3.4350380563930165, 'barNo_before_EOD': 30, 'min_bar_enter_trade_before_EOD': 25, 'risk': 1.5839847144183918}.
# [I 2025-03-05 12:17:14,929] Trial 106 finished with values: [283.3501878611718, 13.04] and parameters: {'trade_enter': 0.5998827992259507, 'fixed_profit_value': 3.717893646927233, 'barNo_before_EOD': 10, 'min_bar_enter_trade_before_EOD': 28, 'risk': 0.6119784699447465}.
# [I 2025-03-05 12:17:15,033] Trial 107 finished with values: [-197.53653027454072, 5.352530541012216] and parameters: {'trade_enter': 0.5052464486469619, 'fixed_profit_value': 0.7384023657529258, 'barNo_before_EOD': 10, 'min_bar_enter_trade_before_EOD': 9, 'risk': 0.6119784699447465}.
# [I 2025-03-05 12:17:15,137] Trial 108 finished with values: [-308.7734406115693, 5.049713193116634] and parameters: {'trade_enter': 0.4068723732612485, 'fixed_profit_value': 2.6994113867355227, 'barNo_before_EOD': 28, 'min_bar_enter_trade_before_EOD': 21, 'risk': 1.6242209741136202}.
# [I 2025-03-05 12:17:15,240] Trial 109 finished with values: [323.69186673235856, 4.821612349914237] and parameters: {'trade_enter': 0.4938440323346971, 'fixed_profit_value': 1.2080846699116008, 'barNo_before_EOD': 26, 'min_bar_enter_trade_before_EOD': 13, 'risk': 0.4843720349797705}.
# [I 2025-03-05 12:17:15,345] Trial 110 finished with values: [183.62399407111195, 5.242537313432836] and parameters: {'trade_enter': 0.4938440323346971, 'fixed_profit_value': 3.3323076343759275, 'barNo_before_EOD': 26, 'min_bar_enter_trade_before_EOD': 13, 'risk': 0.5402445398125701}.
# [I 2025-03-05 12:17:15,443] Trial 111 finished with values: [135.9896149776166, 24.83695652173913] and parameters: {'trade_enter': 1.0134336701319175, 'fixed_profit_value': 3.7433312658397573, 'barNo_before_EOD': 14, 'min_bar_enter_trade_before_EOD': 18, 'risk': 0.8734880156506627}.
# [I 2025-03-05 12:17:15,544] Trial 112 finished with values: [-62.46137128355609, 9.785714285714286] and parameters: {'trade_enter': 0.5705546154098249, 'fixed_profit_value': 1.9828685579181533, 'barNo_before_EOD': 17, 'min_bar_enter_trade_before_EOD': 17, 'risk': 1.2375042259036018}.
# [I 2025-03-05 12:17:15,649] Trial 113 finished with values: [122.46967837517738, 5.850719424460432] and parameters: {'trade_enter': 0.2544820047892392, 'fixed_profit_value': 2.6560895479646685, 'barNo_before_EOD': 13, 'min_bar_enter_trade_before_EOD': 14, 'risk': 0.6119784699447465}.
# [I 2025-03-05 12:17:15,751] Trial 114 finished with values: [-419.4914829392023, 6.530555555555556] and parameters: {'trade_enter': 0.7276896391548664, 'fixed_profit_value': 1.2080846699116008, 'barNo_before_EOD': 25, 'min_bar_enter_trade_before_EOD': 12, 'risk': 1.5926258388126715}.
# [I 2025-03-05 12:17:15,851] Trial 115 finished with values: [271.417012056994, 11.685446009389672] and parameters: {'trade_enter': 0.7490144076499972, 'fixed_profit_value': 2.4355406890217037, 'barNo_before_EOD': 23, 'min_bar_enter_trade_before_EOD': 19, 'risk': 0.3236483973681884}.
# [I 2025-03-05 12:17:15,951] Trial 116 finished with values: [-92.10120701954612, 6.201591511936339] and parameters: {'trade_enter': 0.7490144076499972, 'fixed_profit_value': 2.706273568429191, 'barNo_before_EOD': 30, 'min_bar_enter_trade_before_EOD': 9, 'risk': 1.180342289789772}.
# [I 2025-03-05 12:17:16,045] Trial 117 finished with values: [221.18203291389463, 33.958333333333336] and parameters: {'trade_enter': 1.460660175591236, 'fixed_profit_value': 2.6560895479646685, 'barNo_before_EOD': 9, 'min_bar_enter_trade_before_EOD': 30, 'risk': 0.1857154565247184}.
# [I 2025-03-05 12:17:16,145] Trial 118 finished with values: [-940.2559391097582, 6.328990228013029] and parameters: {'trade_enter': 0.7276896391548664, 'fixed_profit_value': 0.5070405216466397, 'barNo_before_EOD': 9, 'min_bar_enter_trade_before_EOD': 28, 'risk': 1.6666058218075142}.
# [I 2025-03-05 12:17:16,242] Trial 119 finished with values: [341.29405168021094, 23.54054054054054] and parameters: {'trade_enter': 0.9576147847976907, 'fixed_profit_value': 2.6816015441213725, 'barNo_before_EOD': 11, 'min_bar_enter_trade_before_EOD': 11, 'risk': 0.3236483973681884}.
# [I 2025-03-05 12:17:16,338] Trial 120 finished with values: [-68.91765345972708, 17.1625] and parameters: {'trade_enter': 1.1934618968864492, 'fixed_profit_value': 3.7433312658397573, 'barNo_before_EOD': 28, 'min_bar_enter_trade_before_EOD': 18, 'risk': 0.7995290667038013}.
# [I 2025-03-05 12:17:16,446] Trial 121 finished with values: [318.3318707905851, 3.998531571218796] and parameters: {'trade_enter': 0.4068723732612485, 'fixed_profit_value': 3.800797735577176, 'barNo_before_EOD': 30, 'min_bar_enter_trade_before_EOD': 14, 'risk': 0.25154036875597646}.
# [I 2025-03-05 12:17:16,555] Trial 122 finished with values: [345.19727634431035, 2.998810939357907] and parameters: {'trade_enter': 0.4068723732612485, 'fixed_profit_value': 0.6958592665234559, 'barNo_before_EOD': 30, 'min_bar_enter_trade_before_EOD': 15, 'risk': 0.25648838764885384}.
# [I 2025-03-05 12:17:16,651] Trial 123 finished with values: [-3.489329623270347, 7.7025316455696204] and parameters: {'trade_enter': 1.0082677448927666, 'fixed_profit_value': 0.6561685933349759, 'barNo_before_EOD': 28, 'min_bar_enter_trade_before_EOD': 20, 'risk': 0.8984061883234522}.
# [I 2025-03-05 12:17:16,751] Trial 124 finished with values: [104.8803013712942, 19.253246753246753] and parameters: {'trade_enter': 0.7910953015158056, 'fixed_profit_value': 2.8422941860466393, 'barNo_before_EOD': 9, 'min_bar_enter_trade_before_EOD': 19, 'risk': 0.4843720349797705}.
# [I 2025-03-05 12:17:16,853] Trial 125 finished with values: [240.12695233495563, 6.986547085201794] and parameters: {'trade_enter': 0.35713331663800346, 'fixed_profit_value': 2.6560895479646685, 'barNo_before_EOD': 13, 'min_bar_enter_trade_before_EOD': 21, 'risk': 0.4962286956790668}.
# [I 2025-03-05 12:17:16,954] Trial 126 finished with values: [-288.97797481661485, 15.373684210526315] and parameters: {'trade_enter': 0.6900208706478153, 'fixed_profit_value': 2.9051204410664977, 'barNo_before_EOD': 9, 'min_bar_enter_trade_before_EOD': 26, 'risk': 1.3114314679288068}.
# [I 2025-03-05 12:17:17,060] Trial 127 finished with values: [30.794466350031755, 6.589189189189189] and parameters: {'trade_enter': 0.28544500327503547, 'fixed_profit_value': 3.58718936806696, 'barNo_before_EOD': 5, 'min_bar_enter_trade_before_EOD': 9, 'risk': 0.6558063439065142}.
# [I 2025-03-05 12:17:17,161] Trial 128 finished with values: [347.612615806732, 6.8962536023054755] and parameters: {'trade_enter': 0.4068723732612485, 'fixed_profit_value': 3.541619150554635, 'barNo_before_EOD': 30, 'min_bar_enter_trade_before_EOD': 30, 'risk': 0.14614938645857178}.
# [I 2025-03-05 12:17:17,265] Trial 129 finished with values: [-646.8875228071574, 4.895238095238096] and parameters: {'trade_enter': 0.4068723732612485, 'fixed_profit_value': 1.2080846699116008, 'barNo_before_EOD': 28, 'min_bar_enter_trade_before_EOD': 23, 'risk': 1.5839847144183918}.
# [I 2025-03-05 12:17:17,371] Trial 130 finished with values: [-421.699322129639, 6.693957115009747] and parameters: {'trade_enter': 0.3899953954728604, 'fixed_profit_value': 1.8216757117308402, 'barNo_before_EOD': 10, 'min_bar_enter_trade_before_EOD': 9, 'risk': 1.2903335583684574}.
# [I 2025-03-05 12:17:17,478] Trial 131 finished with values: [-354.3589616530114, 4.496913580246914] and parameters: {'trade_enter': 0.27003657913867724, 'fixed_profit_value': 1.9828685579181533, 'barNo_before_EOD': 23, 'min_bar_enter_trade_before_EOD': 17, 'risk': 1.9345244710833178}.
# [I 2025-03-05 12:17:17,587] Trial 132 finished with values: [-457.11856817665426, 4.03972602739726] and parameters: {'trade_enter': 0.4068723732612485, 'fixed_profit_value': 1.7537050215534613, 'barNo_before_EOD': 25, 'min_bar_enter_trade_before_EOD': 9, 'risk': 1.59499461827985}.
# [I 2025-03-05 12:17:17,690] Trial 133 finished with values: [405.4737309990431, 8.346883468834688] and parameters: {'trade_enter': 0.5998827992259507, 'fixed_profit_value': 2.4355406890217037, 'barNo_before_EOD': 15, 'min_bar_enter_trade_before_EOD': 9, 'risk': 0.1969673464132436}.
# [I 2025-03-05 12:17:17,799] Trial 134 finished with values: [319.7216908960811, 4.7936507936507935] and parameters: {'trade_enter': 0.23705063979593397, 'fixed_profit_value': 1.0971835689481602, 'barNo_before_EOD': 13, 'min_bar_enter_trade_before_EOD': 12, 'risk': 0.3791251732136737}.
# [I 2025-03-05 12:17:17,911] Trial 135 finished with values: [170.5829600086329, 2.2001682085786376] and parameters: {'trade_enter': 0.27003657913867724, 'fixed_profit_value': 0.4387694920569682, 'barNo_before_EOD': 21, 'min_bar_enter_trade_before_EOD': 12, 'risk': 0.3791251732136737}.
# [I 2025-03-05 12:17:18,010] Trial 136 finished with values: [186.52218631819437, 16.464285714285715] and parameters: {'trade_enter': 0.8260012386141374, 'fixed_profit_value': 1.5766561506710883, 'barNo_before_EOD': 16, 'min_bar_enter_trade_before_EOD': 26, 'risk': 0.4962286956790668}.
# [I 2025-03-05 12:17:18,118] Trial 137 finished with values: [54.69471685643833, 3.572429906542056] and parameters: {'trade_enter': 0.28544500327503547, 'fixed_profit_value': 3.3323076343759275, 'barNo_before_EOD': 25, 'min_bar_enter_trade_before_EOD': 9, 'risk': 0.6558063439065142}.
# [I 2025-03-05 12:17:18,224] Trial 138 finished with values: [-197.53653027454072, 5.352530541012216] and parameters: {'trade_enter': 0.5052464486469619, 'fixed_profit_value': 0.7384023657529258, 'barNo_before_EOD': 10, 'min_bar_enter_trade_before_EOD': 9, 'risk': 0.6119784699447465}.
# [I 2025-03-05 12:17:18,325] Trial 139 finished with values: [62.69343417358422, 13.9] and parameters: {'trade_enter': 0.6430064871262209, 'fixed_profit_value': 3.717893646927233, 'barNo_before_EOD': 10, 'min_bar_enter_trade_before_EOD': 21, 'risk': 0.6119784699447465}.
# [I 2025-03-05 12:17:18,424] Trial 140 finished with values: [20.030273236147785, 13.729508196721312] and parameters: {'trade_enter': 1.0134336701319175, 'fixed_profit_value': 2.183177813747744, 'barNo_before_EOD': 28, 'min_bar_enter_trade_before_EOD': 21, 'risk': 0.7995290667038013}.
# [I 2025-03-05 12:17:18,529] Trial 141 finished with values: [183.62399407111195, 5.242537313432836] and parameters: {'trade_enter': 0.4938440323346971, 'fixed_profit_value': 3.3323076343759275, 'barNo_before_EOD': 26, 'min_bar_enter_trade_before_EOD': 13, 'risk': 0.5402445398125701}.
# [I 2025-03-05 12:17:18,628] Trial 142 finished with values: [159.43115541615086, 25.043478260869566] and parameters: {'trade_enter': 1.0134336701319175, 'fixed_profit_value': 3.7433312658397573, 'barNo_before_EOD': 15, 'min_bar_enter_trade_before_EOD': 18, 'risk': 0.7995290667038013}.
# [I 2025-03-05 12:17:18,734] Trial 143 finished with values: [293.7861777036098, 4.595238095238095] and parameters: {'trade_enter': 0.4938440323346971, 'fixed_profit_value': 1.8872120398683132, 'barNo_before_EOD': 26, 'min_bar_enter_trade_before_EOD': 9, 'risk': 0.5402445398125701}.
# [I 2025-03-05 12:17:18,831] Trial 144 finished with values: [112.52161786614282, 17.747252747252748] and parameters: {'trade_enter': 1.1044401224762916, 'fixed_profit_value': 1.053987761756541, 'barNo_before_EOD': 9, 'min_bar_enter_trade_before_EOD': 23, 'risk': 0.6898535769502014}.
# [I 2025-03-05 12:17:18,932] Trial 145 finished with values: [163.0191648888252, 9.470967741935484] and parameters: {'trade_enter': 0.5230456997244393, 'fixed_profit_value': 1.6348059606847494, 'barNo_before_EOD': 10, 'min_bar_enter_trade_before_EOD': 25, 'risk': 0.7744055259301182}.
# [I 2025-03-05 12:17:19,033] Trial 146 finished with values: [282.1325299038295, 14.58695652173913] and parameters: {'trade_enter': 0.6820961089420988, 'fixed_profit_value': 3.2380872402121863, 'barNo_before_EOD': 6, 'min_bar_enter_trade_before_EOD': 13, 'risk': 0.25154036875597646}.
# [I 2025-03-05 12:17:19,132] Trial 147 finished with values: [229.29515271288753, 14.8125] and parameters: {'trade_enter': 0.9601334454846664, 'fixed_profit_value': 1.0971835689481602, 'barNo_before_EOD': 13, 'min_bar_enter_trade_before_EOD': 12, 'risk': 0.3791251732136737}.
# [I 2025-03-05 12:17:19,225] Trial 148 finished with values: [61.98023171061315, 22.03846153846154] and parameters: {'trade_enter': 1.5149179188388233, 'fixed_profit_value': 2.4355406890217037, 'barNo_before_EOD': 30, 'min_bar_enter_trade_before_EOD': 24, 'risk': 0.7677100091886935}.
# [I 2025-03-05 12:17:19,334] Trial 149 finished with values: [-948.4310725888222, 7.088729016786571] and parameters: {'trade_enter': 0.5998827992259507, 'fixed_profit_value': 1.2080846699116008, 'barNo_before_EOD': 15, 'min_bar_enter_trade_before_EOD': 9, 'risk': 1.7476362814664512}.
# [I 2025-03-05 12:17:19,440] Trial 150 finished with values: [-449.75706648956543, 6.596715328467154] and parameters: {'trade_enter': 0.28544500327503547, 'fixed_profit_value': 2.9676979698113795, 'barNo_before_EOD': 5, 'min_bar_enter_trade_before_EOD': 11, 'risk': 1.2634581923187107}.
# [I 2025-03-05 12:17:19,547] Trial 151 finished with values: [-1062.993556713801, 3.3125683060109288] and parameters: {'trade_enter': 0.28544500327503547, 'fixed_profit_value': 1.2080846699116008, 'barNo_before_EOD': 25, 'min_bar_enter_trade_before_EOD': 9, 'risk': 1.5839847144183918}.
# [I 2025-03-05 12:17:19,653] Trial 152 finished with values: [314.71019756869356, 2.3372340425531917] and parameters: {'trade_enter': 0.4938440323346971, 'fixed_profit_value': 0.4387694920569682, 'barNo_before_EOD': 26, 'min_bar_enter_trade_before_EOD': 10, 'risk': 0.3236483973681884}.
# [I 2025-03-05 12:17:19,758] Trial 153 finished with values: [452.874607572455, 4.484662576687117] and parameters: {'trade_enter': 0.27003657913867724, 'fixed_profit_value': 1.8872120398683132, 'barNo_before_EOD': 23, 'min_bar_enter_trade_before_EOD': 17, 'risk': 0.2550828547628872}.
# [I 2025-03-05 12:17:19,859] Trial 154 finished with values: [-467.85839935785157, 8.235294117647058] and parameters: {'trade_enter': 0.4068723732612485, 'fixed_profit_value': 2.711243170518408, 'barNo_before_EOD': 8, 'min_bar_enter_trade_before_EOD': 26, 'risk': 1.5839847144183918}.
# [I 2025-03-05 12:17:19,954] Trial 155 finished with values: [23.15180438487171, 20.96153846153846] and parameters: {'trade_enter': 1.3623748873091956, 'fixed_profit_value': 3.800797735577176, 'barNo_before_EOD': 23, 'min_bar_enter_trade_before_EOD': 14, 'risk': 0.7928509583225294}.
# [I 2025-03-05 12:17:20,055] Trial 156 finished with values: [145.63210289103162, 6.375634517766497] and parameters: {'trade_enter': 0.4068723732612485, 'fixed_profit_value': 2.6994113867355227, 'barNo_before_EOD': 28, 'min_bar_enter_trade_before_EOD': 27, 'risk': 0.6300982878526887}.
# [I 2025-03-05 12:17:20,155] Trial 157 finished with values: [198.49709959196858, 22.676258992805757] and parameters: {'trade_enter': 0.8562299837668061, 'fixed_profit_value': 3.800797735577176, 'barNo_before_EOD': 6, 'min_bar_enter_trade_before_EOD': 13, 'risk': 0.3236483973681884}.
# [I 2025-03-05 12:17:20,255] Trial 158 finished with values: [198.49709959196858, 22.676258992805757] and parameters: {'trade_enter': 0.8562299837668061, 'fixed_profit_value': 3.800797735577176, 'barNo_before_EOD': 6, 'min_bar_enter_trade_before_EOD': 13, 'risk': 0.3236483973681884}.
# [I 2025-03-05 12:17:20,355] Trial 159 finished with values: [262.20160829356644, 10.128919860627178] and parameters: {'trade_enter': 0.5230456997244393, 'fixed_profit_value': 3.717893646927233, 'barNo_before_EOD': 18, 'min_bar_enter_trade_before_EOD': 25, 'risk': 0.6119784699447465}.
# [I 2025-03-05 12:17:20,501] Trial 160 finished with values: [186.00046161930385, 4.06651376146789] and parameters: {'trade_enter': 0.7490144076499972, 'fixed_profit_value': 0.5462915137160349, 'barNo_before_EOD': 26, 'min_bar_enter_trade_before_EOD': 13, 'risk': 0.4843720349797705}.
# [I 2025-03-05 12:17:20,612] Trial 161 finished with values: [293.7861777036098, 4.595238095238095] and parameters: {'trade_enter': 0.4938440323346971, 'fixed_profit_value': 1.8872120398683132, 'barNo_before_EOD': 26, 'min_bar_enter_trade_before_EOD': 9, 'risk': 0.5402445398125701}.
# [I 2025-03-05 12:17:20,722] Trial 162 finished with values: [-2603.607221712622, 2.694392523364486] and parameters: {'trade_enter': 0.27003657913867724, 'fixed_profit_value': 0.4387694920569682, 'barNo_before_EOD': 10, 'min_bar_enter_trade_before_EOD': 10, 'risk': 1.5839847144183918}.
# [I 2025-03-05 12:17:20,824] Trial 163 finished with values: [-66.40179110271691, 5.015473887814314] and parameters: {'trade_enter': 0.5230456997244393, 'fixed_profit_value': 3.7433312658397573, 'barNo_before_EOD': 30, 'min_bar_enter_trade_before_EOD': 15, 'risk': 1.6242209741136202}.
# [I 2025-03-05 12:17:20,928] Trial 164 finished with values: [442.0492961625828, 13.842696629213483] and parameters: {'trade_enter': 0.7490144076499972, 'fixed_profit_value': 1.8872120398683132, 'barNo_before_EOD': 21, 'min_bar_enter_trade_before_EOD': 22, 'risk': 0.14614938645857178}.
# [I 2025-03-05 12:17:21,022] Trial 165 finished with values: [236.42833007480613, 44.95238095238095] and parameters: {'trade_enter': 1.5407986629556414, 'fixed_profit_value': 3.7433312658397573, 'barNo_before_EOD': 8, 'min_bar_enter_trade_before_EOD': 24, 'risk': 0.2550828547628872}.
# [I 2025-03-05 12:17:21,128] Trial 166 finished with values: [-636.6516462985273, 3.7541899441340782] and parameters: {'trade_enter': 0.4068723732612485, 'fixed_profit_value': 1.2080846699116008, 'barNo_before_EOD': 30, 'min_bar_enter_trade_before_EOD': 15, 'risk': 1.5839847144183918}.
# [I 2025-03-05 12:17:21,226] Trial 167 finished with values: [325.22857204397485, 5.970802919708029] and parameters: {'trade_enter': 0.8424741763458221, 'fixed_profit_value': 0.6958592665234559, 'barNo_before_EOD': 30, 'min_bar_enter_trade_before_EOD': 17, 'risk': 0.25648838764885384}.
# [I 2025-03-05 12:17:21,321] Trial 168 finished with values: [58.28440928705077, 16.477272727272727] and parameters: {'trade_enter': 1.4484034872353493, 'fixed_profit_value': 3.4350380563930165, 'barNo_before_EOD': 25, 'min_bar_enter_trade_before_EOD': 9, 'risk': 0.6159897123693742}.
# [I 2025-03-05 12:17:21,424] Trial 169 finished with values: [233.01583352289703, 5.767676767676767] and parameters: {'trade_enter': 0.27003657913867724, 'fixed_profit_value': 2.9304488891981064, 'barNo_before_EOD': 21, 'min_bar_enter_trade_before_EOD': 21, 'risk': 0.4962286956790668}.
# [I 2025-03-05 12:17:21,527] Trial 170 finished with values: [238.4031496694072, 5.660980810234541] and parameters: {'trade_enter': 0.39251710715681387, 'fixed_profit_value': 1.8872120398683132, 'barNo_before_EOD': 26, 'min_bar_enter_trade_before_EOD': 23, 'risk': 0.6119784699447465}.
# [I 2025-03-05 12:17:21,625] Trial 171 finished with values: [207.9603083667445, 10.52155172413793] and parameters: {'trade_enter': 0.8562299837668061, 'fixed_profit_value': 3.800797735577176, 'barNo_before_EOD': 23, 'min_bar_enter_trade_before_EOD': 10, 'risk': 0.25154036875597646}.
# [I 2025-03-05 12:17:21,731] Trial 172 finished with values: [78.40833568448289, 4.4273255813953485] and parameters: {'trade_enter': 0.4068723732612485, 'fixed_profit_value': 1.9828685579181533, 'barNo_before_EOD': 23, 'min_bar_enter_trade_before_EOD': 9, 'risk': 1.0464052536709045}.
# [I 2025-03-05 12:17:21,832] Trial 173 finished with values: [-469.0160286782673, 10.315068493150685] and parameters: {'trade_enter': 0.5052464486469619, 'fixed_profit_value': 3.3323076343759275, 'barNo_before_EOD': 10, 'min_bar_enter_trade_before_EOD': 27, 'risk': 1.890311213528973}.
# [I 2025-03-05 12:17:21,932] Trial 174 finished with values: [-859.9618784384077, 7.364457831325301] and parameters: {'trade_enter': 0.7211518666133638, 'fixed_profit_value': 0.7384023657529258, 'barNo_before_EOD': 10, 'min_bar_enter_trade_before_EOD': 9, 'risk': 1.2770569316219131}.
# [I 2025-03-05 12:17:22,026] Trial 175 finished with values: [84.79726620770596, 21.025] and parameters: {'trade_enter': 1.336295338621286, 'fixed_profit_value': 2.4355406890217037, 'barNo_before_EOD': 30, 'min_bar_enter_trade_before_EOD': 25, 'risk': 0.14614938645857178}.
# [I 2025-03-05 12:17:22,121] Trial 176 finished with values: [63.66110843541338, 15.525423728813559] and parameters: {'trade_enter': 1.3758278419945953, 'fixed_profit_value': 3.532013408840945, 'barNo_before_EOD': 26, 'min_bar_enter_trade_before_EOD': 9, 'risk': 0.6159897123693742}.
# [I 2025-03-05 12:17:22,227] Trial 177 finished with values: [394.9824674707729, 3.8743654822335025] and parameters: {'trade_enter': 0.23705063979593397, 'fixed_profit_value': 1.9828685579181533, 'barNo_before_EOD': 22, 'min_bar_enter_trade_before_EOD': 12, 'risk': 0.27269949123510706}.
# [I 2025-03-05 12:17:22,338] Trial 178 finished with values: [148.21008536843794, 2.1213553979511426] and parameters: {'trade_enter': 0.27003657913867724, 'fixed_profit_value': 0.4387694920569682, 'barNo_before_EOD': 21, 'min_bar_enter_trade_before_EOD': 9, 'risk': 0.3791251732136737}.
# [I 2025-03-05 12:17:22,441] Trial 179 finished with values: [46.2757330043426, 3.7815750371471024] and parameters: {'trade_enter': 0.5052464486469619, 'fixed_profit_value': 0.7384023657529258, 'barNo_before_EOD': 26, 'min_bar_enter_trade_before_EOD': 13, 'risk': 0.4843720349797705}.
# [I 2025-03-05 12:17:22,545] Trial 180 finished with values: [5.97214881390816, 4.650918635170604] and parameters: {'trade_enter': 0.7490144076499972, 'fixed_profit_value': 0.6958592665234559, 'barNo_before_EOD': 30, 'min_bar_enter_trade_before_EOD': 16, 'risk': 0.7330555261313886}.
# [I 2025-03-05 12:17:22,642] Trial 181 finished with values: [424.6774908926703, 14.966666666666667] and parameters: {'trade_enter': 0.8128783991259911, 'fixed_profit_value': 1.1838785583228795, 'barNo_before_EOD': 15, 'min_bar_enter_trade_before_EOD': 30, 'risk': 0.14614938645857178}.
# [I 2025-03-05 12:17:22,741] Trial 182 finished with values: [219.8848312607654, 5.156626506024097] and parameters: {'trade_enter': 0.7490144076499972, 'fixed_profit_value': 0.5478212007645854, 'barNo_before_EOD': 25, 'min_bar_enter_trade_before_EOD': 22, 'risk': 0.4843720349797705}.
# [I 2025-03-05 12:17:22,835] Trial 183 finished with values: [-47.37740065180749, 15.126436781609195] and parameters: {'trade_enter': 1.264788772009525, 'fixed_profit_value': 1.9828685579181533, 'barNo_before_EOD': 25, 'min_bar_enter_trade_before_EOD': 9, 'risk': 0.6159897123693742}.
# [I 2025-03-05 12:17:22,933] Trial 184 finished with values: [172.20540614662326, 8.716346153846153] and parameters: {'trade_enter': 0.9576147847976907, 'fixed_profit_value': 0.4387694920569682, 'barNo_before_EOD': 11, 'min_bar_enter_trade_before_EOD': 10, 'risk': 0.3236483973681884}.
# [I 2025-03-05 12:17:23,030] Trial 185 finished with values: [222.2987677270061, 14.94078947368421] and parameters: {'trade_enter': 0.8562299837668061, 'fixed_profit_value': 3.800797735577176, 'barNo_before_EOD': 25, 'min_bar_enter_trade_before_EOD': 22, 'risk': 0.25154036875597646}.
# [I 2025-03-05 12:17:23,132] Trial 186 finished with values: [264.2513463594312, 6.151111111111111] and parameters: {'trade_enter': 0.27003657913867724, 'fixed_profit_value': 3.1313410301261793, 'barNo_before_EOD': 21, 'min_bar_enter_trade_before_EOD': 28, 'risk': 0.3791251732136737}.
# [I 2025-03-05 12:17:23,235] Trial 187 finished with values: [166.68980378531188, 9.074792243767313] and parameters: {'trade_enter': 0.4938440323346971, 'fixed_profit_value': 2.6560895479646685, 'barNo_before_EOD': 13, 'min_bar_enter_trade_before_EOD': 13, 'risk': 0.5402445398125701}.
# [I 2025-03-05 12:17:23,343] Trial 188 finished with values: [-1121.7186314495732, 4.305806451612903] and parameters: {'trade_enter': 0.28544500327503547, 'fixed_profit_value': 0.6958592665234559, 'barNo_before_EOD': 3, 'min_bar_enter_trade_before_EOD': 11, 'risk': 1.0048713618143892}.
# [I 2025-03-05 12:17:23,449] Trial 189 finished with values: [164.79198681625653, 3.59375] and parameters: {'trade_enter': 0.28544500327503547, 'fixed_profit_value': 3.3323076343759275, 'barNo_before_EOD': 26, 'min_bar_enter_trade_before_EOD': 11, 'risk': 0.4843720349797705}.
# [I 2025-03-05 12:17:23,544] Trial 190 finished with values: [72.22024705979703, 8.628571428571428] and parameters: {'trade_enter': 1.5675414776609393, 'fixed_profit_value': 0.4387694920569682, 'barNo_before_EOD': 21, 'min_bar_enter_trade_before_EOD': 12, 'risk': 0.3791251732136737}.
# [I 2025-03-05 12:17:23,651] Trial 191 finished with values: [-354.3589616530114, 4.496913580246914] and parameters: {'trade_enter': 0.27003657913867724, 'fixed_profit_value': 1.9828685579181533, 'barNo_before_EOD': 23, 'min_bar_enter_trade_before_EOD': 17, 'risk': 1.9345244710833178}.
# [I 2025-03-05 12:17:23,759] Trial 192 finished with values: [-257.7129383566367, 4.7936507936507935] and parameters: {'trade_enter': 0.23705063979593397, 'fixed_profit_value': 1.0971835689481602, 'barNo_before_EOD': 13, 'min_bar_enter_trade_before_EOD': 12, 'risk': 0.8014820998544098}.
# [I 2025-03-05 12:17:23,862] Trial 193 finished with values: [207.01477834262832, 7.152046783625731] and parameters: {'trade_enter': 0.7276896391548664, 'fixed_profit_value': 1.9828685579181533, 'barNo_before_EOD': 25, 'min_bar_enter_trade_before_EOD': 11, 'risk': 0.4962286956790668}.
# [I 2025-03-05 12:17:23,957] Trial 194 finished with values: [153.00731469368955, 21.677419354838708] and parameters: {'trade_enter': 1.3796610546309178, 'fixed_profit_value': 1.7537050215534613, 'barNo_before_EOD': 30, 'min_bar_enter_trade_before_EOD': 30, 'risk': 0.14614938645857178}.
# [I 2025-03-05 12:17:24,065] Trial 195 finished with values: [192.83012351963458, 6.328467153284672] and parameters: {'trade_enter': 0.28544500327503547, 'fixed_profit_value': 3.013013095841041, 'barNo_before_EOD': 9, 'min_bar_enter_trade_before_EOD': 11, 'risk': 0.4843720349797705}.
# [I 2025-03-05 12:17:24,172] Trial 196 finished with values: [342.3263888029654, 5.7243150684931505] and parameters: {'trade_enter': 0.35713331663800346, 'fixed_profit_value': 2.6560895479646685, 'barNo_before_EOD': 13, 'min_bar_enter_trade_before_EOD': 9, 'risk': 0.3236483973681884}.
# [I 2025-03-05 12:17:24,279] Trial 197 finished with values: [345.19727634431035, 2.998810939357907] and parameters: {'trade_enter': 0.4068723732612485, 'fixed_profit_value': 0.6958592665234559, 'barNo_before_EOD': 30, 'min_bar_enter_trade_before_EOD': 15, 'risk': 0.25648838764885384}.
# [I 2025-03-05 12:17:24,389] Trial 198 finished with values: [390.7712587958589, 3.023877745940783] and parameters: {'trade_enter': 0.27003657913867724, 'fixed_profit_value': 0.909653662514717, 'barNo_before_EOD': 23, 'min_bar_enter_trade_before_EOD': 6, 'risk': 0.3236483973681884}.
# [I 2025-03-05 12:17:24,496] Trial 199 finished with values: [170.81883808727565, 4.141630901287554] and parameters: {'trade_enter': 0.36726902047278176, 'fixed_profit_value': 3.3323076343759275, 'barNo_before_EOD': 26, 'min_bar_enter_trade_before_EOD': 13, 'risk': 0.5402445398125701}.

# %%
sorted_trials = sorted(trading_study_2.best_trials, key=lambda t: t.values[0], reverse=True)
for trial in sorted_trials:
    print(f"Trial number : {trial.number}, Balance : {trial.values[0]}, Trade Length : {trial.values[1]}")
# Out:
# Trial number : 52, Balance : 478.59377210835726, Trade Length : 6.725
# Trial number : 153, Balance : 452.874607572455, Trade Length : 4.484662576687117
# Trial number : 177, Balance : 394.9824674707729, Trade Length : 3.8743654822335025
# Trial number : 198, Balance : 390.7712587958589, Trade Length : 3.023877745940783
# Trial number : 101, Balance : 357.56369913091663, Trade Length : 3.0216271884654993
# Trial number : 122, Balance : 345.19727634431035, Trade Length : 2.998810939357907
# Trial number : 197, Balance : 345.19727634431035, Trade Length : 2.998810939357907
# Trial number : 152, Balance : 314.71019756869356, Trade Length : 2.3372340425531917
# Trial number : 67, Balance : 301.77960588173283, Trade Length : 2.06484375

# %%
sorted_trials[0].params
# Out:
# {'trade_enter': 0.5230456997244393,
#  'fixed_profit_value': 2.4355406890217037,
#  'barNo_before_EOD': 30,
#  'min_bar_enter_trade_before_EOD': 25,
#  'risk': 0.14614938645857178}

# %%
for trial in trading_study_2.trials:
    print(f"Trial {trial.number}: Best value = {trial.values}")
# Out:
# Trial 0: Best value = [420.80199689188004, 263.0]
# Trial 1: Best value = [-49.93553682101156, 3.0]
# Trial 2: Best value = [-3.7528638737576046, 290.0]
# Trial 3: Best value = [132.07973992854397, 85.0]
# Trial 4: Best value = [5.487857695356613, 133.0]
# Trial 5: Best value = [92.4904572949738, 24.0]
# Trial 6: Best value = [-9.453323356199078, 9.0]
# Trial 7: Best value = [-233.67029260752417, 232.0]
# Trial 8: Best value = [87.99203310314907, 97.0]
# Trial 9: Best value = [-247.3006446033359, 189.0]
# Trial 10: Best value = [99.58457331213921, 151.0]
# Trial 11: Best value = [869.1926460884704, 599.0]
# Trial 12: Best value = [164.44383489905508, 203.0]
# Trial 13: Best value = [267.63740176036555, 183.0]
# Trial 14: Best value = [-180.32554504400116, 158.0]
# Trial 15: Best value = [35.414034673272425, 112.0]
# Trial 16: Best value = [-599.0375067879481, 556.0]
# Trial 17: Best value = [-30.23947556616759, 67.0]
# Trial 18: Best value = [-322.7453503622835, 424.0]
# Trial 19: Best value = [-39.54070262477896, 6.0]
# Trial 20: Best value = [12.331128391134769, 93.0]
# Trial 21: Best value = [55.93409120389542, 517.0]
# Trial 22: Best value = [-10.304657735145344, 42.0]
# Trial 23: Best value = [-480.902372870845, 565.0]
# Trial 24: Best value = [-127.69250270057361, 91.0]
# Trial 25: Best value = [-1005.8651791598296, 546.0]
# Trial 26: Best value = [-230.55900884114692, 52.0]
# Trial 27: Best value = [-992.4113141884095, 407.0]
# Trial 28: Best value = [110.34191983933705, 61.0]
# Trial 29: Best value = [1.222218435830528, 84.0]
# Trial 30: Best value = [-1049.4493214164972, 199.0]
# Trial 31: Best value = [-260.0686859984689, 53.0]
# Trial 32: Best value = [-561.7339993375775, 611.0]
# Trial 33: Best value = [131.06736814684157, 46.0]
# Trial 34: Best value = [-477.2807233487248, 163.0]
# Trial 35: Best value = [-117.8088305582159, 189.0]
# Trial 36: Best value = [-353.49845329583917, 274.0]
# Trial 37: Best value = [-616.6067279746662, 525.0]
# Trial 38: Best value = [-18.160323540755655, 59.0]
# Trial 39: Best value = [-46.114003983327386, 16.0]
# Trial 40: Best value = [-266.13650864953513, 47.0]
# Trial 41: Best value = [-619.6248191993747, 244.0]
# Trial 42: Best value = [-34.70349870913047, 49.0]
# Trial 43: Best value = [-26.222408314692913, 52.0]
# Trial 44: Best value = [-409.7206209745888, 352.0]
# Trial 45: Best value = [-933.9533969793674, 237.0]
# Trial 46: Best value = [99.28699494798705, 201.0]
# Trial 47: Best value = [-44.21371526787365, 196.0]
# Trial 48: Best value = [-1088.0458778763702, 1293.0]
# Trial 49: Best value = [-36.372093979076, 5.0]
# Trial 50: Best value = [-23.39142226429126, 3.0]
# Trial 51: Best value = [240.81036073860676, 133.0]
# Trial 52: Best value = [11.877095706189227, 9.0]
# Trial 53: Best value = [315.37460635233987, 88.0]
# Trial 54: Best value = [176.38379282651715, 178.0]
# Trial 55: Best value = [157.37419103615176, 44.0]
# Trial 56: Best value = [209.41255995215388, 298.0]
# Trial 57: Best value = [-84.21485512608311, 308.0]
# Trial 58: Best value = [141.64556305383022, 294.0]
# Trial 59: Best value = [355.50342952215175, 201.0]
# Trial 60: Best value = [-2.6792486055145126, 42.0]
# Trial 61: Best value = [182.4320416596175, 39.0]
# Trial 62: Best value = [-201.3957228821081, 753.0]
# Trial 63: Best value = [-277.0166709658359, 223.0]
# Trial 64: Best value = [-145.44447747162542, 31.0]
# Trial 65: Best value = [59.600283403362354, 85.0]
# Trial 66: Best value = [-864.1706317527284, 517.0]
# Trial 67: Best value = [0.0, 3.0]
# Trial 68: Best value = [130.44584959242454, 105.0]
# Trial 69: Best value = [-23.199967573022704, 5.0]
# Trial 70: Best value = [39.47964537167967, 156.0]
# Trial 71: Best value = [-265.45741340491617, 256.0]
# Trial 72: Best value = [0.2878568898527245, 112.0]
# Trial 73: Best value = [-670.3179038548084, 311.0]
# Trial 74: Best value = [110.34191983933705, 63.0]
# Trial 75: Best value = [-183.6218068703633, 87.0]
# Trial 76: Best value = [124.88801128925654, 33.0]
# Trial 77: Best value = [-116.6501083378464, 403.0]
# Trial 78: Best value = [79.0544002582385, 21.0]
# Trial 79: Best value = [103.592541001366, 114.0]
# Trial 80: Best value = [-364.9405782243085, 158.0]
# Trial 81: Best value = [317.2257066116124, 322.0]
# Trial 82: Best value = [360.71195715199116, 947.0]
# Trial 83: Best value = [-1144.750322023073, 966.0]
# Trial 84: Best value = [-472.59462148029127, 124.0]
# Trial 85: Best value = [-49.93553682101156, 3.0]
# Trial 86: Best value = [-13.147677241082253, 148.0]
# Trial 87: Best value = [65.76528995546451, 39.0]
# Trial 88: Best value = [58.810993949078515, 1112.0]
# Trial 89: Best value = [6.908615907527424, 138.0]
# Trial 90: Best value = [33.99276831754118, 64.0]
# Trial 91: Best value = [144.67381131046457, 74.0]
# Trial 92: Best value = [-24.042397523283064, 9.0]
# Trial 93: Best value = [13.758125994552621, 3.0]
# Trial 94: Best value = [-322.7453503622835, 424.0]
# Trial 95: Best value = [-252.1388954163578, 131.0]
# Trial 96: Best value = [15.494796405913583, 57.0]
# Trial 97: Best value = [0.0, 5.0]
# Trial 98: Best value = [-18.562313931811264, 4.0]
# Trial 99: Best value = [-31.31141310150665, 3.0]
# Trial 100: Best value = [299.0133140165727, 101.0]
# Trial 101: Best value = [-1231.2508312204357, 382.0]
# Trial 102: Best value = [142.59362091778777, 101.0]
# Trial 103: Best value = [7.81551382637668, 3.0]
# Trial 104: Best value = [-73.56768604844294, 21.0]
# Trial 105: Best value = [-251.22304858845223, 102.0]
# Trial 106: Best value = [13.409086098853031, 521.0]
# Trial 107: Best value = [150.4841016082549, 20.0]
# Trial 108: Best value = [-36.19251200791062, 4.0]
# Trial 109: Best value = [-27.192966610636812, 4.0]
# Trial 110: Best value = [-26.222408314692913, 30.0]
# Trial 111: Best value = [0.0, 3.0]
# Trial 112: Best value = [149.91330039767075, 30.0]
# Trial 113: Best value = [-13.980152379992546, 13.0]
# Trial 114: Best value = [-25.997779355541727, 4.0]
# Trial 115: Best value = [-53.0385751797916, 5.0]
# Trial 116: Best value = [-33.06228387753339, 3.0]
# Trial 117: Best value = [369.3599633583747, 673.0]
# Trial 118: Best value = [-24.84764921563015, 6.0]
# Trial 119: Best value = [304.9604196208164, 272.0]
# Trial 120: Best value = [-397.61311408356346, 63.0]
# Trial 121: Best value = [-42.34545424051956, 94.0]
# Trial 122: Best value = [100.97974265317345, 40.0]
# Trial 123: Best value = [-56.48170999233034, 5.0]
# Trial 124: Best value = [41.2357082809419, 10.0]
# Trial 125: Best value = [202.10008545298015, 76.0]
# Trial 126: Best value = [11.202834762715527, 4.0]
# Trial 127: Best value = [116.12266826500087, 213.0]
# Trial 128: Best value = [156.39280858503093, 203.0]
# Trial 129: Best value = [-1098.205739106187, 298.0]
# Trial 130: Best value = [-67.16663262195159, 95.0]
# Trial 131: Best value = [-25.82842561898577, 6.0]
# Trial 132: Best value = [-120.67722232282222, 55.0]
# Trial 133: Best value = [-584.3629693381223, 294.0]
# Trial 134: Best value = [110.34191983933705, 61.0]
# Trial 135: Best value = [346.7541045711732, 269.0]
# Trial 136: Best value = [-30.742540806822973, 3.0]
# Trial 137: Best value = [353.3762047216151, 1044.0]
# Trial 138: Best value = [-23.39142226429126, 3.0]
# Trial 139: Best value = [-31.54637694311453, 5.0]
# Trial 140: Best value = [-119.88912665372808, 4.0]
# Trial 141: Best value = [-14.148313931810822, 14.0]
# Trial 142: Best value = [65.01234120494676, 18.0]
# Trial 143: Best value = [-2.6792486055145126, 53.0]
# Trial 144: Best value = [36.58481171521808, 13.0]
# Trial 145: Best value = [316.3182224805369, 342.0]
# Trial 146: Best value = [31.037954171497855, 11.0]
# Trial 147: Best value = [84.23448910247225, 25.0]
# Trial 148: Best value = [467.27614203054446, 263.0]
# Trial 149: Best value = [235.00242052468533, 169.0]
# Trial 150: Best value = [601.9436714327694, 432.0]
# Trial 151: Best value = [314.5814884548075, 77.0]
# Trial 152: Best value = [-8.606277987638565, 3.0]
# Trial 153: Best value = [82.82633067973956, 51.0]
# Trial 154: Best value = [255.82416112451253, 175.0]
# Trial 155: Best value = [411.34983945533384, 753.0]
# Trial 156: Best value = [0.0, 3.0]
# Trial 157: Best value = [52.01339370120816, 240.0]
# Trial 158: Best value = [90.17819876510549, 37.0]
# Trial 159: Best value = [-204.03083993222288, 1040.0]
# Trial 160: Best value = [175.59945754494134, 191.0]
# Trial 161: Best value = [0.0, 5.0]
# Trial 162: Best value = [6.264014296465024, 4.0]
# Trial 163: Best value = [0.0, 3.0]
# Trial 164: Best value = [102.64068147645413, 73.0]
# Trial 165: Best value = [289.78610314549275, 234.0]
# Trial 166: Best value = [-18.562313931811264, 4.0]
# Trial 167: Best value = [18.79204288939507, 7.0]
# Trial 168: Best value = [317.7057239046034, 342.0]
# Trial 169: Best value = [-19.197023282147395, 3.0]
# Trial 170: Best value = [-81.63732576785824, 22.0]
# Trial 171: Best value = [96.16772327327435, 31.0]
# Trial 172: Best value = [49.24901671789414, 100.0]
# Trial 173: Best value = [7.81551382637668, 4.0]
# Trial 174: Best value = [-17.166410114604275, 5.0]
# Trial 175: Best value = [184.1599292662872, 34.0]
# Trial 176: Best value = [317.99811497013314, 197.0]
# Trial 177: Best value = [478.73714733731595, 488.0]
# Trial 178: Best value = [377.2413742388587, 320.0]
# Trial 179: Best value = [10.136896821380908, 39.0]
# Trial 180: Best value = [-162.336723533025, 62.0]
# Trial 181: Best value = [91.95910385383809, 15.0]
# Trial 182: Best value = [229.57478203756196, 71.0]
# Trial 183: Best value = [292.660974131313, 195.0]
# Trial 184: Best value = [-418.8770409091202, 571.0]
# Trial 185: Best value = [273.7058647657429, 197.0]
# Trial 186: Best value = [282.957889975582, 71.0]
# Trial 187: Best value = [-79.36565965770139, 169.0]
# Trial 188: Best value = [215.3763626631491, 125.0]
# Trial 189: Best value = [211.93375133812344, 112.0]
# Trial 190: Best value = [87.61081144063154, 40.0]
# Trial 191: Best value = [84.23448910247225, 25.0]
# Trial 192: Best value = [0.0, 3.0]
# Trial 193: Best value = [43.0727413169549, 10.0]
# Trial 194: Best value = [321.82896868783473, 144.0]
# Trial 195: Best value = [4.1447707500970665, 12.0]
# Trial 196: Best value = [303.4922420167997, 468.0]
# Trial 197: Best value = [-518.7427967958719, 300.0]
# Trial 198: Best value = [215.21545480592422, 93.0]
# Trial 199: Best value = [296.24678636692664, 193.0]

# %%
def compute_trade_signal(row):
    trade_enter_buy = 0.5
    trade_enter_sell = 0.5
    if row['BuyPower'] > trade_enter_buy and row['BuyPower'] > row['SellPower']:
        return 'B'
    elif row['SellPower'] > trade_enter_sell and row['SellPower'] > row['BuyPower']:
        return 'S'
    else:
        return 'N'
    
tr_signals['SignalNew'] = tr_signals.apply(compute_trade_signal, axis=1)

# %%
buy_signals = tr_signals[tr_signals['Signal'] == 'B']
sell_signals = tr_signals[tr_signals['Signal']== 'S']
trade_to_show = '2024-01-05'
#trading_data['Date'] = pd.to_datetime(trading_data['Date'])
fig = make_subplots(rows=2, cols=1, shared_xaxes=True, 
                    row_heights=[0.7, 0.3], vertical_spacing=0.1,
                    subplot_titles=("CandleStick Chart", "Buy/Sell Signals"))
fig.add_trace(
    go.Candlestick(
        x=tr_signals['Date'], 
        open=tr_signals['Open'], 
        high=tr_signals['High'], 
        low=tr_signals['Low'], 
        close=tr_signals['Close'],
        name='OHLC'
        ), row=1, col=1
)
'''
fig.add_trace(
    go.Scatter(
        x=buy_signals['Date'], 
        y=buy_signals['Low'], 
        mode='markers', 
        name='Buy Signal', 
        marker=dict(color='blue', size=10)))

fig.add_trace(
    go.Scatter(
        x=sell_signals['Date'], 
        y=sell_signals['High'], 
        mode='markers', 
        name='Sell Signal', 
        marker=dict(color='yellow', size=10)))
'''
for index, row in positions_df.iterrows():
    if row['Type'] == 'B':
        entry_symbol = 'triangle-up'
        entry_color = 'blue'
        exit_symbol = 'triangle-down'
        exit_color ='green' if row['Profit'] >= 0 else 'red'
    elif row['Type'] == 'S':
        entry_symbol = 'triangle-down'
        entry_color = 'yellow'
        exit_symbol = 'triangle-up'
        exit_color = 'green' if row['Profit'] >= 0 else 'red'
    
    fig.add_trace(
        go.Scatter(
            x=[row['EntryDate']],
            y=[row['Entry'] + 0.1],
            mode='markers',
            marker=dict(symbol=entry_symbol, size=10, color=entry_color),
            name=f'Entry {row['Type']}'
        ))
    
    fig.add_trace(
        go.Scatter(
            x=[row['ExitDate']],
            y=[row['Exit'] - 0.1],
            mode='markers',
            marker=dict(symbol=exit_symbol, size=10, color=exit_color),
            name=f'Exit {row["Type"]}'
        ))
  
fig.add_trace(
    go.Scatter(
        x=tr_signals['Date'],
        y=tr_signals['BuyPower'],
        mode='lines',
        name='Buy Signal',
        line=dict(color='green', width=2)
    ), row=2, col=1
)

fig.add_trace(
    go.Scatter(
        x=tr_signals['Date'],
        y=tr_signals['SellPower'],
        mode='lines',
        name='Sell Signal',
        line=dict(color='red', width=2)
    ), row=2, col=1
)
  

fig.update_layout(
    title='CandleStick chart with Buy Sell Signals',
    xaxis=dict(type="date", 
               rangebreaks=[
                   dict(bounds=["sat", "mon"]),
                   dict(bounds=[16,9.5], pattern='hour')
               ]              
            ),
    xaxis_rangeslider_visible=False,
    height=600,
    hovermode='x unified'
)



fig.update_xaxes(matches='x')

fig.show()
