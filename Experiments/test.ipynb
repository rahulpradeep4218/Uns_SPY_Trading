# %%
st = ''
print(int(st))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 2
#       1 st = ''
# ----> 2 print(int(st))
#
# ValueError: invalid literal for int() with base 10: ''

# %%
from functions.utility import get_columns_mapping
import yaml

# %%
config_path = '../Config/training.yaml'
with open(config_path, 'r') as file:
    conf = yaml.safe_load(file)

# %%
robust_cols = conf['scaling']['robust']['columns']
robust_cols
# Out:
# 'bolband,donchn,tchr'

# %%
print(get_columns_mapping(robust_cols, conf))
# Out:
# ['BOLLBU', 'BOLLBL', 'DONUP', 'DONLOW', 'TCHR_U', 'TCHR_L']

# %%
import hashlib
from datetime import datetime

# Get current time string with seconds
timestamp = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
data = timestamp + "xgboost"
# Convert to SHA256 hash
hash_object = hashlib.sha256(data.encode())
unique_id = hash_object.hexdigest()

print("Timestamp:", timestamp)
print("Unique ID:", unique_id)
# Out:
# Timestamp: 2025-05-26 15:25:28
# Unique ID: 07aea41c3dc4f8795045df30f14e6680fe044d4d8d99b25f11ce79b132511e29

# %%
print(conf['training_details']['high_qalpha'][0])
# Out:
# 0.25
